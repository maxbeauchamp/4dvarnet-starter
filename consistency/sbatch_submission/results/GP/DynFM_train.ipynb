# %%
# --- parameters (patch_notebook_params.py) ---
MAX_EPOCHS = 2000
N_SAMPLES = 10           # run_metrics.py forces 50 for generative methods
RESET_TRAINING = False
CUDA_VISIBLE_DEVICES = "0"
METRICS_CSV = "results/metrics.csv"

# %%
# Parameters
MAX_EPOCHS = 2000
N_SAMPLES = 1
RESET_TRAINING = False
CUDA_VISIBLE_DEVICES = "0"
METRICS_CSV = "/Odyssey/private/m19beauc/4dvarnet-starter-devs/consistency/sbatch_submission/results/GP/DynFM_metrics_train.csv"

# %%
# --- epoch heartbeat (patch_notebook_params.py) ---
import pytorch_lightning as _pl

class EpochHeartbeat(_pl.Callback):
    """Prints one clear progress line every `every_n_epochs` epochs, so
    sbatch logs show training progress without the noise of a per-batch
    tqdm progress bar (which doesn't render well once redirected to a
    plain log file).    """

    def __init__(self, every_n_epochs: int = 1):
        self.every_n_epochs = every_n_epochs

    def on_train_epoch_end(self, trainer, pl_module):
        epoch = trainer.current_epoch + 1
        if epoch % self.every_n_epochs != 0 and epoch != trainer.max_epochs:
            return
        parts = []
        for k, v in sorted(trainer.callback_metrics.items()):
            try:
                parts.append(f'{k}={float(v):.4f}')
            except (TypeError, ValueError):
                pass
        print(f'[progress] epoch {epoch}/{trainer.max_epochs} | ' + ' | '.join(parts), flush=True)

# %% [markdown]
# ## Dynamic Flow Matching (DynFM) — GP / SPDE
#
# Unified spin-up + physical transport via Flow Matching.
# - **Spin-up** (t ∈ [0, SF]): linear interpolant noise → IC (frame 0)
# - **Physical** (t ∈ [SF, 1]): linear interpolant frame[k] → frame[k+1]
# - Single UNet predicts velocity v(x_t, y, t) → 1 channel output
# - No Karras preconditioning — ODE integration preserves diversity naturally

# %%
# !nvidia-smi
# Out:
# Mon Aug 10 09:03:07 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 NVL                Off |   00000000:E3:00.0 Off |                    0 |
# | N/A   44C    P0             64W /  400W |       0MiB /  95830MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os; os.environ["CUDA_VISIBLE_DEVICES"] = CUDA_VISIBLE_DEVICES

# %%
import math
import os
import zipfile
import glob
from dataclasses import dataclass
from typing import Optional, Tuple

import numpy as np
import xarray as xr
import pandas as pd
import torch
from torch import Tensor, nn
from torch.nn import functional as F
from pytorch_lightning import LightningModule, Trainer, seed_everything
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from matplotlib import pyplot as plt
from torchinfo import summary

import sys
sys.path.append('../..')      # -> consistency/
sys.path.append('../../..')   # -> 4dvarnet-starter-devs/

from flowmatching_models_FM import (
    UNetFM, UNetFMConfig,
    LogScaleModel, TimeEmbedding,
    neglogpdf, neglogcdf,
    sample_uniform_time, masked_average,
)

try:
    from properscoring import crps_ensemble
    HAS_PROPERSCORING = True
except ImportError:
    HAS_PROPERSCORING = False
    print("properscoring not installed — CRPS disabled.")

# %% [markdown]
# ## DataModule — SPDE Gaussian Process
#
# Same dataset as DynCM: `window_size` physical frames + sparse observations.

# %%
from src.data_notebook_spde import SPDEDataModule

SPDE_PATH = "../../../data/SPDE_diffusion_dataset_1.nc"

ds_inspect = xr.open_dataset(SPDE_PATH)
print(ds_inspect)
print("\nVariables:")
for v in ds_inspect.data_vars:
    print(f"  {v}: {ds_inspect[v].dims}  shape={ds_inspect[v].shape}  dtype={ds_inspect[v].dtype}")
ds_inspect.close()

datamodule = SPDEDataModule(
    path=SPDE_PATH,
    window_size=5,
    stride=1,
    train_ratio=0.7,
    val_ratio=0.15,
    dl_kw={"batch_size": 1, "num_workers": 1},
)
datamodule.setup()

sample = datamodule.train_ds[0]
C  = datamodule.window_size
H, W = sample.tgt.shape[-2], sample.tgt.shape[-1]
t_IC = 1.0 / C   # transition point between spin-up and physical regime

print(f"window_size C      = {C}")
print(f"t_IC (transition)  = {t_IC:.4f}  (= 1/C)")
print(f"Spatial size       = {H} x {W}")
print(f"TrainingItem: input (y) {sample.input.shape}  tgt (x) {sample.tgt.shape}")

fig, axes = plt.subplots(2, C, figsize=(3 * C, 5))
for t_idx in range(C):
    axes[0, t_idx].imshow(sample.tgt[t_idx],   origin="lower", cmap="RdBu_r")
    axes[0, t_idx].set_title(f"x GT  t={t_idx}", fontsize=8)
    axes[0, t_idx].axis("off")
    axes[1, t_idx].imshow(sample.input[t_idx], origin="lower", cmap="RdBu_r")
    axes[1, t_idx].set_title(f"y obs t={t_idx}", fontsize=8)
    axes[1, t_idx].axis("off")
plt.suptitle("Training sample — GT (top) & observations (bottom)", y=1.01)
plt.tight_layout()
plt.show()
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 300, lat: 128, lon: 128)
# Coordinates:
#   * lon        (lon) int64 0 1 2 3 4 5 6 7 8 ... 120 121 122 123 124 125 126 127
#   * lat        (lat) int64 0 1 2 3 4 5 6 7 8 ... 120 121 122 123 124 125 126 127
#   * time       (time) int64 0 1 2 3 4 5 6 7 ... 292 293 294 295 296 297 298 299
# Data variables:
#     x          (time, lat, lon) float32 ...
#     y          (time, lat, lon) float32 ...
#     OI         (time, lat, lon) float64 ...
#     H11        (lat, lon) float32 ...
#     H22        (lat, lon) float32 ...
#     H12        (lat, lon) float32 ...
#     Time       (time) int64 ...
#     longitude  (lon) int64 ...
#     latitude   (lat) int64 ...
# Attributes:
#     description:  SPDE-based diffusion GP
#
# Variables:
#   x: ('time', 'lat', 'lon')  shape=(300, 128, 128)  dtype=float32
#   y: ('time', 'lat', 'lon')  shape=(300, 128, 128)  dtype=float32
#   OI: ('time', 'lat', 'lon')  shape=(300, 128, 128)  dtype=float64
#   H11: ('lat', 'lon')  shape=(128, 128)  dtype=float32
#   H22: ('lat', 'lon')  shape=(128, 128)  dtype=float32
#   H12: ('lat', 'lon')  shape=(128, 128)  dtype=float32
#   Time: ('time',)  shape=(300,)  dtype=int64
#   longitude: ('lon',)  shape=(128,)  dtype=int64
#   latitude: ('lat',)  shape=(128,)  dtype=int64
# [SPDEDataModule] T=300, window=5, stride=1 → 296 windows: train=207, val=44, test=45
# [SPDEDataModule] Norm stats (mean, std): (-0.00018237734911963344, 0.249156191945076)
# window_size C      = 5
# t_IC (transition)  = 0.2000  (= 1/C)
# Spatial size       = 128 x 128
# TrainingItem: input (y) (5, 128, 128)  tgt (x) (5, 128, 128)

# %% [markdown]
# ### UNetFM for DynFM
#
# - **channels=1** : the ODE state is a single spatial field
# - **cond_channels=C** : full observation window as conditioning
# - Input: cat(x_t, y_filled, mask) → 1 + 2C channels
# - Output: velocity v → 1 channel
# - Single time embedding t (no dual t, t' like DynCM)

# %%
cfg = UNetFMConfig(channels=1, cond_channels=C)
net = UNetFM(cfg)

summary(
    net,
    input_size=(
        (1, 1, H, W),    # x_t (single frame)
        (1, C, H, W),    # y (full obs window)
        (1,),             # t
    ),
)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# UNetFM                                        [1, 1, 128, 128]          --
# ├─Conv2d: 1-1                                 [1, 64, 128, 128]         6,400
# ├─TimeEmbedding: 1-2                          [1, 128, 1, 1]            64
# │    └─Sequential: 2-1                        [1, 128, 1, 1]            --
# │    │    └─Linear: 3-1                       [1, 512]                  66,048
# │    │    └─SiLU: 3-2                         [1, 512]                  --
# │    │    └─Linear: 3-3                       [1, 128]                  65,664
# │    │    └─Rearrange: 3-4                    [1, 128, 1, 1]            --
# ├─ModuleList: 1-3                             --                        --
# │    └─UNetBlock: 2-2                         [1, 64, 128, 128]         --
# │    │    └─Sequential: 3-5                   [1, 64, 128, 128]         37,056
# │    │    └─Sequential: 3-6                   [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-7                   [1, 64, 128, 128]         37,056
# │    │    └─Conv2d: 3-8                       [1, 64, 128, 128]         4,160
# │    └─UNetBlock: 2-3                         [1, 64, 128, 128]         --
# │    │    └─Sequential: 3-9                   [1, 64, 128, 128]         37,056
# │    │    └─Sequential: 3-10                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-11                  [1, 64, 128, 128]         37,056
# │    │    └─Conv2d: 3-12                      [1, 64, 128, 128]         4,160
# │    └─Downsample: 2-4                        [1, 64, 64, 64]           --
# │    │    └─Sequential: 3-13                  [1, 64, 64, 64]           16,448
# │    └─UNetBlock: 2-5                         [1, 128, 64, 64]          --
# │    │    └─Sequential: 3-14                  [1, 128, 64, 64]          73,984
# │    │    └─Sequential: 3-15                  [1, 128, 1, 1]            16,512
# │    │    └─Sequential: 3-16                  [1, 128, 64, 64]          147,840
# │    │    └─Conv2d: 3-17                      [1, 128, 64, 64]          8,320
# │    └─UNetBlock: 2-6                         [1, 128, 64, 64]          --
# │    │    └─Sequential: 3-18                  [1, 128, 64, 64]          147,840
# │    │    └─Sequential: 3-19                  [1, 128, 1, 1]            16,512
# │    │    └─Sequential: 3-20                  [1, 128, 64, 64]          147,840
# │    │    └─Conv2d: 3-21                      [1, 128, 64, 64]          16,512
# │    └─Downsample: 2-7                        [1, 128, 32, 32]          --
# │    │    └─Sequential: 3-22                  [1, 128, 32, 32]          65,664
# ├─ModuleList: 1-4                             --                        --
# │    └─UNetBlockWithSelfAttention: 2-8        [1, 256, 32, 32]          --
# │    │    └─UNetBlock: 3-23                   [1, 256, 32, 32]          952,064
# │    │    └─SelfAttention: 3-24               [1, 256, 32, 32]          328,960
# │    └─UNetBlockWithSelfAttention: 2-9        [1, 256, 32, 32]          --
# │    │    └─UNetBlock: 3-25                   [1, 256, 32, 32]          1,280,000
# │    │    └─SelfAttention: 3-26               [1, 256, 32, 32]          328,960
# │    └─UNetBlockWithSelfAttention: 2-10       [1, 256, 32, 32]          --
# │    │    └─UNetBlock: 3-27                   [1, 256, 32, 32]          1,280,000
# │    │    └─SelfAttention: 3-28               [1, 256, 32, 32]          328,960
# │    └─UNetBlockWithSelfAttention: 2-11       [1, 256, 32, 32]          --
# │    │    └─UNetBlock: 3-29                   [1, 256, 32, 32]          1,280,000
# │    │    └─SelfAttention: 3-30               [1, 256, 32, 32]          328,960
# │    └─Downsample: 2-12                       [1, 256, 16, 16]          --
# │    │    └─Sequential: 3-31                  [1, 256, 16, 16]          262,400
# │    └─UNetBlockWithSelfAttention: 2-13       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-32                   [1, 256, 16, 16]          1,280,000
# │    │    └─SelfAttention: 3-33               [1, 256, 16, 16]          328,960
# │    └─UNetBlockWithSelfAttention: 2-14       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-34                   [1, 256, 16, 16]          1,280,000
# │    │    └─SelfAttention: 3-35               [1, 256, 16, 16]          328,960
# │    └─UNetBlockWithSelfAttention: 2-15       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-36                   [1, 256, 16, 16]          1,280,000
# │    │    └─SelfAttention: 3-37               [1, 256, 16, 16]          328,960
# │    └─UNetBlockWithSelfAttention: 2-16       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-38                   [1, 256, 16, 16]          1,280,000
# │    │    └─SelfAttention: 3-39               [1, 256, 16, 16]          328,960
# ├─ModuleList: 1-5                             --                        --
# │    └─UNetBlockWithSelfAttention: 2-17       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-40                   [1, 256, 16, 16]          1,935,872
# │    │    └─SelfAttention: 3-41               [1, 256, 16, 16]          328,960
# │    └─UNetBlockWithSelfAttention: 2-18       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-42                   [1, 256, 16, 16]          1,935,872
# │    │    └─SelfAttention: 3-43               [1, 256, 16, 16]          328,960
# │    └─UNetBlockWithSelfAttention: 2-19       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-44                   [1, 256, 16, 16]          1,935,872
# │    │    └─SelfAttention: 3-45               [1, 256, 16, 16]          328,960
# │    └─UNetBlockWithSelfAttention: 2-20       [1, 256, 16, 16]          --
# │    │    └─UNetBlock: 3-46                   [1, 256, 16, 16]          1,935,872
# │    │    └─SelfAttention: 3-47               [1, 256, 16, 16]          328,960
# │    └─Upsample: 2-21                         [1, 256, 32, 32]          --
# │    │    └─Sequential: 3-48                  [1, 256, 32, 32]          590,080
# │    └─UNetBlockWithSelfAttention: 2-22       [1, 256, 32, 32]          --
# │    │    └─UNetBlock: 3-49                   [1, 256, 32, 32]          1,935,872
# │    │    └─SelfAttention: 3-50               [1, 256, 32, 32]          328,960
# │    └─UNetBlockWithSelfAttention: 2-23       [1, 256, 32, 32]          --
# │    │    └─UNetBlock: 3-51                   [1, 256, 32, 32]          1,935,872
# │    │    └─SelfAttention: 3-52               [1, 256, 32, 32]          328,960
# │    └─UNetBlockWithSelfAttention: 2-24       [1, 256, 32, 32]          --
# │    │    └─UNetBlock: 3-53                   [1, 256, 32, 32]          1,935,872
# │    │    └─SelfAttention: 3-54               [1, 256, 32, 32]          328,960
# │    └─UNetBlockWithSelfAttention: 2-25       [1, 128, 32, 32]          --
# │    │    └─UNetBlock: 3-55                   [1, 128, 32, 32]          820,992
# │    │    └─SelfAttention: 3-56               [1, 128, 32, 32]          82,560
# ├─ModuleList: 1-6                             --                        --
# │    └─Upsample: 2-26                         [1, 128, 64, 64]          --
# │    │    └─Sequential: 3-57                  [1, 128, 64, 64]          147,584
# │    └─UNetBlock: 2-27                        [1, 128, 64, 64]          --
# │    │    └─Sequential: 3-58                  [1, 128, 64, 64]          295,552
# │    │    └─Sequential: 3-59                  [1, 128, 1, 1]            16,512
# │    │    └─Sequential: 3-60                  [1, 128, 64, 64]          147,840
# │    │    └─Conv2d: 3-61                      [1, 128, 64, 64]          32,896
# │    └─UNetBlock: 2-28                        [1, 64, 64, 64]           --
# │    │    └─Sequential: 3-62                  [1, 64, 64, 64]           148,032
# │    │    └─Sequential: 3-63                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-64                  [1, 64, 64, 64]           37,056
# │    │    └─Conv2d: 3-65                      [1, 64, 64, 64]           16,448
# │    └─Upsample: 2-29                         [1, 64, 128, 128]         --
# │    │    └─Sequential: 3-66                  [1, 64, 128, 128]         36,928
# │    └─UNetBlock: 2-30                        [1, 64, 128, 128]         --
# │    │    └─Sequential: 3-67                  [1, 64, 128, 128]         74,048
# │    │    └─Sequential: 3-68                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-69                  [1, 64, 128, 128]         37,056
# │    │    └─Conv2d: 3-70                      [1, 64, 128, 128]         8,256
# │    └─UNetBlock: 2-31                        [1, 64, 128, 128]         --
# │    │    └─Sequential: 3-71                  [1, 64, 128, 128]         74,048
# │    │    └─Sequential: 3-72                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-73                  [1, 64, 128, 128]         37,056
# │    │    └─Conv2d: 3-74                      [1, 64, 128, 128]         8,256
# ├─Conv2d: 1-7                                 [1, 1, 128, 128]          577
# ===============================================================================================
# Total params: 32,265,217
# Trainable params: 32,265,153
# Non-trainable params: 64
# Total mult-adds (Units.GIGABYTES): 30.71
# ===============================================================================================
# Input size (MB): 0.39
# Forward/backward pass size (MB): 542.81
# Params size (MB): 129.06
# Estimated Total Size (MB): 672.27
# ===============================================================================================

# %% [markdown]
# ### DynFM Training — Unified Interpolant
#
# **Timeline** t ∈ [0, 1] with `SF = SPINUP_FRAC`:
#
# | Regime | Time | Interpolant | Velocity target |
# |---|---|---|---|
# | Spin-up | t ∈ [0, SF] | x(t) = (1−τ)·ε + τ·IC, τ=t/SF | v = (IC − ε) / SF |
# | Physical | t ∈ [SF, 1] | x(t) = (1−α)·f[k] + α·f[k+1] | v = (f[k+1] − f[k])·(C−1)/(1−SF) |
#
# At inference, Heun ODE integration from t=0 (noise) to t=1 extracts physical frames at
# t_k = SF + k·(1−SF)/(C−1) for k=0,...,C−1.

# %%
SPINUP_FRAC = 0.3

@dataclass
class LitDynFMConfig:
    lr: float = 1e-4
    betas: Tuple[float, float] = (0.9, 0.995)
    lr_scheduler_start_factor: float = 1e-5
    lr_scheduler_iters: int = 10_000
    ema_decay: float = 0.999
    spinup_frac: float = 0.3
    eval_n_steps: int = 40
    loss_type: str = "mse"           # "mse" or "log_scale"
    precondition: bool = True        # velocity preconditioning (c_out scaling)


class LitDynFM(LightningModule):

    def __init__(self, network: UNetFM, config: LitDynFMConfig,
                 n_log_scale_embedding: int = 128):
        super().__init__()
        self.network = network
        self.config  = config
        self.sf      = config.spinup_frac
        self.precondition = config.precondition
        self.use_log_scale = config.loss_type == "log_scale"
        if self.use_log_scale:
            self.log_scale = LogScaleModel(n_log_scale_embedding, n_vars=1)
        self.ema_model = torch.optim.swa_utils.AveragedModel(
            network,
            multi_avg_fn=torch.optim.swa_utils.get_ema_multi_avg_fn(config.ema_decay),
            device="cpu",
        )
        self.ema_model.requires_grad_(False)
        self.ema_model.eval()
        self._val_batch = None

    def on_fit_start(self):
        try:
            dl = self.trainer.datamodule.val_dataloader()
            batch = next(iter(dl))
            if isinstance(batch, list): batch = batch[0]
            self._val_batch = batch
            print(f"Val batch cached: tgt={batch.tgt.shape}")
        except Exception as e:
            print(f"Could not cache val batch: {e}")

    def on_train_batch_end(self, outputs, batch, batch_idx):
        self.ema_model.update_parameters(self.network)

    def _build_interpolant(self, x_full, t, noise):
        B, C, H, W = x_full.shape
        SF = self.sf
        is_spinup = t < SF

        # Spin-up: noise -> IC (frame 0)
        tau_s = (t / SF).clamp(0, 1).view(B, 1, 1, 1)
        ic = x_full[:, [0], :, :]
        xt_s = (1 - tau_s) * noise + tau_s * ic
        vt_s = (ic - noise) / SF

        # Physical: frame[k] -> frame[k+1]
        tau_p = ((t - SF) / (1 - SF)).clamp(0, 1)
        fpos = tau_p * (C - 1)
        k = fpos.long().clamp(0, C - 2)
        alpha = (fpos - k.float()).view(B, 1, 1, 1)
        b_idx = torch.arange(B, device=x_full.device)
        f_k  = x_full[b_idx, k].unsqueeze(1)
        f_k1 = x_full[b_idx, (k + 1).clamp(max=C - 1)].unsqueeze(1)
        xt_p = (1 - alpha) * f_k + alpha * f_k1
        vt_p = (f_k1 - f_k) * (C - 1) / (1 - SF)

        is_s = is_spinup.view(B, 1, 1, 1)
        x_t      = torch.where(is_s, xt_s, xt_p)
        v_target = torch.where(is_s, vt_s, vt_p)

        c_out = torch.where(
            is_spinup,
            torch.tensor(1.0 / SF, device=x_full.device, dtype=x_full.dtype),
            torch.tensor(float(C - 1) / (1.0 - SF), device=x_full.device, dtype=x_full.dtype),
        ).view(B, 1, 1, 1)

        return x_t, v_target, c_out

    def training_step(self, batch, batch_idx):
        if isinstance(batch, list): batch = batch[0]
        x_full = batch.tgt
        y      = batch.input
        B, C, H, W = x_full.shape

        t = sample_uniform_time(x_full).view(B)
        noise = torch.randn(B, 1, H, W, device=x_full.device, dtype=x_full.dtype)

        x_t, v_target, c_out = self._build_interpolant(x_full, t, noise)
        v_pred = self.network(x_t, y, t)

        if self.precondition:
            v_target = v_target / c_out

        if self.use_log_scale:
            log_s = self.log_scale(t).view(B, 1, 1, 1).expand_as(v_pred)
            residual = (v_target - v_pred) / log_s.exp().clamp(min=1e-5)
            loss = neglogpdf(residual, log_s).mean()
        else:
            loss = F.mse_loss(v_pred, v_target)

        self.log("train_loss", loss, prog_bar=True, on_step=True, on_epoch=True)
        return loss

    def on_train_epoch_end(self):
        if self._val_batch is None: return
        device = self.device
        dtype  = next(self.network.parameters()).dtype
        x_gt = self._val_batch.tgt.to(device=device, dtype=dtype)
        y    = self._val_batch.input.to(device=device, dtype=dtype)
        B, C, H, W = x_gt.shape

        ema_net = self.ema_model.module.to(device=device, dtype=dtype)
        ema_net.eval()

        noise = torch.randn(B, 1, H, W, device=device, dtype=dtype)
        _, traj, traj_times = dynfm_heun_sample(ema_net, noise, y,
                                    n_steps=self.config.eval_n_steps,
                                    spinup_frac=self.sf, precondition=self.precondition)
        frames = extract_dynfm_frames(traj, traj_times, C, self.sf)
        x_hat = torch.cat(frames, dim=1)

        rmse = (x_hat.float() - x_gt.float()).pow(2).mean().sqrt().item()
        print(f"[Epoch {self.current_epoch}]  Val RMSE (DynFM, EMA) = {rmse:.4f}")
        self.log("val_rmse_ema", rmse)

    def configure_optimizers(self):
        params = list(self.network.parameters())
        if self.use_log_scale:
            params += list(self.log_scale.parameters())
        opt   = torch.optim.Adam(params, lr=self.config.lr, betas=self.config.betas)
        sched = torch.optim.lr_scheduler.LinearLR(
            opt, start_factor=self.config.lr_scheduler_start_factor,
            total_iters=self.config.lr_scheduler_iters,
        )
        return [opt], [{"scheduler": sched, "interval": "step", "frequency": 1}]


print("LitDynFM defined")
# Out:
# LitDynFM defined

# %%
@torch.no_grad()
def dynfm_heun_sample(model, noise, y, n_steps=40, spinup_frac=0.3, precondition=True):
    """Heun (RK2) ODE sampling with boundary-aware time grid.

    Inserts the spinup/physical boundary (t=SF) and frame-boundary times
    into the integration grid so that no single Heun step straddles a
    c_out discontinuity or a velocity-target transition.
    """
    C_obs = y.shape[1]
    SF = spinup_frac
    c_out_s = 1.0 / SF
    c_out_p = float(C_obs - 1) / (1.0 - SF)

    # Uniform grid + regime boundaries (SF, frame times)
    boundaries = {SF}
    for k in range(C_obs):
        boundaries.add(SF + (1.0 - SF) * k / max(C_obs - 1, 1))
    uniform_times = {i / n_steps for i in range(n_steps + 1)}
    all_times = sorted(uniform_times | boundaries)

    x = noise.clone()
    traj = [x.clone()]
    traj_times = [0.0]

    for i in range(len(all_times) - 1):
        t0 = all_times[i]
        t1 = all_times[i + 1]
        dt = t1 - t0
        if dt < 1e-10:
            continue

        t0_t = torch.full((x.size(0),), t0, device=x.device, dtype=x.dtype)
        t1_t = torch.full((x.size(0),), t1, device=x.device, dtype=x.dtype)

        v0 = model(x, y, t0_t)
        if precondition:
            v0 = v0 * (c_out_s if t0 < SF else c_out_p)

        x1_pred = x + dt * v0

        v1 = model(x1_pred, y, t1_t)
        if precondition:
            v1 = v1 * (c_out_s if t1 < SF else c_out_p)

        x = x + dt * 0.5 * (v0 + v1)
        traj.append(x.clone())
        traj_times.append(t1)

    return x, traj, traj_times


def extract_dynfm_frames(traj, traj_times, C, spinup_frac=0.3):
    """Extract the C physical frames from a trajectory using traj_times."""
    SF = spinup_frac
    frame_times = [SF + k * (1 - SF) / max(C - 1, 1) for k in range(C)]
    times_arr = np.array(traj_times)
    frame_indices = [int(np.argmin(np.abs(times_arr - ft))) for ft in frame_times]
    return [traj[idx] for idx in frame_indices]


n_actual = len(sorted({i / 40 for i in range(41)} | {SPINUP_FRAC} |
               {SPINUP_FRAC + k*(1-SPINUP_FRAC)/max(C-1,1) for k in range(C)})) - 1
print(f"Sampling functions defined (boundary-aware grid)")
print(f"  n_steps=40 → {n_actual} actual Heun steps (with {C+1} boundary points inserted)")
print(f"Frame extraction times (C={C}, SF={SPINUP_FRAC}):")
for k in range(C):
    ft = SPINUP_FRAC + k * (1 - SPINUP_FRAC) / max(C - 1, 1)
    print(f"  frame[{k}] @ t={ft:.3f}")
# Out:
# Sampling functions defined (boundary-aware grid)
#   n_steps=40 → 41 actual Heun steps (with 6 boundary points inserted)
# Frame extraction times (C=5, SF=0.3):
#   frame[0] @ t=0.300
#   frame[1] @ t=0.475
#   frame[2] @ t=0.650
#   frame[3] @ t=0.825
#   frame[4] @ t=1.000

# %% [markdown]
# ## Training

# %%
def is_valid_checkpoint(path: str) -> bool:
    try:
        with zipfile.ZipFile(path, 'r') as zf:
            zf.testzip()
        return True
    except Exception:
        return False

def find_best_valid_checkpoint(ckpt_dir: str) -> Optional[str]:
    if not os.path.isdir(ckpt_dir):
        return None
    last = os.path.join(ckpt_dir, "last.ckpt")
    if os.path.exists(last) and is_valid_checkpoint(last):
        print(f"Valid checkpoint: {last}")
        return last
    all_ckpts = sorted(
        [p for p in glob.glob(os.path.join(ckpt_dir, "*.ckpt")) if "last" not in p],
        key=lambda p: float(p.split("train_loss=")[-1].replace(".ckpt", ""))
        if "train_loss=" in p else float("inf"),
    )
    for p in all_ckpts:
        if is_valid_checkpoint(p):
            print(f"Valid checkpoint: {p}")
            return p
    print("No valid checkpoint found. Starting from scratch.")
    return None

LOG_DIR     = "logs_DynFM_spde"
CKPT_DIR    = os.path.join(LOG_DIR, "checkpoints")
MODEL_PATH  = os.path.join(LOG_DIR, "best_model")

# RESET_TRAINING set by the parameters cell above
if RESET_TRAINING:
    import shutil
    for d in [CKPT_DIR, MODEL_PATH]:
        if os.path.exists(d):
            shutil.rmtree(d)
    resume_ckpt = None
    print("RESET_TRAINING=True -- starting from scratch")
else:
    resume_ckpt = find_best_valid_checkpoint(CKPT_DIR)

network = UNetFM(UNetFMConfig(channels=1, cond_channels=C))
lit_dynfm = LitDynFM(
    network=network,
    config=LitDynFMConfig(
        lr_scheduler_iters=1000,
        eval_n_steps=4*C+1,
        spinup_frac=SPINUP_FRAC,
        loss_type="mse",
        precondition=True,
    ),
)

trainer = Trainer(enable_progress_bar=False, 
    accelerator="gpu",
    max_epochs=MAX_EPOCHS,
    accumulate_grad_batches=4,
    precision="16-mixed",
    log_every_n_steps=1,
    logger=TensorBoardLogger(".", name=LOG_DIR, version=""),
    callbacks=[
        LearningRateMonitor(logging_interval="step"),
        ModelCheckpoint(
            dirpath=CKPT_DIR,
            monitor="train_loss",
            save_top_k=3,
            save_last=True,
            filename="{epoch:03d}-{step}-{train_loss:.4f}",
        ),
    ],
)

seed_everything(42)
trainer.callbacks.append(EpochHeartbeat(every_n_epochs=1))
trainer.fit(lit_dynfm, datamodule, ckpt_path=resume_ckpt)

ema_net = lit_dynfm.ema_model.module
ema_net.save_pretrained(MODEL_PATH)
print(f"EMA model saved to: {MODEL_PATH}")
# Out:
# Valid checkpoint: logs_DynFM_spde/checkpoints/last.ckpt
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/lightning_fabric/plugins/environments/slurm.py:168: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /Odyssey/private/m19beauc/conda_envs/4dvarnet-starte ...
#   rank_zero_warn(
# Using 16bit Automatic Mixed Precision (AMP)
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/plugins/precision/amp.py:53: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 42
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/trainer/configuration_validator.py:69: UserWarning: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
#   rank_zero_warn("You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.")
# You are using a CUDA device ('NVIDIA H100 NVL') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:617: UserWarning: Checkpoint directory /Odyssey/private/m19beauc/4dvarnet-starter-devs/consistency/Notebooks/Notebooks_GP/logs_DynFM_spde/checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# Restoring states from the checkpoint path at logs_DynFM_spde/checkpoints/last.ckpt
# [SPDEDataModule] T=300, window=5, stride=1 → 296 windows: train=207, val=44, test=45
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/utilities/migration/utils.py:55: PossibleUserWarning: The loaded checkpoint was produced with Lightning v2.0.9, which is newer than your current Lightning version: v2.0.7
#   rank_zero_warn(
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:337: UserWarning: The dirpath has changed from 'logs_DynFM_spde/checkpoints' to '/Odyssey/private/m19beauc/4dvarnet-starter-devs/consistency/Notebooks/Notebooks_GP/logs_DynFM_spde/checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
#   warnings.warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   | Name      | Type          | Params
# --------------------------------------------
# 0 | network   | UNetFM        | 32.3 M
# 1 | ema_model | AveragedModel | 32.3 M
# --------------------------------------------
# 32.3 M    Trainable params
# 32.3 M    Non-trainable params
# 64.5 M    Total params
# 258.122   Total estimated model params size (MB)
# Restored all states from the checkpoint at logs_DynFM_spde/checkpoints/last.ckpt
# Val batch cached: tgt=torch.Size([1, 5, 128, 128])
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/utilities/_pytree.py:21: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return [pytree], LeafSpec()
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 96 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# [progress] epoch 109/2000 | train_loss=0.7926 | train_loss_epoch=0.7926 | train_loss_step=0.5959
# [Epoch 108]  Val RMSE (DynFM, EMA) = 1.2718
# [progress] epoch 110/2000 | train_loss=0.7745 | train_loss_epoch=0.7745 | train_loss_step=0.6817 | val_rmse_ema=1.2718
# [Epoch 109]  Val RMSE (DynFM, EMA) = 1.2693
# [progress] epoch 111/2000 | train_loss=0.7695 | train_loss_epoch=0.7695 | train_loss_step=0.7862 | val_rmse_ema=1.2693
# [Epoch 110]  Val RMSE (DynFM, EMA) = 1.2975
# [progress] epoch 112/2000 | train_loss=0.7627 | train_loss_epoch=0.7627 | train_loss_step=0.8579 | val_rmse_ema=1.2975
# [Epoch 111]  Val RMSE (DynFM, EMA) = 1.2875
# [progress] epoch 113/2000 | train_loss=0.7634 | train_loss_epoch=0.7634 | train_loss_step=0.8136 | val_rmse_ema=1.2875
# [Epoch 112]  Val RMSE (DynFM, EMA) = 1.2819
# [progress] epoch 114/2000 | train_loss=0.7865 | train_loss_epoch=0.7865 | train_loss_step=0.6501 | val_rmse_ema=1.2819
# [Epoch 113]  Val RMSE (DynFM, EMA) = 1.2803
# [progress] epoch 115/2000 | train_loss=0.7983 | train_loss_epoch=0.7983 | train_loss_step=0.7423 | val_rmse_ema=1.2803
# [Epoch 114]  Val RMSE (DynFM, EMA) = 1.2590
# [progress] epoch 116/2000 | train_loss=0.7934 | train_loss_epoch=0.7934 | train_loss_step=0.7835 | val_rmse_ema=1.2590
# [Epoch 115]  Val RMSE (DynFM, EMA) = 1.2550
# [progress] epoch 117/2000 | train_loss=0.7828 | train_loss_epoch=0.7828 | train_loss_step=0.7260 | val_rmse_ema=1.2550
# [Epoch 116]  Val RMSE (DynFM, EMA) = 1.2575
# [progress] epoch 118/2000 | train_loss=0.7612 | train_loss_epoch=0.7612 | train_loss_step=0.8511 | val_rmse_ema=1.2575
# [Epoch 117]  Val RMSE (DynFM, EMA) = 1.2753
# [progress] epoch 119/2000 | train_loss=0.7868 | train_loss_epoch=0.7868 | train_loss_step=0.7336 | val_rmse_ema=1.2753
# [Epoch 118]  Val RMSE (DynFM, EMA) = 1.2725
# [progress] epoch 120/2000 | train_loss=0.7766 | train_loss_epoch=0.7766 | train_loss_step=0.9019 | val_rmse_ema=1.2725
# [Epoch 119]  Val RMSE (DynFM, EMA) = 1.2564
# [progress] epoch 121/2000 | train_loss=0.7816 | train_loss_epoch=0.7816 | train_loss_step=0.7469 | val_rmse_ema=1.2564
# [Epoch 120]  Val RMSE (DynFM, EMA) = 1.2321
# [progress] epoch 122/2000 | train_loss=0.7860 | train_loss_epoch=0.7860 | train_loss_step=0.7729 | val_rmse_ema=1.2321
# [Epoch 121]  Val RMSE (DynFM, EMA) = 1.2664
# [progress] epoch 123/2000 | train_loss=0.7775 | train_loss_epoch=0.7775 | train_loss_step=0.9465 | val_rmse_ema=1.2664
# [Epoch 122]  Val RMSE (DynFM, EMA) = 1.2799
# [progress] epoch 124/2000 | train_loss=0.7754 | train_loss_epoch=0.7754 | train_loss_step=0.8698 | val_rmse_ema=1.2799
# [Epoch 123]  Val RMSE (DynFM, EMA) = 1.2789
# [progress] epoch 125/2000 | train_loss=0.7629 | train_loss_epoch=0.7629 | train_loss_step=0.6271 | val_rmse_ema=1.2789
# [Epoch 124]  Val RMSE (DynFM, EMA) = 1.2626
# [progress] epoch 126/2000 | train_loss=0.7710 | train_loss_epoch=0.7710 | train_loss_step=0.6483 | val_rmse_ema=1.2626
# [Epoch 125]  Val RMSE (DynFM, EMA) = 1.2482
# [progress] epoch 127/2000 | train_loss=0.7753 | train_loss_epoch=0.7753 | train_loss_step=0.7881 | val_rmse_ema=1.2482
# [Epoch 126]  Val RMSE (DynFM, EMA) = 1.2548
# [progress] epoch 128/2000 | train_loss=0.7888 | train_loss_epoch=0.7888 | train_loss_step=0.6656 | val_rmse_ema=1.2548
# [Epoch 127]  Val RMSE (DynFM, EMA) = 1.2499
# [progress] epoch 129/2000 | train_loss=0.7733 | train_loss_epoch=0.7733 | train_loss_step=0.7771 | val_rmse_ema=1.2499
# [Epoch 128]  Val RMSE (DynFM, EMA) = 1.2718
# [progress] epoch 130/2000 | train_loss=0.7767 | train_loss_epoch=0.7767 | train_loss_step=0.6976 | val_rmse_ema=1.2718
# [Epoch 129]  Val RMSE (DynFM, EMA) = 1.2572
# [progress] epoch 131/2000 | train_loss=0.7560 | train_loss_epoch=0.7560 | train_loss_step=0.6978 | val_rmse_ema=1.2572
# [Epoch 130]  Val RMSE (DynFM, EMA) = 1.2726
# [progress] epoch 132/2000 | train_loss=0.7748 | train_loss_epoch=0.7748 | train_loss_step=0.6547 | val_rmse_ema=1.2726
# [Epoch 131]  Val RMSE (DynFM, EMA) = 1.2400
# [progress] epoch 133/2000 | train_loss=0.7721 | train_loss_epoch=0.7721 | train_loss_step=0.7359 | val_rmse_ema=1.2400
# [Epoch 132]  Val RMSE (DynFM, EMA) = 1.2546
# [progress] epoch 134/2000 | train_loss=0.7691 | train_loss_epoch=0.7691 | train_loss_step=1.0151 | val_rmse_ema=1.2546
# [Epoch 133]  Val RMSE (DynFM, EMA) = 1.2566
# [progress] epoch 135/2000 | train_loss=0.7713 | train_loss_epoch=0.7713 | train_loss_step=0.7903 | val_rmse_ema=1.2566
# [Epoch 134]  Val RMSE (DynFM, EMA) = 1.2787
# [progress] epoch 136/2000 | train_loss=0.7788 | train_loss_epoch=0.7788 | train_loss_step=1.0663 | val_rmse_ema=1.2787
# [Epoch 135]  Val RMSE (DynFM, EMA) = 1.2337
# [progress] epoch 137/2000 | train_loss=0.7688 | train_loss_epoch=0.7688 | train_loss_step=0.6207 | val_rmse_ema=1.2337
# [Epoch 136]  Val RMSE (DynFM, EMA) = 1.2490
# [progress] epoch 138/2000 | train_loss=0.7659 | train_loss_epoch=0.7659 | train_loss_step=0.6459 | val_rmse_ema=1.2490
# [Epoch 137]  Val RMSE (DynFM, EMA) = 1.2057
# [progress] epoch 139/2000 | train_loss=0.7596 | train_loss_epoch=0.7596 | train_loss_step=0.9731 | val_rmse_ema=1.2057
# [Epoch 138]  Val RMSE (DynFM, EMA) = 1.2121
# [progress] epoch 140/2000 | train_loss=0.7768 | train_loss_epoch=0.7768 | train_loss_step=0.6767 | val_rmse_ema=1.2121
# [Epoch 139]  Val RMSE (DynFM, EMA) = 1.2169
# [progress] epoch 141/2000 | train_loss=0.7656 | train_loss_epoch=0.7656 | train_loss_step=0.6121 | val_rmse_ema=1.2169
# [Epoch 140]  Val RMSE (DynFM, EMA) = 1.2376
# [progress] epoch 142/2000 | train_loss=0.7566 | train_loss_epoch=0.7566 | train_loss_step=0.6573 | val_rmse_ema=1.2376
# [Epoch 141]  Val RMSE (DynFM, EMA) = 1.2606
# [progress] epoch 143/2000 | train_loss=0.7626 | train_loss_epoch=0.7626 | train_loss_step=0.6910 | val_rmse_ema=1.2606
# [Epoch 142]  Val RMSE (DynFM, EMA) = 1.2525
# [progress] epoch 144/2000 | train_loss=0.7429 | train_loss_epoch=0.7429 | train_loss_step=0.6044 | val_rmse_ema=1.2525
# [Epoch 143]  Val RMSE (DynFM, EMA) = 1.2600
# [progress] epoch 145/2000 | train_loss=0.7454 | train_loss_epoch=0.7454 | train_loss_step=0.6362 | val_rmse_ema=1.2600
# [Epoch 144]  Val RMSE (DynFM, EMA) = 1.2608
# [progress] epoch 146/2000 | train_loss=0.7489 | train_loss_epoch=0.7489 | train_loss_step=0.7730 | val_rmse_ema=1.2608
# [Epoch 145]  Val RMSE (DynFM, EMA) = 1.2547
# [progress] epoch 147/2000 | train_loss=0.7752 | train_loss_epoch=0.7752 | train_loss_step=0.9121 | val_rmse_ema=1.2547
# [Epoch 146]  Val RMSE (DynFM, EMA) = 1.2589
# [progress] epoch 148/2000 | train_loss=0.7391 | train_loss_epoch=0.7391 | train_loss_step=0.8215 | val_rmse_ema=1.2589
# [Epoch 147]  Val RMSE (DynFM, EMA) = 1.2247
# [progress] epoch 149/2000 | train_loss=0.7507 | train_loss_epoch=0.7507 | train_loss_step=0.6388 | val_rmse_ema=1.2247
# [Epoch 148]  Val RMSE (DynFM, EMA) = 1.2482
# [progress] epoch 150/2000 | train_loss=0.7492 | train_loss_epoch=0.7492 | train_loss_step=1.0270 | val_rmse_ema=1.2482
# [Epoch 149]  Val RMSE (DynFM, EMA) = 1.2319
# [progress] epoch 151/2000 | train_loss=0.7825 | train_loss_epoch=0.7825 | train_loss_step=0.9638 | val_rmse_ema=1.2319
# [Epoch 150]  Val RMSE (DynFM, EMA) = 1.2446
# [progress] epoch 152/2000 | train_loss=0.7651 | train_loss_epoch=0.7651 | train_loss_step=0.6543 | val_rmse_ema=1.2446
# [Epoch 151]  Val RMSE (DynFM, EMA) = 1.2872
# [progress] epoch 153/2000 | train_loss=0.7573 | train_loss_epoch=0.7573 | train_loss_step=0.5994 | val_rmse_ema=1.2872
# [Epoch 152]  Val RMSE (DynFM, EMA) = 1.2876
# [progress] epoch 154/2000 | train_loss=0.7463 | train_loss_epoch=0.7463 | train_loss_step=0.9222 | val_rmse_ema=1.2876
# [Epoch 153]  Val RMSE (DynFM, EMA) = 1.2810
# [progress] epoch 155/2000 | train_loss=0.7524 | train_loss_epoch=0.7524 | train_loss_step=0.9738 | val_rmse_ema=1.2810
# [Epoch 154]  Val RMSE (DynFM, EMA) = 1.2510
# [progress] epoch 156/2000 | train_loss=0.7594 | train_loss_epoch=0.7594 | train_loss_step=0.6363 | val_rmse_ema=1.2510
# [Epoch 155]  Val RMSE (DynFM, EMA) = 1.2911
# [progress] epoch 157/2000 | train_loss=0.7326 | train_loss_epoch=0.7326 | train_loss_step=0.6276 | val_rmse_ema=1.2911
# [Epoch 156]  Val RMSE (DynFM, EMA) = 1.3065
# [progress] epoch 158/2000 | train_loss=0.7650 | train_loss_epoch=0.7650 | train_loss_step=0.6269 | val_rmse_ema=1.3065
# [Epoch 157]  Val RMSE (DynFM, EMA) = 1.2699
# [progress] epoch 159/2000 | train_loss=0.7832 | train_loss_epoch=0.7832 | train_loss_step=0.7178 | val_rmse_ema=1.2699
# [Epoch 158]  Val RMSE (DynFM, EMA) = 1.2773
# [progress] epoch 160/2000 | train_loss=0.7580 | train_loss_epoch=0.7580 | train_loss_step=0.7989 | val_rmse_ema=1.2773
# [Epoch 159]  Val RMSE (DynFM, EMA) = 1.2705
# [progress] epoch 161/2000 | train_loss=0.7585 | train_loss_epoch=0.7585 | train_loss_step=0.7070 | val_rmse_ema=1.2705
# [Epoch 160]  Val RMSE (DynFM, EMA) = 1.2941
# [progress] epoch 162/2000 | train_loss=0.7394 | train_loss_epoch=0.7394 | train_loss_step=0.5924 | val_rmse_ema=1.2941
# [Epoch 161]  Val RMSE (DynFM, EMA) = 1.2832
# [progress] epoch 163/2000 | train_loss=0.7515 | train_loss_epoch=0.7515 | train_loss_step=0.8809 | val_rmse_ema=1.2832
# [Epoch 162]  Val RMSE (DynFM, EMA) = 1.2746
# [progress] epoch 164/2000 | train_loss=0.7488 | train_loss_epoch=0.7488 | train_loss_step=0.8731 | val_rmse_ema=1.2746
# [Epoch 163]  Val RMSE (DynFM, EMA) = 1.2664
# [progress] epoch 165/2000 | train_loss=0.7443 | train_loss_epoch=0.7443 | train_loss_step=0.5886 | val_rmse_ema=1.2664
# [Epoch 164]  Val RMSE (DynFM, EMA) = 1.2501
# [progress] epoch 166/2000 | train_loss=0.7506 | train_loss_epoch=0.7506 | train_loss_step=0.8193 | val_rmse_ema=1.2501
# [Epoch 165]  Val RMSE (DynFM, EMA) = 1.2414
# [progress] epoch 167/2000 | train_loss=0.7537 | train_loss_epoch=0.7537 | train_loss_step=0.7047 | val_rmse_ema=1.2414
# [Epoch 166]  Val RMSE (DynFM, EMA) = 1.2612
# [progress] epoch 168/2000 | train_loss=0.7457 | train_loss_epoch=0.7457 | train_loss_step=0.7856 | val_rmse_ema=1.2612
# [Epoch 167]  Val RMSE (DynFM, EMA) = 1.2461
# [progress] epoch 169/2000 | train_loss=0.7334 | train_loss_epoch=0.7334 | train_loss_step=0.6605 | val_rmse_ema=1.2461
# [Epoch 168]  Val RMSE (DynFM, EMA) = 1.2559
# [progress] epoch 170/2000 | train_loss=0.7517 | train_loss_epoch=0.7517 | train_loss_step=0.8629 | val_rmse_ema=1.2559
# [Epoch 169]  Val RMSE (DynFM, EMA) = 1.2498
# [progress] epoch 171/2000 | train_loss=0.7443 | train_loss_epoch=0.7443 | train_loss_step=0.6448 | val_rmse_ema=1.2498
# [Epoch 170]  Val RMSE (DynFM, EMA) = 1.2519
# [progress] epoch 172/2000 | train_loss=0.7575 | train_loss_epoch=0.7575 | train_loss_step=0.7526 | val_rmse_ema=1.2519
# [Epoch 171]  Val RMSE (DynFM, EMA) = 1.3172
# [progress] epoch 173/2000 | train_loss=0.7395 | train_loss_epoch=0.7395 | train_loss_step=0.8950 | val_rmse_ema=1.3172
# [Epoch 172]  Val RMSE (DynFM, EMA) = 1.2886
# [progress] epoch 174/2000 | train_loss=0.7633 | train_loss_epoch=0.7633 | train_loss_step=0.8749 | val_rmse_ema=1.2886
# [Epoch 173]  Val RMSE (DynFM, EMA) = 1.2823
# [progress] epoch 175/2000 | train_loss=0.7434 | train_loss_epoch=0.7434 | train_loss_step=0.7369 | val_rmse_ema=1.2823
# [Epoch 174]  Val RMSE (DynFM, EMA) = 1.2953
# [progress] epoch 176/2000 | train_loss=0.7308 | train_loss_epoch=0.7308 | train_loss_step=0.7060 | val_rmse_ema=1.2953
# [Epoch 175]  Val RMSE (DynFM, EMA) = 1.2842
# [progress] epoch 177/2000 | train_loss=0.7290 | train_loss_epoch=0.7290 | train_loss_step=0.6142 | val_rmse_ema=1.2842
# [Epoch 176]  Val RMSE (DynFM, EMA) = 1.2697
# [progress] epoch 178/2000 | train_loss=0.7382 | train_loss_epoch=0.7382 | train_loss_step=0.7521 | val_rmse_ema=1.2697
# [Epoch 177]  Val RMSE (DynFM, EMA) = 1.2587
# [progress] epoch 179/2000 | train_loss=0.7295 | train_loss_epoch=0.7295 | train_loss_step=0.6082 | val_rmse_ema=1.2587
# [Epoch 178]  Val RMSE (DynFM, EMA) = 1.2848
# [progress] epoch 180/2000 | train_loss=0.7386 | train_loss_epoch=0.7386 | train_loss_step=0.6058 | val_rmse_ema=1.2848
# [Epoch 179]  Val RMSE (DynFM, EMA) = 1.3028
# [progress] epoch 181/2000 | train_loss=0.7225 | train_loss_epoch=0.7225 | train_loss_step=0.6006 | val_rmse_ema=1.3028
# [Epoch 180]  Val RMSE (DynFM, EMA) = 1.3032
# [progress] epoch 182/2000 | train_loss=0.7339 | train_loss_epoch=0.7339 | train_loss_step=0.6636 | val_rmse_ema=1.3032
# [Epoch 181]  Val RMSE (DynFM, EMA) = 1.3338
# [progress] epoch 183/2000 | train_loss=0.7309 | train_loss_epoch=0.7309 | train_loss_step=0.8366 | val_rmse_ema=1.3338
# [Epoch 182]  Val RMSE (DynFM, EMA) = 1.3053
# [progress] epoch 184/2000 | train_loss=0.7178 | train_loss_epoch=0.7178 | train_loss_step=0.6239 | val_rmse_ema=1.3053
# [Epoch 183]  Val RMSE (DynFM, EMA) = 1.3139
# [progress] epoch 185/2000 | train_loss=0.7198 | train_loss_epoch=0.7198 | train_loss_step=0.6271 | val_rmse_ema=1.3139
# [Epoch 184]  Val RMSE (DynFM, EMA) = 1.3059
# [progress] epoch 186/2000 | train_loss=0.7205 | train_loss_epoch=0.7205 | train_loss_step=0.6602 | val_rmse_ema=1.3059
# [Epoch 185]  Val RMSE (DynFM, EMA) = 1.2740
# [progress] epoch 187/2000 | train_loss=0.7310 | train_loss_epoch=0.7310 | train_loss_step=0.5987 | val_rmse_ema=1.2740
# [Epoch 186]  Val RMSE (DynFM, EMA) = 1.2986
# [progress] epoch 188/2000 | train_loss=0.7452 | train_loss_epoch=0.7452 | train_loss_step=0.6811 | val_rmse_ema=1.2986
# [Epoch 187]  Val RMSE (DynFM, EMA) = 1.2612
# [progress] epoch 189/2000 | train_loss=0.7136 | train_loss_epoch=0.7136 | train_loss_step=0.6676 | val_rmse_ema=1.2612
# [Epoch 188]  Val RMSE (DynFM, EMA) = 1.2989
# [progress] epoch 190/2000 | train_loss=0.7218 | train_loss_epoch=0.7218 | train_loss_step=0.5410 | val_rmse_ema=1.2989
# [Epoch 189]  Val RMSE (DynFM, EMA) = 1.2933
# [progress] epoch 191/2000 | train_loss=0.7354 | train_loss_epoch=0.7354 | train_loss_step=0.8472 | val_rmse_ema=1.2933
# [Epoch 190]  Val RMSE (DynFM, EMA) = 1.2884
# [progress] epoch 192/2000 | train_loss=0.7221 | train_loss_epoch=0.7221 | train_loss_step=0.9679 | val_rmse_ema=1.2884
# [Epoch 191]  Val RMSE (DynFM, EMA) = 1.3243
# [progress] epoch 193/2000 | train_loss=0.7114 | train_loss_epoch=0.7114 | train_loss_step=0.8598 | val_rmse_ema=1.3243
# [Epoch 192]  Val RMSE (DynFM, EMA) = 1.3083
# [progress] epoch 194/2000 | train_loss=0.7111 | train_loss_epoch=0.7111 | train_loss_step=0.8437 | val_rmse_ema=1.3083
# [Epoch 193]  Val RMSE (DynFM, EMA) = 1.2639
# [progress] epoch 195/2000 | train_loss=0.7045 | train_loss_epoch=0.7045 | train_loss_step=0.8616 | val_rmse_ema=1.2639
# [Epoch 194]  Val RMSE (DynFM, EMA) = 1.2577
# [progress] epoch 196/2000 | train_loss=0.7012 | train_loss_epoch=0.7012 | train_loss_step=0.8992 | val_rmse_ema=1.2577
# [Epoch 195]  Val RMSE (DynFM, EMA) = 1.2379
# [progress] epoch 197/2000 | train_loss=0.7069 | train_loss_epoch=0.7069 | train_loss_step=0.7091 | val_rmse_ema=1.2379
# [Epoch 196]  Val RMSE (DynFM, EMA) = 1.2519
# [progress] epoch 198/2000 | train_loss=0.7142 | train_loss_epoch=0.7142 | train_loss_step=0.6468 | val_rmse_ema=1.2519
# [Epoch 197]  Val RMSE (DynFM, EMA) = 1.2284
# [progress] epoch 199/2000 | train_loss=0.6951 | train_loss_epoch=0.6951 | train_loss_step=0.9823 | val_rmse_ema=1.2284
# [Epoch 198]  Val RMSE (DynFM, EMA) = 1.2410
# [progress] epoch 200/2000 | train_loss=0.6836 | train_loss_epoch=0.6836 | train_loss_step=0.6908 | val_rmse_ema=1.2410
# [Epoch 199]  Val RMSE (DynFM, EMA) = 1.2276
# [progress] epoch 201/2000 | train_loss=0.6846 | train_loss_epoch=0.6846 | train_loss_step=0.5926 | val_rmse_ema=1.2276
# [Epoch 200]  Val RMSE (DynFM, EMA) = 1.1948
# [progress] epoch 202/2000 | train_loss=0.7188 | train_loss_epoch=0.7188 | train_loss_step=0.8612 | val_rmse_ema=1.1948
# [Epoch 201]  Val RMSE (DynFM, EMA) = 1.2404
# [progress] epoch 203/2000 | train_loss=0.6779 | train_loss_epoch=0.6779 | train_loss_step=0.5482 | val_rmse_ema=1.2404
# [Epoch 202]  Val RMSE (DynFM, EMA) = 1.2794
# [progress] epoch 204/2000 | train_loss=0.6892 | train_loss_epoch=0.6892 | train_loss_step=0.6230 | val_rmse_ema=1.2794
# [Epoch 203]  Val RMSE (DynFM, EMA) = 1.2824
# [progress] epoch 205/2000 | train_loss=0.6774 | train_loss_epoch=0.6774 | train_loss_step=0.6358 | val_rmse_ema=1.2824
# [Epoch 204]  Val RMSE (DynFM, EMA) = 1.2877
# [progress] epoch 206/2000 | train_loss=0.6992 | train_loss_epoch=0.6992 | train_loss_step=0.5695 | val_rmse_ema=1.2877
# [Epoch 205]  Val RMSE (DynFM, EMA) = 1.2945
# [progress] epoch 207/2000 | train_loss=0.7030 | train_loss_epoch=0.7030 | train_loss_step=1.0267 | val_rmse_ema=1.2945
# [Epoch 206]  Val RMSE (DynFM, EMA) = 1.2545
# [progress] epoch 208/2000 | train_loss=0.6925 | train_loss_epoch=0.6925 | train_loss_step=0.6368 | val_rmse_ema=1.2545
# [Epoch 207]  Val RMSE (DynFM, EMA) = 1.2866
# [progress] epoch 209/2000 | train_loss=0.7133 | train_loss_epoch=0.7133 | train_loss_step=0.6542 | val_rmse_ema=1.2866
# [Epoch 208]  Val RMSE (DynFM, EMA) = 1.2953
# [progress] epoch 210/2000 | train_loss=0.7092 | train_loss_epoch=0.7092 | train_loss_step=0.5198 | val_rmse_ema=1.2953
# [Epoch 209]  Val RMSE (DynFM, EMA) = 1.2624
# [progress] epoch 211/2000 | train_loss=0.6825 | train_loss_epoch=0.6825 | train_loss_step=0.8734 | val_rmse_ema=1.2624
# [Epoch 210]  Val RMSE (DynFM, EMA) = 1.2896
# [progress] epoch 212/2000 | train_loss=0.6813 | train_loss_epoch=0.6813 | train_loss_step=0.9659 | val_rmse_ema=1.2896
# [Epoch 211]  Val RMSE (DynFM, EMA) = 1.2837
# [progress] epoch 213/2000 | train_loss=0.6918 | train_loss_epoch=0.6918 | train_loss_step=0.6276 | val_rmse_ema=1.2837
# [Epoch 212]  Val RMSE (DynFM, EMA) = 1.3056
# [progress] epoch 214/2000 | train_loss=0.6856 | train_loss_epoch=0.6856 | train_loss_step=0.5559 | val_rmse_ema=1.3056
# [Epoch 213]  Val RMSE (DynFM, EMA) = 1.3070
# [progress] epoch 215/2000 | train_loss=0.6599 | train_loss_epoch=0.6599 | train_loss_step=0.4753 | val_rmse_ema=1.3070
# [Epoch 214]  Val RMSE (DynFM, EMA) = 1.3247
# [progress] epoch 216/2000 | train_loss=0.6708 | train_loss_epoch=0.6708 | train_loss_step=0.8780 | val_rmse_ema=1.3247
# [Epoch 215]  Val RMSE (DynFM, EMA) = 1.2812
# [progress] epoch 217/2000 | train_loss=0.6667 | train_loss_epoch=0.6667 | train_loss_step=0.9263 | val_rmse_ema=1.2812
# [Epoch 216]  Val RMSE (DynFM, EMA) = 1.3054
# [progress] epoch 218/2000 | train_loss=0.6595 | train_loss_epoch=0.6595 | train_loss_step=0.5410 | val_rmse_ema=1.3054
# [Epoch 217]  Val RMSE (DynFM, EMA) = 1.2685
# [progress] epoch 219/2000 | train_loss=0.6668 | train_loss_epoch=0.6668 | train_loss_step=0.5580 | val_rmse_ema=1.2685
# [Epoch 218]  Val RMSE (DynFM, EMA) = 1.2841
# [progress] epoch 220/2000 | train_loss=0.6635 | train_loss_epoch=0.6635 | train_loss_step=0.5336 | val_rmse_ema=1.2841
# [Epoch 219]  Val RMSE (DynFM, EMA) = 1.2443
# [progress] epoch 221/2000 | train_loss=0.6496 | train_loss_epoch=0.6496 | train_loss_step=0.5550 | val_rmse_ema=1.2443
# [Epoch 220]  Val RMSE (DynFM, EMA) = 1.2776
# [progress] epoch 222/2000 | train_loss=0.6638 | train_loss_epoch=0.6638 | train_loss_step=0.6355 | val_rmse_ema=1.2776
# [Epoch 221]  Val RMSE (DynFM, EMA) = 1.2397
# [progress] epoch 223/2000 | train_loss=0.6520 | train_loss_epoch=0.6520 | train_loss_step=0.4820 | val_rmse_ema=1.2397
# [Epoch 222]  Val RMSE (DynFM, EMA) = 1.2726
# [progress] epoch 224/2000 | train_loss=0.6693 | train_loss_epoch=0.6693 | train_loss_step=0.8480 | val_rmse_ema=1.2726
# [Epoch 223]  Val RMSE (DynFM, EMA) = 1.3127
# [progress] epoch 225/2000 | train_loss=0.6748 | train_loss_epoch=0.6748 | train_loss_step=0.4609 | val_rmse_ema=1.3127
# [Epoch 224]  Val RMSE (DynFM, EMA) = 1.2992
# [progress] epoch 226/2000 | train_loss=0.6546 | train_loss_epoch=0.6546 | train_loss_step=0.5652 | val_rmse_ema=1.2992
# [Epoch 225]  Val RMSE (DynFM, EMA) = 1.3250
# [progress] epoch 227/2000 | train_loss=0.6599 | train_loss_epoch=0.6599 | train_loss_step=0.6087 | val_rmse_ema=1.3250
# [Epoch 226]  Val RMSE (DynFM, EMA) = 1.3473
# [progress] epoch 228/2000 | train_loss=0.6250 | train_loss_epoch=0.6250 | train_loss_step=0.5391 | val_rmse_ema=1.3473
# [Epoch 227]  Val RMSE (DynFM, EMA) = 1.3523
# [progress] epoch 229/2000 | train_loss=0.6287 | train_loss_epoch=0.6287 | train_loss_step=0.6261 | val_rmse_ema=1.3523
# [Epoch 228]  Val RMSE (DynFM, EMA) = 1.3298
# [progress] epoch 230/2000 | train_loss=0.6327 | train_loss_epoch=0.6327 | train_loss_step=0.4895 | val_rmse_ema=1.3298
# [Epoch 229]  Val RMSE (DynFM, EMA) = 1.3121
# [progress] epoch 231/2000 | train_loss=0.6518 | train_loss_epoch=0.6518 | train_loss_step=0.7120 | val_rmse_ema=1.3121
# [Epoch 230]  Val RMSE (DynFM, EMA) = 1.3369
# [progress] epoch 232/2000 | train_loss=0.6485 | train_loss_epoch=0.6485 | train_loss_step=0.5343 | val_rmse_ema=1.3369
# [Epoch 231]  Val RMSE (DynFM, EMA) = 1.3067
# [progress] epoch 233/2000 | train_loss=0.6709 | train_loss_epoch=0.6709 | train_loss_step=0.8476 | val_rmse_ema=1.3067
# [Epoch 232]  Val RMSE (DynFM, EMA) = 1.2672
# [progress] epoch 234/2000 | train_loss=0.6186 | train_loss_epoch=0.6186 | train_loss_step=0.4457 | val_rmse_ema=1.2672
# [Epoch 233]  Val RMSE (DynFM, EMA) = 1.2907
# [progress] epoch 235/2000 | train_loss=0.6510 | train_loss_epoch=0.6510 | train_loss_step=0.5942 | val_rmse_ema=1.2907
# [Epoch 234]  Val RMSE (DynFM, EMA) = 1.3450
# [progress] epoch 236/2000 | train_loss=0.6687 | train_loss_epoch=0.6687 | train_loss_step=0.8134 | val_rmse_ema=1.3450
# [Epoch 235]  Val RMSE (DynFM, EMA) = 1.2866
# [progress] epoch 237/2000 | train_loss=0.6396 | train_loss_epoch=0.6396 | train_loss_step=0.5168 | val_rmse_ema=1.2866
# [Epoch 236]  Val RMSE (DynFM, EMA) = 1.3047
# [progress] epoch 238/2000 | train_loss=0.6349 | train_loss_epoch=0.6349 | train_loss_step=0.4441 | val_rmse_ema=1.3047
# [Epoch 237]  Val RMSE (DynFM, EMA) = 1.2792
# [progress] epoch 239/2000 | train_loss=0.6461 | train_loss_epoch=0.6461 | train_loss_step=0.5022 | val_rmse_ema=1.2792
# [Epoch 238]  Val RMSE (DynFM, EMA) = 1.2685
# [progress] epoch 240/2000 | train_loss=0.6373 | train_loss_epoch=0.6373 | train_loss_step=0.4222 | val_rmse_ema=1.2685
# [Epoch 239]  Val RMSE (DynFM, EMA) = 1.3099
# [progress] epoch 241/2000 | train_loss=0.6249 | train_loss_epoch=0.6249 | train_loss_step=0.4709 | val_rmse_ema=1.3099
# [Epoch 240]  Val RMSE (DynFM, EMA) = 1.3036
# [progress] epoch 242/2000 | train_loss=0.6250 | train_loss_epoch=0.6250 | train_loss_step=0.5287 | val_rmse_ema=1.3036
# [Epoch 241]  Val RMSE (DynFM, EMA) = 1.2925
# [progress] epoch 243/2000 | train_loss=0.6433 | train_loss_epoch=0.6433 | train_loss_step=0.6347 | val_rmse_ema=1.2925
# [Epoch 242]  Val RMSE (DynFM, EMA) = 1.2824
# [progress] epoch 244/2000 | train_loss=0.6487 | train_loss_epoch=0.6487 | train_loss_step=0.4733 | val_rmse_ema=1.2824
# [Epoch 243]  Val RMSE (DynFM, EMA) = 1.2929
# [progress] epoch 245/2000 | train_loss=0.6267 | train_loss_epoch=0.6267 | train_loss_step=0.4414 | val_rmse_ema=1.2929
# [Epoch 244]  Val RMSE (DynFM, EMA) = 1.2988
# [progress] epoch 246/2000 | train_loss=0.6187 | train_loss_epoch=0.6187 | train_loss_step=0.4703 | val_rmse_ema=1.2988
# [Epoch 245]  Val RMSE (DynFM, EMA) = 1.3231
# [progress] epoch 247/2000 | train_loss=0.6498 | train_loss_epoch=0.6498 | train_loss_step=0.4449 | val_rmse_ema=1.3231
# [Epoch 246]  Val RMSE (DynFM, EMA) = 1.2936
# [progress] epoch 248/2000 | train_loss=0.6057 | train_loss_epoch=0.6057 | train_loss_step=0.8605 | val_rmse_ema=1.2936
# [Epoch 247]  Val RMSE (DynFM, EMA) = 1.2522
# [progress] epoch 249/2000 | train_loss=0.6445 | train_loss_epoch=0.6445 | train_loss_step=0.8416 | val_rmse_ema=1.2522
# [Epoch 248]  Val RMSE (DynFM, EMA) = 1.2835
# [progress] epoch 250/2000 | train_loss=0.6184 | train_loss_epoch=0.6184 | train_loss_step=0.8611 | val_rmse_ema=1.2835
# [Epoch 249]  Val RMSE (DynFM, EMA) = 1.2970
# [progress] epoch 251/2000 | train_loss=0.6124 | train_loss_epoch=0.6124 | train_loss_step=0.4302 | val_rmse_ema=1.2970
# [Epoch 250]  Val RMSE (DynFM, EMA) = 1.3016
# [progress] epoch 252/2000 | train_loss=0.6116 | train_loss_epoch=0.6116 | train_loss_step=0.5541 | val_rmse_ema=1.3016
# [Epoch 251]  Val RMSE (DynFM, EMA) = 1.3086
# [progress] epoch 253/2000 | train_loss=0.6240 | train_loss_epoch=0.6240 | train_loss_step=0.5291 | val_rmse_ema=1.3086
# [Epoch 252]  Val RMSE (DynFM, EMA) = 1.3139
# [progress] epoch 254/2000 | train_loss=0.6015 | train_loss_epoch=0.6015 | train_loss_step=0.8671 | val_rmse_ema=1.3139
# [Epoch 253]  Val RMSE (DynFM, EMA) = 1.3304
# [progress] epoch 255/2000 | train_loss=0.5694 | train_loss_epoch=0.5694 | train_loss_step=0.4571 | val_rmse_ema=1.3304
# [Epoch 254]  Val RMSE (DynFM, EMA) = 1.3279
# [progress] epoch 256/2000 | train_loss=0.6022 | train_loss_epoch=0.6022 | train_loss_step=1.0302 | val_rmse_ema=1.3279
# [Epoch 255]  Val RMSE (DynFM, EMA) = 1.3384
# [progress] epoch 257/2000 | train_loss=0.5949 | train_loss_epoch=0.5949 | train_loss_step=0.5407 | val_rmse_ema=1.3384
# [Epoch 256]  Val RMSE (DynFM, EMA) = 1.3055
# [progress] epoch 258/2000 | train_loss=0.5921 | train_loss_epoch=0.5921 | train_loss_step=0.8974 | val_rmse_ema=1.3055
# [Epoch 257]  Val RMSE (DynFM, EMA) = 1.3116
# [progress] epoch 259/2000 | train_loss=0.6336 | train_loss_epoch=0.6336 | train_loss_step=0.8692 | val_rmse_ema=1.3116
# [Epoch 258]  Val RMSE (DynFM, EMA) = 1.2980
# [progress] epoch 260/2000 | train_loss=0.6112 | train_loss_epoch=0.6112 | train_loss_step=0.5229 | val_rmse_ema=1.2980
# [Epoch 259]  Val RMSE (DynFM, EMA) = 1.2957
# [progress] epoch 261/2000 | train_loss=0.6050 | train_loss_epoch=0.6050 | train_loss_step=0.8673 | val_rmse_ema=1.2957
# [Epoch 260]  Val RMSE (DynFM, EMA) = 1.3357
# [progress] epoch 262/2000 | train_loss=0.5791 | train_loss_epoch=0.5791 | train_loss_step=0.4623 | val_rmse_ema=1.3357
# [Epoch 261]  Val RMSE (DynFM, EMA) = 1.3116
# [progress] epoch 263/2000 | train_loss=0.5985 | train_loss_epoch=0.5985 | train_loss_step=0.4735 | val_rmse_ema=1.3116
# [Epoch 262]  Val RMSE (DynFM, EMA) = 1.3248
# [progress] epoch 264/2000 | train_loss=0.5944 | train_loss_epoch=0.5944 | train_loss_step=0.4832 | val_rmse_ema=1.3248
# [Epoch 263]  Val RMSE (DynFM, EMA) = 1.3412
# [progress] epoch 265/2000 | train_loss=0.5723 | train_loss_epoch=0.5723 | train_loss_step=0.4825 | val_rmse_ema=1.3412
# [Epoch 264]  Val RMSE (DynFM, EMA) = 1.3306
# [progress] epoch 266/2000 | train_loss=0.5688 | train_loss_epoch=0.5688 | train_loss_step=0.4345 | val_rmse_ema=1.3306
# [Epoch 265]  Val RMSE (DynFM, EMA) = 1.3824
# [progress] epoch 267/2000 | train_loss=0.5876 | train_loss_epoch=0.5876 | train_loss_step=0.4387 | val_rmse_ema=1.3824
# [Epoch 266]  Val RMSE (DynFM, EMA) = 1.3428
# [progress] epoch 268/2000 | train_loss=0.5681 | train_loss_epoch=0.5681 | train_loss_step=0.3591 | val_rmse_ema=1.3428
# [Epoch 267]  Val RMSE (DynFM, EMA) = 1.3432
# [progress] epoch 269/2000 | train_loss=0.5873 | train_loss_epoch=0.5873 | train_loss_step=0.9948 | val_rmse_ema=1.3432
# [Epoch 268]  Val RMSE (DynFM, EMA) = 1.3545
# [progress] epoch 270/2000 | train_loss=0.5777 | train_loss_epoch=0.5777 | train_loss_step=0.8954 | val_rmse_ema=1.3545
# [Epoch 269]  Val RMSE (DynFM, EMA) = 1.3480
# [progress] epoch 271/2000 | train_loss=0.5922 | train_loss_epoch=0.5922 | train_loss_step=0.4468 | val_rmse_ema=1.3480
# [Epoch 270]  Val RMSE (DynFM, EMA) = 1.3746
# [progress] epoch 272/2000 | train_loss=0.6012 | train_loss_epoch=0.6012 | train_loss_step=0.4118 | val_rmse_ema=1.3746
# [Epoch 271]  Val RMSE (DynFM, EMA) = 1.3724
# [progress] epoch 273/2000 | train_loss=0.5814 | train_loss_epoch=0.5814 | train_loss_step=0.8823 | val_rmse_ema=1.3724
# [Epoch 272]  Val RMSE (DynFM, EMA) = 1.3864
# [progress] epoch 274/2000 | train_loss=0.5900 | train_loss_epoch=0.5900 | train_loss_step=0.4688 | val_rmse_ema=1.3864
# [Epoch 273]  Val RMSE (DynFM, EMA) = 1.3711
# [progress] epoch 275/2000 | train_loss=0.5538 | train_loss_epoch=0.5538 | train_loss_step=0.4324 | val_rmse_ema=1.3711
# [Epoch 274]  Val RMSE (DynFM, EMA) = 1.3354
# [progress] epoch 276/2000 | train_loss=0.5907 | train_loss_epoch=0.5907 | train_loss_step=0.5066 | val_rmse_ema=1.3354
# [Epoch 275]  Val RMSE (DynFM, EMA) = 1.3860
# [progress] epoch 277/2000 | train_loss=0.5720 | train_loss_epoch=0.5720 | train_loss_step=0.4238 | val_rmse_ema=1.3860
# [Epoch 276]  Val RMSE (DynFM, EMA) = 1.3537
# [progress] epoch 278/2000 | train_loss=0.5624 | train_loss_epoch=0.5624 | train_loss_step=0.3409 | val_rmse_ema=1.3537
# [Epoch 277]  Val RMSE (DynFM, EMA) = 1.3717
# [progress] epoch 279/2000 | train_loss=0.5834 | train_loss_epoch=0.5834 | train_loss_step=0.5847 | val_rmse_ema=1.3717
# [Epoch 278]  Val RMSE (DynFM, EMA) = 1.3482
# [progress] epoch 280/2000 | train_loss=0.5669 | train_loss_epoch=0.5669 | train_loss_step=0.8677 | val_rmse_ema=1.3482
# [Epoch 279]  Val RMSE (DynFM, EMA) = 1.3618
# [progress] epoch 281/2000 | train_loss=0.5737 | train_loss_epoch=0.5737 | train_loss_step=0.8741 | val_rmse_ema=1.3618
# [Epoch 280]  Val RMSE (DynFM, EMA) = 1.3334
# [progress] epoch 282/2000 | train_loss=0.5493 | train_loss_epoch=0.5493 | train_loss_step=0.4475 | val_rmse_ema=1.3334
# [Epoch 281]  Val RMSE (DynFM, EMA) = 1.3360
# [progress] epoch 283/2000 | train_loss=0.5632 | train_loss_epoch=0.5632 | train_loss_step=0.4563 | val_rmse_ema=1.3360
# [Epoch 282]  Val RMSE (DynFM, EMA) = 1.3624
# [progress] epoch 284/2000 | train_loss=0.5843 | train_loss_epoch=0.5843 | train_loss_step=0.4417 | val_rmse_ema=1.3624
# [Epoch 283]  Val RMSE (DynFM, EMA) = 1.3166
# [progress] epoch 285/2000 | train_loss=0.5724 | train_loss_epoch=0.5724 | train_loss_step=0.4635 | val_rmse_ema=1.3166
# [Epoch 284]  Val RMSE (DynFM, EMA) = 1.3454
# [progress] epoch 286/2000 | train_loss=0.5854 | train_loss_epoch=0.5854 | train_loss_step=0.4216 | val_rmse_ema=1.3454
# [Epoch 285]  Val RMSE (DynFM, EMA) = 1.3471
# [progress] epoch 287/2000 | train_loss=0.5587 | train_loss_epoch=0.5587 | train_loss_step=0.4494 | val_rmse_ema=1.3471
# [Epoch 286]  Val RMSE (DynFM, EMA) = 1.3342
# [progress] epoch 288/2000 | train_loss=0.5631 | train_loss_epoch=0.5631 | train_loss_step=0.3649 | val_rmse_ema=1.3342
# [Epoch 287]  Val RMSE (DynFM, EMA) = 1.3358
# [progress] epoch 289/2000 | train_loss=0.5711 | train_loss_epoch=0.5711 | train_loss_step=0.4107 | val_rmse_ema=1.3358
# [Epoch 288]  Val RMSE (DynFM, EMA) = 1.3547
# [progress] epoch 290/2000 | train_loss=0.5734 | train_loss_epoch=0.5734 | train_loss_step=0.4327 | val_rmse_ema=1.3547
# [Epoch 289]  Val RMSE (DynFM, EMA) = 1.3485
# [progress] epoch 291/2000 | train_loss=0.5532 | train_loss_epoch=0.5532 | train_loss_step=0.9009 | val_rmse_ema=1.3485
# [Epoch 290]  Val RMSE (DynFM, EMA) = 1.3306
# [progress] epoch 292/2000 | train_loss=0.5632 | train_loss_epoch=0.5632 | train_loss_step=0.5056 | val_rmse_ema=1.3306
# [Epoch 291]  Val RMSE (DynFM, EMA) = 1.3034
# [progress] epoch 293/2000 | train_loss=0.5773 | train_loss_epoch=0.5773 | train_loss_step=0.4747 | val_rmse_ema=1.3034
# [Epoch 292]  Val RMSE (DynFM, EMA) = 1.3011
# [progress] epoch 294/2000 | train_loss=0.5471 | train_loss_epoch=0.5471 | train_loss_step=0.3705 | val_rmse_ema=1.3011
# [Epoch 293]  Val RMSE (DynFM, EMA) = 1.3260
# [progress] epoch 295/2000 | train_loss=0.5575 | train_loss_epoch=0.5575 | train_loss_step=0.3619 | val_rmse_ema=1.3260
# [Epoch 294]  Val RMSE (DynFM, EMA) = 1.3194
# [progress] epoch 296/2000 | train_loss=0.5811 | train_loss_epoch=0.5811 | train_loss_step=0.3648 | val_rmse_ema=1.3194
# [Epoch 295]  Val RMSE (DynFM, EMA) = 1.2952
# [progress] epoch 297/2000 | train_loss=0.5440 | train_loss_epoch=0.5440 | train_loss_step=0.3872 | val_rmse_ema=1.2952
# [Epoch 296]  Val RMSE (DynFM, EMA) = 1.3122
# [progress] epoch 298/2000 | train_loss=0.5554 | train_loss_epoch=0.5554 | train_loss_step=0.9733 | val_rmse_ema=1.3122
# [Epoch 297]  Val RMSE (DynFM, EMA) = 1.3067
# [progress] epoch 299/2000 | train_loss=0.5387 | train_loss_epoch=0.5387 | train_loss_step=0.4047 | val_rmse_ema=1.3067
# [Epoch 298]  Val RMSE (DynFM, EMA) = 1.3281
# [progress] epoch 300/2000 | train_loss=0.5554 | train_loss_epoch=0.5554 | train_loss_step=0.4164 | val_rmse_ema=1.3281
# [Epoch 299]  Val RMSE (DynFM, EMA) = 1.3216
# [progress] epoch 301/2000 | train_loss=0.5510 | train_loss_epoch=0.5510 | train_loss_step=0.3801 | val_rmse_ema=1.3216
# [Epoch 300]  Val RMSE (DynFM, EMA) = 1.3323
# [progress] epoch 302/2000 | train_loss=0.5360 | train_loss_epoch=0.5360 | train_loss_step=0.3995 | val_rmse_ema=1.3323
# [Epoch 301]  Val RMSE (DynFM, EMA) = 1.3374
# [progress] epoch 303/2000 | train_loss=0.5456 | train_loss_epoch=0.5456 | train_loss_step=0.8786 | val_rmse_ema=1.3374
# [Epoch 302]  Val RMSE (DynFM, EMA) = 1.3494
# [progress] epoch 304/2000 | train_loss=0.5357 | train_loss_epoch=0.5357 | train_loss_step=0.4169 | val_rmse_ema=1.3494
# [Epoch 303]  Val RMSE (DynFM, EMA) = 1.3264
# [progress] epoch 305/2000 | train_loss=0.5421 | train_loss_epoch=0.5421 | train_loss_step=0.9276 | val_rmse_ema=1.3264
# [Epoch 304]  Val RMSE (DynFM, EMA) = 1.3142
# [progress] epoch 306/2000 | train_loss=0.5263 | train_loss_epoch=0.5263 | train_loss_step=0.4380 | val_rmse_ema=1.3142
# [Epoch 305]  Val RMSE (DynFM, EMA) = 1.3229
# [progress] epoch 307/2000 | train_loss=0.5659 | train_loss_epoch=0.5659 | train_loss_step=0.4606 | val_rmse_ema=1.3229
# [Epoch 306]  Val RMSE (DynFM, EMA) = 1.3382
# [progress] epoch 308/2000 | train_loss=0.5808 | train_loss_epoch=0.5808 | train_loss_step=0.3765 | val_rmse_ema=1.3382
# [Epoch 307]  Val RMSE (DynFM, EMA) = 1.2892
# [progress] epoch 309/2000 | train_loss=0.5543 | train_loss_epoch=0.5543 | train_loss_step=0.3755 | val_rmse_ema=1.2892
# [Epoch 308]  Val RMSE (DynFM, EMA) = 1.3262
# [progress] epoch 310/2000 | train_loss=0.5282 | train_loss_epoch=0.5282 | train_loss_step=0.3500 | val_rmse_ema=1.3262
# [Epoch 309]  Val RMSE (DynFM, EMA) = 1.3469
# [progress] epoch 311/2000 | train_loss=0.5455 | train_loss_epoch=0.5455 | train_loss_step=0.9490 | val_rmse_ema=1.3469
# [Epoch 310]  Val RMSE (DynFM, EMA) = 1.3155
# [progress] epoch 312/2000 | train_loss=0.5214 | train_loss_epoch=0.5214 | train_loss_step=0.4161 | val_rmse_ema=1.3155
# [Epoch 311]  Val RMSE (DynFM, EMA) = 1.3082
# [progress] epoch 313/2000 | train_loss=0.5187 | train_loss_epoch=0.5187 | train_loss_step=0.8332 | val_rmse_ema=1.3082
# [Epoch 312]  Val RMSE (DynFM, EMA) = 1.2948
# [progress] epoch 314/2000 | train_loss=0.5182 | train_loss_epoch=0.5182 | train_loss_step=0.3326 | val_rmse_ema=1.2948
# [Epoch 313]  Val RMSE (DynFM, EMA) = 1.2970
# [progress] epoch 315/2000 | train_loss=0.5505 | train_loss_epoch=0.5505 | train_loss_step=0.3642 | val_rmse_ema=1.2970
# [Epoch 314]  Val RMSE (DynFM, EMA) = 1.3173
# [progress] epoch 316/2000 | train_loss=0.5423 | train_loss_epoch=0.5423 | train_loss_step=0.9879 | val_rmse_ema=1.3173
# [Epoch 315]  Val RMSE (DynFM, EMA) = 1.2843
# [progress] epoch 317/2000 | train_loss=0.5266 | train_loss_epoch=0.5266 | train_loss_step=0.3297 | val_rmse_ema=1.2843
# [Epoch 316]  Val RMSE (DynFM, EMA) = 1.3222
# [progress] epoch 318/2000 | train_loss=0.5038 | train_loss_epoch=0.5038 | train_loss_step=0.3524 | val_rmse_ema=1.3222
# [Epoch 317]  Val RMSE (DynFM, EMA) = 1.2940
# [progress] epoch 319/2000 | train_loss=0.5306 | train_loss_epoch=0.5306 | train_loss_step=0.3856 | val_rmse_ema=1.2940
# [Epoch 318]  Val RMSE (DynFM, EMA) = 1.3059
# [progress] epoch 320/2000 | train_loss=0.5503 | train_loss_epoch=0.5503 | train_loss_step=0.8620 | val_rmse_ema=1.3059
# [Epoch 319]  Val RMSE (DynFM, EMA) = 1.3687
# [progress] epoch 321/2000 | train_loss=0.5282 | train_loss_epoch=0.5282 | train_loss_step=0.3386 | val_rmse_ema=1.3687
# [Epoch 320]  Val RMSE (DynFM, EMA) = 1.3736
# [progress] epoch 322/2000 | train_loss=0.5313 | train_loss_epoch=0.5313 | train_loss_step=0.8225 | val_rmse_ema=1.3736
# [Epoch 321]  Val RMSE (DynFM, EMA) = 1.3539
# [progress] epoch 323/2000 | train_loss=0.5141 | train_loss_epoch=0.5141 | train_loss_step=0.3456 | val_rmse_ema=1.3539
# [Epoch 322]  Val RMSE (DynFM, EMA) = 1.3511
# [progress] epoch 324/2000 | train_loss=0.5327 | train_loss_epoch=0.5327 | train_loss_step=0.2716 | val_rmse_ema=1.3511
# [Epoch 323]  Val RMSE (DynFM, EMA) = 1.3639
# [progress] epoch 325/2000 | train_loss=0.5072 | train_loss_epoch=0.5072 | train_loss_step=0.3305 | val_rmse_ema=1.3639
# [Epoch 324]  Val RMSE (DynFM, EMA) = 1.3699
# [progress] epoch 326/2000 | train_loss=0.5249 | train_loss_epoch=0.5249 | train_loss_step=0.3686 | val_rmse_ema=1.3699
# [Epoch 325]  Val RMSE (DynFM, EMA) = 1.3907
# [progress] epoch 327/2000 | train_loss=0.5197 | train_loss_epoch=0.5197 | train_loss_step=0.3494 | val_rmse_ema=1.3907
# [Epoch 326]  Val RMSE (DynFM, EMA) = 1.3288
# [progress] epoch 328/2000 | train_loss=0.5079 | train_loss_epoch=0.5079 | train_loss_step=0.3281 | val_rmse_ema=1.3288
# [Epoch 327]  Val RMSE (DynFM, EMA) = 1.3352
# [progress] epoch 329/2000 | train_loss=0.5277 | train_loss_epoch=0.5277 | train_loss_step=0.4250 | val_rmse_ema=1.3352
# [Epoch 328]  Val RMSE (DynFM, EMA) = 1.2989
# [progress] epoch 330/2000 | train_loss=0.5163 | train_loss_epoch=0.5163 | train_loss_step=0.3541 | val_rmse_ema=1.2989
# [Epoch 329]  Val RMSE (DynFM, EMA) = 1.3085
# [progress] epoch 331/2000 | train_loss=0.5168 | train_loss_epoch=0.5168 | train_loss_step=0.3517 | val_rmse_ema=1.3085
# [Epoch 330]  Val RMSE (DynFM, EMA) = 1.2712
# [progress] epoch 332/2000 | train_loss=0.5348 | train_loss_epoch=0.5348 | train_loss_step=0.8764 | val_rmse_ema=1.2712
# [Epoch 331]  Val RMSE (DynFM, EMA) = 1.3046
# [progress] epoch 333/2000 | train_loss=0.5530 | train_loss_epoch=0.5530 | train_loss_step=0.3789 | val_rmse_ema=1.3046
# [Epoch 332]  Val RMSE (DynFM, EMA) = 1.3141
# [progress] epoch 334/2000 | train_loss=0.4928 | train_loss_epoch=0.4928 | train_loss_step=0.2870 | val_rmse_ema=1.3141
# [Epoch 333]  Val RMSE (DynFM, EMA) = 1.3197
# [progress] epoch 335/2000 | train_loss=0.5162 | train_loss_epoch=0.5162 | train_loss_step=0.3972 | val_rmse_ema=1.3197
# [Epoch 334]  Val RMSE (DynFM, EMA) = 1.3034
# [progress] epoch 336/2000 | train_loss=0.4972 | train_loss_epoch=0.4972 | train_loss_step=0.3626 | val_rmse_ema=1.3034
# [Epoch 335]  Val RMSE (DynFM, EMA) = 1.3326
# [progress] epoch 337/2000 | train_loss=0.4898 | train_loss_epoch=0.4898 | train_loss_step=0.3199 | val_rmse_ema=1.3326
# [Epoch 336]  Val RMSE (DynFM, EMA) = 1.2831
# [progress] epoch 338/2000 | train_loss=0.5305 | train_loss_epoch=0.5305 | train_loss_step=0.3108 | val_rmse_ema=1.2831
# [Epoch 337]  Val RMSE (DynFM, EMA) = 1.3098
# [progress] epoch 339/2000 | train_loss=0.4964 | train_loss_epoch=0.4964 | train_loss_step=0.3965 | val_rmse_ema=1.3098
# [Epoch 338]  Val RMSE (DynFM, EMA) = 1.2886
# [progress] epoch 340/2000 | train_loss=0.5337 | train_loss_epoch=0.5337 | train_loss_step=0.3106 | val_rmse_ema=1.2886
# [Epoch 339]  Val RMSE (DynFM, EMA) = 1.3269
# [progress] epoch 341/2000 | train_loss=0.5120 | train_loss_epoch=0.5120 | train_loss_step=1.0162 | val_rmse_ema=1.3269
# [Epoch 340]  Val RMSE (DynFM, EMA) = 1.3439
# [progress] epoch 342/2000 | train_loss=0.4973 | train_loss_epoch=0.4973 | train_loss_step=0.3070 | val_rmse_ema=1.3439
# [Epoch 341]  Val RMSE (DynFM, EMA) = 1.3262
# [progress] epoch 343/2000 | train_loss=0.5502 | train_loss_epoch=0.5502 | train_loss_step=0.3700 | val_rmse_ema=1.3262
# [Epoch 342]  Val RMSE (DynFM, EMA) = 1.3379
# [progress] epoch 344/2000 | train_loss=0.5235 | train_loss_epoch=0.5235 | train_loss_step=0.2507 | val_rmse_ema=1.3379
# [Epoch 343]  Val RMSE (DynFM, EMA) = 1.3537
# [progress] epoch 345/2000 | train_loss=0.5013 | train_loss_epoch=0.5013 | train_loss_step=0.3468 | val_rmse_ema=1.3537
# [Epoch 344]  Val RMSE (DynFM, EMA) = 1.3367
# [progress] epoch 346/2000 | train_loss=0.5383 | train_loss_epoch=0.5383 | train_loss_step=0.8188 | val_rmse_ema=1.3367
# [Epoch 345]  Val RMSE (DynFM, EMA) = 1.3140
# [progress] epoch 347/2000 | train_loss=0.5138 | train_loss_epoch=0.5138 | train_loss_step=1.0320 | val_rmse_ema=1.3140
# [Epoch 346]  Val RMSE (DynFM, EMA) = 1.3445
# [progress] epoch 348/2000 | train_loss=0.5296 | train_loss_epoch=0.5296 | train_loss_step=0.9475 | val_rmse_ema=1.3445
# [Epoch 347]  Val RMSE (DynFM, EMA) = 1.3044
# [progress] epoch 349/2000 | train_loss=0.5320 | train_loss_epoch=0.5320 | train_loss_step=0.3973 | val_rmse_ema=1.3044
# [Epoch 348]  Val RMSE (DynFM, EMA) = 1.3341
# [progress] epoch 350/2000 | train_loss=0.5005 | train_loss_epoch=0.5005 | train_loss_step=0.8394 | val_rmse_ema=1.3341
# [Epoch 349]  Val RMSE (DynFM, EMA) = 1.3386
# [progress] epoch 351/2000 | train_loss=0.5055 | train_loss_epoch=0.5055 | train_loss_step=0.3025 | val_rmse_ema=1.3386
# [Epoch 350]  Val RMSE (DynFM, EMA) = 1.3670
# [progress] epoch 352/2000 | train_loss=0.5214 | train_loss_epoch=0.5214 | train_loss_step=0.3700 | val_rmse_ema=1.3670
# [Epoch 351]  Val RMSE (DynFM, EMA) = 1.3891
# [progress] epoch 353/2000 | train_loss=0.4991 | train_loss_epoch=0.4991 | train_loss_step=0.2869 | val_rmse_ema=1.3891
# [Epoch 352]  Val RMSE (DynFM, EMA) = 1.3754
# [progress] epoch 354/2000 | train_loss=0.4880 | train_loss_epoch=0.4880 | train_loss_step=0.9290 | val_rmse_ema=1.3754
# [Epoch 353]  Val RMSE (DynFM, EMA) = 1.3646
# [progress] epoch 355/2000 | train_loss=0.4917 | train_loss_epoch=0.4917 | train_loss_step=0.2882 | val_rmse_ema=1.3646
# [Epoch 354]  Val RMSE (DynFM, EMA) = 1.3480
# [progress] epoch 356/2000 | train_loss=0.5089 | train_loss_epoch=0.5089 | train_loss_step=0.8649 | val_rmse_ema=1.3480
# [Epoch 355]  Val RMSE (DynFM, EMA) = 1.3542
# [progress] epoch 357/2000 | train_loss=0.5030 | train_loss_epoch=0.5030 | train_loss_step=0.8641 | val_rmse_ema=1.3542
# [Epoch 356]  Val RMSE (DynFM, EMA) = 1.3368
# [progress] epoch 358/2000 | train_loss=0.4894 | train_loss_epoch=0.4894 | train_loss_step=0.3927 | val_rmse_ema=1.3368
# [Epoch 357]  Val RMSE (DynFM, EMA) = 1.3568
# [progress] epoch 359/2000 | train_loss=0.5070 | train_loss_epoch=0.5070 | train_loss_step=0.2897 | val_rmse_ema=1.3568
# [Epoch 358]  Val RMSE (DynFM, EMA) = 1.4072
# [progress] epoch 360/2000 | train_loss=0.5139 | train_loss_epoch=0.5139 | train_loss_step=0.2694 | val_rmse_ema=1.4072
# [Epoch 359]  Val RMSE (DynFM, EMA) = 1.3681
# [progress] epoch 361/2000 | train_loss=0.4746 | train_loss_epoch=0.4746 | train_loss_step=0.8669 | val_rmse_ema=1.3681
# [Epoch 360]  Val RMSE (DynFM, EMA) = 1.4517
# [progress] epoch 362/2000 | train_loss=0.5081 | train_loss_epoch=0.5081 | train_loss_step=0.2901 | val_rmse_ema=1.4517
# [Epoch 361]  Val RMSE (DynFM, EMA) = 1.4022
# [progress] epoch 363/2000 | train_loss=0.4949 | train_loss_epoch=0.4949 | train_loss_step=0.3107 | val_rmse_ema=1.4022
# [Epoch 362]  Val RMSE (DynFM, EMA) = 1.3931
# [progress] epoch 364/2000 | train_loss=0.4822 | train_loss_epoch=0.4822 | train_loss_step=0.3458 | val_rmse_ema=1.3931
# [Epoch 363]  Val RMSE (DynFM, EMA) = 1.3687
# [progress] epoch 365/2000 | train_loss=0.5032 | train_loss_epoch=0.5032 | train_loss_step=0.9127 | val_rmse_ema=1.3687
# [Epoch 364]  Val RMSE (DynFM, EMA) = 1.3453
# [progress] epoch 366/2000 | train_loss=0.4981 | train_loss_epoch=0.4981 | train_loss_step=0.2909 | val_rmse_ema=1.3453
# [Epoch 365]  Val RMSE (DynFM, EMA) = 1.3468
# [progress] epoch 367/2000 | train_loss=0.4631 | train_loss_epoch=0.4631 | train_loss_step=0.2739 | val_rmse_ema=1.3468
# [Epoch 366]  Val RMSE (DynFM, EMA) = 1.3689
# [progress] epoch 368/2000 | train_loss=0.4868 | train_loss_epoch=0.4868 | train_loss_step=0.2745 | val_rmse_ema=1.3689
# [Epoch 367]  Val RMSE (DynFM, EMA) = 1.3373
# [progress] epoch 369/2000 | train_loss=0.4790 | train_loss_epoch=0.4790 | train_loss_step=0.2837 | val_rmse_ema=1.3373
# [Epoch 368]  Val RMSE (DynFM, EMA) = 1.3446
# [progress] epoch 370/2000 | train_loss=0.4962 | train_loss_epoch=0.4962 | train_loss_step=0.8480 | val_rmse_ema=1.3446
# [Epoch 369]  Val RMSE (DynFM, EMA) = 1.3660
# [progress] epoch 371/2000 | train_loss=0.4855 | train_loss_epoch=0.4855 | train_loss_step=0.8249 | val_rmse_ema=1.3660
# [Epoch 370]  Val RMSE (DynFM, EMA) = 1.3396
# [progress] epoch 372/2000 | train_loss=0.4589 | train_loss_epoch=0.4589 | train_loss_step=0.2768 | val_rmse_ema=1.3396
# [Epoch 371]  Val RMSE (DynFM, EMA) = 1.3693
# [progress] epoch 373/2000 | train_loss=0.4595 | train_loss_epoch=0.4595 | train_loss_step=0.9542 | val_rmse_ema=1.3693
# [Epoch 372]  Val RMSE (DynFM, EMA) = 1.3205
# [progress] epoch 374/2000 | train_loss=0.4883 | train_loss_epoch=0.4883 | train_loss_step=0.9381 | val_rmse_ema=1.3205
# [Epoch 373]  Val RMSE (DynFM, EMA) = 1.3436
# [progress] epoch 375/2000 | train_loss=0.4848 | train_loss_epoch=0.4848 | train_loss_step=0.3194 | val_rmse_ema=1.3436
# [Epoch 374]  Val RMSE (DynFM, EMA) = 1.3516
# [progress] epoch 376/2000 | train_loss=0.4560 | train_loss_epoch=0.4560 | train_loss_step=0.3161 | val_rmse_ema=1.3516
# [Epoch 375]  Val RMSE (DynFM, EMA) = 1.3224
# ...
# [Epoch 1903]  Val RMSE (DynFM, EMA) = 1.0532
# [progress] epoch 1905/2000 | train_loss=0.1335 | train_loss_epoch=0.1335 | train_loss_step=0.0509 | val_rmse_ema=1.0532
# [Epoch 1904]  Val RMSE (DynFM, EMA) = 1.0516
# [progress] epoch 1906/2000 | train_loss=0.1318 | train_loss_epoch=0.1318 | train_loss_step=0.1825 | val_rmse_ema=1.0516
# [Epoch 1905]  Val RMSE (DynFM, EMA) = 1.0508
# [progress] epoch 1907/2000 | train_loss=0.1306 | train_loss_epoch=0.1306 | train_loss_step=0.3151 | val_rmse_ema=1.0508
# [Epoch 1906]  Val RMSE (DynFM, EMA) = 1.0563
# [progress] epoch 1908/2000 | train_loss=0.0991 | train_loss_epoch=0.0991 | train_loss_step=0.0345 | val_rmse_ema=1.0563
# [Epoch 1907]  Val RMSE (DynFM, EMA) = 1.0630
# [progress] epoch 1909/2000 | train_loss=0.1176 | train_loss_epoch=0.1176 | train_loss_step=0.0357 | val_rmse_ema=1.0630
# [Epoch 1908]  Val RMSE (DynFM, EMA) = 1.0579
# [progress] epoch 1910/2000 | train_loss=0.0813 | train_loss_epoch=0.0813 | train_loss_step=0.1774 | val_rmse_ema=1.0579
# [Epoch 1909]  Val RMSE (DynFM, EMA) = 1.0551
# [progress] epoch 1911/2000 | train_loss=0.1184 | train_loss_epoch=0.1184 | train_loss_step=0.0459 | val_rmse_ema=1.0551
# [Epoch 1910]  Val RMSE (DynFM, EMA) = 1.0597
# [progress] epoch 1912/2000 | train_loss=0.1122 | train_loss_epoch=0.1122 | train_loss_step=0.1964 | val_rmse_ema=1.0597
# [Epoch 1911]  Val RMSE (DynFM, EMA) = 1.0529
# [progress] epoch 1913/2000 | train_loss=0.1007 | train_loss_epoch=0.1007 | train_loss_step=0.0680 | val_rmse_ema=1.0529
# [Epoch 1912]  Val RMSE (DynFM, EMA) = 1.0625
# [progress] epoch 1914/2000 | train_loss=0.1241 | train_loss_epoch=0.1241 | train_loss_step=0.0421 | val_rmse_ema=1.0625
# [Epoch 1913]  Val RMSE (DynFM, EMA) = 1.0546
# [progress] epoch 1915/2000 | train_loss=0.1068 | train_loss_epoch=0.1068 | train_loss_step=0.0419 | val_rmse_ema=1.0546
# [Epoch 1914]  Val RMSE (DynFM, EMA) = 1.0545
# [progress] epoch 1916/2000 | train_loss=0.1066 | train_loss_epoch=0.1066 | train_loss_step=0.0467 | val_rmse_ema=1.0545
# [Epoch 1915]  Val RMSE (DynFM, EMA) = 1.0633
# [progress] epoch 1917/2000 | train_loss=0.1133 | train_loss_epoch=0.1133 | train_loss_step=0.0567 | val_rmse_ema=1.0633
# [Epoch 1916]  Val RMSE (DynFM, EMA) = 1.0556
# [progress] epoch 1918/2000 | train_loss=0.1433 | train_loss_epoch=0.1433 | train_loss_step=0.0852 | val_rmse_ema=1.0556
# [Epoch 1917]  Val RMSE (DynFM, EMA) = 1.0676
# [progress] epoch 1919/2000 | train_loss=0.0996 | train_loss_epoch=0.0996 | train_loss_step=0.0538 | val_rmse_ema=1.0676
# [Epoch 1918]  Val RMSE (DynFM, EMA) = 1.0882
# [progress] epoch 1920/2000 | train_loss=0.1671 | train_loss_epoch=0.1671 | train_loss_step=0.0888 | val_rmse_ema=1.0882
# [Epoch 1919]  Val RMSE (DynFM, EMA) = 1.0872
# [progress] epoch 1921/2000 | train_loss=0.1226 | train_loss_epoch=0.1226 | train_loss_step=0.0494 | val_rmse_ema=1.0872
# [Epoch 1920]  Val RMSE (DynFM, EMA) = 1.0870
# [progress] epoch 1922/2000 | train_loss=0.1245 | train_loss_epoch=0.1245 | train_loss_step=0.9935 | val_rmse_ema=1.0870
# [Epoch 1921]  Val RMSE (DynFM, EMA) = 1.0831
# [progress] epoch 1923/2000 | train_loss=0.1200 | train_loss_epoch=0.1200 | train_loss_step=0.0623 | val_rmse_ema=1.0831
# [Epoch 1922]  Val RMSE (DynFM, EMA) = 1.0873
# [progress] epoch 1924/2000 | train_loss=0.1033 | train_loss_epoch=0.1033 | train_loss_step=0.0411 | val_rmse_ema=1.0873
# [Epoch 1923]  Val RMSE (DynFM, EMA) = 1.0732
# [progress] epoch 1925/2000 | train_loss=0.1590 | train_loss_epoch=0.1590 | train_loss_step=0.3374 | val_rmse_ema=1.0732
# [Epoch 1924]  Val RMSE (DynFM, EMA) = 1.0799
# [progress] epoch 1926/2000 | train_loss=0.1206 | train_loss_epoch=0.1206 | train_loss_step=0.0446 | val_rmse_ema=1.0799
# [Epoch 1925]  Val RMSE (DynFM, EMA) = 1.0805
# [progress] epoch 1927/2000 | train_loss=0.1269 | train_loss_epoch=0.1269 | train_loss_step=0.3145 | val_rmse_ema=1.0805
# [Epoch 1926]  Val RMSE (DynFM, EMA) = 1.0770
# [progress] epoch 1928/2000 | train_loss=0.1165 | train_loss_epoch=0.1165 | train_loss_step=0.1112 | val_rmse_ema=1.0770
# [Epoch 1927]  Val RMSE (DynFM, EMA) = 1.0721
# [progress] epoch 1929/2000 | train_loss=0.1150 | train_loss_epoch=0.1150 | train_loss_step=0.9692 | val_rmse_ema=1.0721
# [Epoch 1928]  Val RMSE (DynFM, EMA) = 1.0744
# [progress] epoch 1930/2000 | train_loss=0.1185 | train_loss_epoch=0.1185 | train_loss_step=0.0477 | val_rmse_ema=1.0744
# [Epoch 1929]  Val RMSE (DynFM, EMA) = 1.0638
# [progress] epoch 1931/2000 | train_loss=0.1278 | train_loss_epoch=0.1278 | train_loss_step=0.0533 | val_rmse_ema=1.0638
# [Epoch 1930]  Val RMSE (DynFM, EMA) = 1.0596
# [progress] epoch 1932/2000 | train_loss=0.1006 | train_loss_epoch=0.1006 | train_loss_step=0.0375 | val_rmse_ema=1.0596
# [Epoch 1931]  Val RMSE (DynFM, EMA) = 1.0658
# [progress] epoch 1933/2000 | train_loss=0.1082 | train_loss_epoch=0.1082 | train_loss_step=0.0382 | val_rmse_ema=1.0658
# [Epoch 1932]  Val RMSE (DynFM, EMA) = 1.0603
# [progress] epoch 1934/2000 | train_loss=0.1059 | train_loss_epoch=0.1059 | train_loss_step=0.0613 | val_rmse_ema=1.0603
# [Epoch 1933]  Val RMSE (DynFM, EMA) = 1.0713
# [progress] epoch 1935/2000 | train_loss=0.1022 | train_loss_epoch=0.1022 | train_loss_step=0.0365 | val_rmse_ema=1.0713
# [Epoch 1934]  Val RMSE (DynFM, EMA) = 1.0766
# [progress] epoch 1936/2000 | train_loss=0.1022 | train_loss_epoch=0.1022 | train_loss_step=0.0726 | val_rmse_ema=1.0766
# [Epoch 1935]  Val RMSE (DynFM, EMA) = 1.0731
# [progress] epoch 1937/2000 | train_loss=0.1249 | train_loss_epoch=0.1249 | train_loss_step=0.0420 | val_rmse_ema=1.0731
# [Epoch 1936]  Val RMSE (DynFM, EMA) = 1.0743
# [progress] epoch 1938/2000 | train_loss=0.1187 | train_loss_epoch=0.1187 | train_loss_step=0.0751 | val_rmse_ema=1.0743
# [Epoch 1937]  Val RMSE (DynFM, EMA) = 1.0800
# [progress] epoch 1939/2000 | train_loss=0.1013 | train_loss_epoch=0.1013 | train_loss_step=0.0398 | val_rmse_ema=1.0800
# [Epoch 1938]  Val RMSE (DynFM, EMA) = 1.0781
# [progress] epoch 1940/2000 | train_loss=0.1196 | train_loss_epoch=0.1196 | train_loss_step=0.2164 | val_rmse_ema=1.0781
# [Epoch 1939]  Val RMSE (DynFM, EMA) = 1.0872
# [progress] epoch 1941/2000 | train_loss=0.1172 | train_loss_epoch=0.1172 | train_loss_step=0.0601 | val_rmse_ema=1.0872
# [Epoch 1940]  Val RMSE (DynFM, EMA) = 1.0820
# [progress] epoch 1942/2000 | train_loss=0.1140 | train_loss_epoch=0.1140 | train_loss_step=0.0450 | val_rmse_ema=1.0820
# [Epoch 1941]  Val RMSE (DynFM, EMA) = 1.0805
# [progress] epoch 1943/2000 | train_loss=0.1188 | train_loss_epoch=0.1188 | train_loss_step=0.0573 | val_rmse_ema=1.0805
# [Epoch 1942]  Val RMSE (DynFM, EMA) = 1.0757
# [progress] epoch 1944/2000 | train_loss=0.1216 | train_loss_epoch=0.1216 | train_loss_step=0.0477 | val_rmse_ema=1.0757
# [Epoch 1943]  Val RMSE (DynFM, EMA) = 1.0899
# [progress] epoch 1945/2000 | train_loss=0.1452 | train_loss_epoch=0.1452 | train_loss_step=0.9955 | val_rmse_ema=1.0899
# [Epoch 1944]  Val RMSE (DynFM, EMA) = 1.1050
# [progress] epoch 1946/2000 | train_loss=0.1403 | train_loss_epoch=0.1403 | train_loss_step=0.1652 | val_rmse_ema=1.1050
# [Epoch 1945]  Val RMSE (DynFM, EMA) = 1.1068
# [progress] epoch 1947/2000 | train_loss=0.0992 | train_loss_epoch=0.0992 | train_loss_step=0.0431 | val_rmse_ema=1.1068
# [Epoch 1946]  Val RMSE (DynFM, EMA) = 1.0732
# [progress] epoch 1948/2000 | train_loss=0.1304 | train_loss_epoch=0.1304 | train_loss_step=0.0592 | val_rmse_ema=1.0732
# [Epoch 1947]  Val RMSE (DynFM, EMA) = 1.0616
# [progress] epoch 1949/2000 | train_loss=0.1252 | train_loss_epoch=0.1252 | train_loss_step=0.5006 | val_rmse_ema=1.0616
# [Epoch 1948]  Val RMSE (DynFM, EMA) = 1.0802
# [progress] epoch 1950/2000 | train_loss=0.1125 | train_loss_epoch=0.1125 | train_loss_step=0.2021 | val_rmse_ema=1.0802
# [Epoch 1949]  Val RMSE (DynFM, EMA) = 1.0797
# [progress] epoch 1951/2000 | train_loss=0.0999 | train_loss_epoch=0.0999 | train_loss_step=0.0402 | val_rmse_ema=1.0797
# [Epoch 1950]  Val RMSE (DynFM, EMA) = 1.0770
# [progress] epoch 1952/2000 | train_loss=0.1222 | train_loss_epoch=0.1222 | train_loss_step=0.0554 | val_rmse_ema=1.0770
# [Epoch 1951]  Val RMSE (DynFM, EMA) = 1.0832
# [progress] epoch 1953/2000 | train_loss=0.1291 | train_loss_epoch=0.1291 | train_loss_step=0.0523 | val_rmse_ema=1.0832
# [Epoch 1952]  Val RMSE (DynFM, EMA) = 1.0826
# [progress] epoch 1954/2000 | train_loss=0.1321 | train_loss_epoch=0.1321 | train_loss_step=0.0916 | val_rmse_ema=1.0826
# [Epoch 1953]  Val RMSE (DynFM, EMA) = 1.0716
# [progress] epoch 1955/2000 | train_loss=0.1385 | train_loss_epoch=0.1385 | train_loss_step=0.0443 | val_rmse_ema=1.0716
# [Epoch 1954]  Val RMSE (DynFM, EMA) = 1.0826
# [progress] epoch 1956/2000 | train_loss=0.1125 | train_loss_epoch=0.1125 | train_loss_step=0.2156 | val_rmse_ema=1.0826
# [Epoch 1955]  Val RMSE (DynFM, EMA) = 1.0755
# [progress] epoch 1957/2000 | train_loss=0.1338 | train_loss_epoch=0.1338 | train_loss_step=0.0731 | val_rmse_ema=1.0755
# [Epoch 1956]  Val RMSE (DynFM, EMA) = 1.0738
# [progress] epoch 1958/2000 | train_loss=0.1258 | train_loss_epoch=0.1258 | train_loss_step=0.0453 | val_rmse_ema=1.0738
# [Epoch 1957]  Val RMSE (DynFM, EMA) = 1.0724
# [progress] epoch 1959/2000 | train_loss=0.0998 | train_loss_epoch=0.0998 | train_loss_step=0.0436 | val_rmse_ema=1.0724
# [Epoch 1958]  Val RMSE (DynFM, EMA) = 1.0668
# [progress] epoch 1960/2000 | train_loss=0.1012 | train_loss_epoch=0.1012 | train_loss_step=0.1549 | val_rmse_ema=1.0668
# [Epoch 1959]  Val RMSE (DynFM, EMA) = 1.0645
# [progress] epoch 1961/2000 | train_loss=0.1547 | train_loss_epoch=0.1547 | train_loss_step=0.0487 | val_rmse_ema=1.0645
# [Epoch 1960]  Val RMSE (DynFM, EMA) = 1.0582
# [progress] epoch 1962/2000 | train_loss=0.1140 | train_loss_epoch=0.1140 | train_loss_step=0.0512 | val_rmse_ema=1.0582
# [Epoch 1961]  Val RMSE (DynFM, EMA) = 1.0551
# [progress] epoch 1963/2000 | train_loss=0.1083 | train_loss_epoch=0.1083 | train_loss_step=0.3657 | val_rmse_ema=1.0551
# [Epoch 1962]  Val RMSE (DynFM, EMA) = 1.0619
# [progress] epoch 1964/2000 | train_loss=0.1073 | train_loss_epoch=0.1073 | train_loss_step=0.2418 | val_rmse_ema=1.0619
# [Epoch 1963]  Val RMSE (DynFM, EMA) = 1.0542
# [progress] epoch 1965/2000 | train_loss=0.1056 | train_loss_epoch=0.1056 | train_loss_step=0.9066 | val_rmse_ema=1.0542
# [Epoch 1964]  Val RMSE (DynFM, EMA) = 1.0605
# [progress] epoch 1966/2000 | train_loss=0.1189 | train_loss_epoch=0.1189 | train_loss_step=0.0594 | val_rmse_ema=1.0605
# [Epoch 1965]  Val RMSE (DynFM, EMA) = 1.0546
# [progress] epoch 1967/2000 | train_loss=0.1221 | train_loss_epoch=0.1221 | train_loss_step=0.1522 | val_rmse_ema=1.0546
# [Epoch 1966]  Val RMSE (DynFM, EMA) = 1.0528
# [progress] epoch 1968/2000 | train_loss=0.1086 | train_loss_epoch=0.1086 | train_loss_step=0.0883 | val_rmse_ema=1.0528
# [Epoch 1967]  Val RMSE (DynFM, EMA) = 1.0576
# [progress] epoch 1969/2000 | train_loss=0.0948 | train_loss_epoch=0.0948 | train_loss_step=0.0972 | val_rmse_ema=1.0576
# [Epoch 1968]  Val RMSE (DynFM, EMA) = 1.0581
# [progress] epoch 1970/2000 | train_loss=0.1200 | train_loss_epoch=0.1200 | train_loss_step=0.0414 | val_rmse_ema=1.0581
# [Epoch 1969]  Val RMSE (DynFM, EMA) = 1.0488
# [progress] epoch 1971/2000 | train_loss=0.1157 | train_loss_epoch=0.1157 | train_loss_step=0.3279 | val_rmse_ema=1.0488
# [Epoch 1970]  Val RMSE (DynFM, EMA) = 1.0466
# [progress] epoch 1972/2000 | train_loss=0.1143 | train_loss_epoch=0.1143 | train_loss_step=0.0318 | val_rmse_ema=1.0466
# [Epoch 1971]  Val RMSE (DynFM, EMA) = 1.0566
# [progress] epoch 1973/2000 | train_loss=0.1104 | train_loss_epoch=0.1104 | train_loss_step=0.0511 | val_rmse_ema=1.0566
# [Epoch 1972]  Val RMSE (DynFM, EMA) = 1.0599
# [progress] epoch 1974/2000 | train_loss=0.0998 | train_loss_epoch=0.0998 | train_loss_step=0.0481 | val_rmse_ema=1.0599
# [Epoch 1973]  Val RMSE (DynFM, EMA) = 1.0396
# [progress] epoch 1975/2000 | train_loss=0.1107 | train_loss_epoch=0.1107 | train_loss_step=0.0982 | val_rmse_ema=1.0396
# [Epoch 1974]  Val RMSE (DynFM, EMA) = 1.0353
# [progress] epoch 1976/2000 | train_loss=0.1161 | train_loss_epoch=0.1161 | train_loss_step=0.1082 | val_rmse_ema=1.0353
# [Epoch 1975]  Val RMSE (DynFM, EMA) = 1.0345
# [progress] epoch 1977/2000 | train_loss=0.1291 | train_loss_epoch=0.1291 | train_loss_step=0.0515 | val_rmse_ema=1.0345
# [Epoch 1976]  Val RMSE (DynFM, EMA) = 1.0263
# [progress] epoch 1978/2000 | train_loss=0.1091 | train_loss_epoch=0.1091 | train_loss_step=0.0439 | val_rmse_ema=1.0263
# [Epoch 1977]  Val RMSE (DynFM, EMA) = 1.0290
# [progress] epoch 1979/2000 | train_loss=0.1339 | train_loss_epoch=0.1339 | train_loss_step=0.0619 | val_rmse_ema=1.0290
# [Epoch 1978]  Val RMSE (DynFM, EMA) = 1.0363
# [progress] epoch 1980/2000 | train_loss=0.1402 | train_loss_epoch=0.1402 | train_loss_step=0.0524 | val_rmse_ema=1.0363
# [Epoch 1979]  Val RMSE (DynFM, EMA) = 1.0404
# [progress] epoch 1981/2000 | train_loss=0.1435 | train_loss_epoch=0.1435 | train_loss_step=0.0361 | val_rmse_ema=1.0404
# [Epoch 1980]  Val RMSE (DynFM, EMA) = 1.0442
# [progress] epoch 1982/2000 | train_loss=0.1294 | train_loss_epoch=0.1294 | train_loss_step=0.0542 | val_rmse_ema=1.0442
# [Epoch 1981]  Val RMSE (DynFM, EMA) = 1.0420
# [progress] epoch 1983/2000 | train_loss=0.0906 | train_loss_epoch=0.0906 | train_loss_step=0.0330 | val_rmse_ema=1.0420
# [Epoch 1982]  Val RMSE (DynFM, EMA) = 1.0550
# [progress] epoch 1984/2000 | train_loss=0.1103 | train_loss_epoch=0.1103 | train_loss_step=0.8210 | val_rmse_ema=1.0550
# [Epoch 1983]  Val RMSE (DynFM, EMA) = 1.0478
# [progress] epoch 1985/2000 | train_loss=0.1187 | train_loss_epoch=0.1187 | train_loss_step=0.0418 | val_rmse_ema=1.0478
# [Epoch 1984]  Val RMSE (DynFM, EMA) = 1.0552
# [progress] epoch 1986/2000 | train_loss=0.1134 | train_loss_epoch=0.1134 | train_loss_step=0.0479 | val_rmse_ema=1.0552
# [Epoch 1985]  Val RMSE (DynFM, EMA) = 1.0479
# [progress] epoch 1987/2000 | train_loss=0.1004 | train_loss_epoch=0.1004 | train_loss_step=0.8912 | val_rmse_ema=1.0479
# [Epoch 1986]  Val RMSE (DynFM, EMA) = 1.0603
# [progress] epoch 1988/2000 | train_loss=0.1285 | train_loss_epoch=0.1285 | train_loss_step=0.0475 | val_rmse_ema=1.0603
# [Epoch 1987]  Val RMSE (DynFM, EMA) = 1.0453
# [progress] epoch 1989/2000 | train_loss=0.1011 | train_loss_epoch=0.1011 | train_loss_step=0.0432 | val_rmse_ema=1.0453
# [Epoch 1988]  Val RMSE (DynFM, EMA) = 1.0339
# [progress] epoch 1990/2000 | train_loss=0.1098 | train_loss_epoch=0.1098 | train_loss_step=0.0513 | val_rmse_ema=1.0339
# [Epoch 1989]  Val RMSE (DynFM, EMA) = 1.0371
# [progress] epoch 1991/2000 | train_loss=0.1127 | train_loss_epoch=0.1127 | train_loss_step=0.0559 | val_rmse_ema=1.0371
# [Epoch 1990]  Val RMSE (DynFM, EMA) = 1.0387
# [progress] epoch 1992/2000 | train_loss=0.1061 | train_loss_epoch=0.1061 | train_loss_step=0.0529 | val_rmse_ema=1.0387
# [Epoch 1991]  Val RMSE (DynFM, EMA) = 1.0320
# [progress] epoch 1993/2000 | train_loss=0.0991 | train_loss_epoch=0.0991 | train_loss_step=0.1083 | val_rmse_ema=1.0320
# [Epoch 1992]  Val RMSE (DynFM, EMA) = 1.0369
# [progress] epoch 1994/2000 | train_loss=0.1374 | train_loss_epoch=0.1374 | train_loss_step=0.0489 | val_rmse_ema=1.0369
# [Epoch 1993]  Val RMSE (DynFM, EMA) = 1.0378
# [progress] epoch 1995/2000 | train_loss=0.0824 | train_loss_epoch=0.0824 | train_loss_step=0.0449 | val_rmse_ema=1.0378
# [Epoch 1994]  Val RMSE (DynFM, EMA) = 1.0369
# [progress] epoch 1996/2000 | train_loss=0.1150 | train_loss_epoch=0.1150 | train_loss_step=0.0678 | val_rmse_ema=1.0369
# [Epoch 1995]  Val RMSE (DynFM, EMA) = 1.0358
# [progress] epoch 1997/2000 | train_loss=0.1244 | train_loss_epoch=0.1244 | train_loss_step=0.0309 | val_rmse_ema=1.0358
# [Epoch 1996]  Val RMSE (DynFM, EMA) = 1.0417
# [progress] epoch 1998/2000 | train_loss=0.1049 | train_loss_epoch=0.1049 | train_loss_step=0.0350 | val_rmse_ema=1.0417
# [Epoch 1997]  Val RMSE (DynFM, EMA) = 1.0461
# [progress] epoch 1999/2000 | train_loss=0.1264 | train_loss_epoch=0.1264 | train_loss_step=0.0473 | val_rmse_ema=1.0461
# [Epoch 1998]  Val RMSE (DynFM, EMA) = 1.0388
# [progress] epoch 2000/2000 | train_loss=0.0968 | train_loss_epoch=0.0968 | train_loss_step=0.0414 | val_rmse_ema=1.0388
# [Epoch 1999]  Val RMSE (DynFM, EMA) = 1.0455
# `Trainer.fit` stopped: `max_epochs=2000` reached.
# EMA model saved to: logs_DynFM_spde/best_model

# %% [markdown]
# ## Sampling & Evaluation

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype  = torch.float32

MODEL_PATH = os.path.join("logs_DynFM_spde", "best_model")

ema_unet = UNetFM.from_pretrained(MODEL_PATH).eval().to(device=device, dtype=dtype)
print(f"EMA UNetFM loaded from {MODEL_PATH}")
# Out:
# EMA UNetFM loaded from logs_DynFM_spde/best_model

# %% [markdown]
# ### Test Batch

# %%
seed_everything(42)
batch = next(iter(datamodule.test_dataloader()))
C = batch.tgt.shape[1]
H, W = batch.tgt.shape[-2], batch.tgt.shape[-1]
y_obs = batch.input.to(device=device, dtype=dtype)
m_norm, s_norm = datamodule.norm_stats()
print(f"Test batch: tgt={batch.tgt.shape}, input={batch.input.shape}")
# Out:
# [rank: 0] Global seed set to 42
# Test batch: tgt=torch.Size([1, 5, 128, 128]), input=torch.Size([1, 5, 128, 128])

# %% [markdown]
# ### Ensemble Generation

# %%
# N_SAMPLES set by the parameters cell above
N_STEPS   = 4 * C + 1

all_frames = []

with torch.no_grad():
    for s in range(N_SAMPLES):
        noise = torch.randn(1, 1, H, W, device=device, dtype=dtype)
        _, traj, traj_times = dynfm_heun_sample(ema_unet, noise, y_obs[0:1], n_steps=N_STEPS,
                                    spinup_frac=SPINUP_FRAC, precondition=True)
        frames = extract_dynfm_frames(traj, traj_times, C, SPINUP_FRAC)
        member = torch.cat(frames, dim=1)   # (1, C, H, W)
        all_frames.append(member.cpu())
        print(f"  member {s+1}/{N_SAMPLES}", end="\r")

ensemble = torch.cat(all_frames, dim=0)    # (N, C, H, W)
ens_mean = ensemble.mean(0)                 # (C, H, W)
ens_std  = ensemble.std(0)
print(f"\nEnsemble: {tuple(ensemble.shape)}")
# Out:
#   member 1/1
# Ensemble: (1, 5, 128, 128)
# /tmp/ipykernel_998657/364050858.py:18: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1879.)
#   ens_std  = ensemble.std(0)

# %%
# Full trajectory for member 0 (for transport visualisation)
torch.manual_seed(42)
noise_viz = torch.randn(1, 1, H, W, device=device, dtype=dtype)
with torch.no_grad():
    _, traj_viz, traj_times_viz = dynfm_heun_sample(ema_unet, noise_viz, y_obs[0:1],
                                    n_steps=N_STEPS, spinup_frac=SPINUP_FRAC,
                                    precondition=True)

# Physical frame stack
gt_np     = batch.tgt[0].float().numpy()
ens_mean_traj = ens_mean.float().numpy()
ens_std_traj  = ens_std.float().numpy()
print(f"GT: {gt_np.shape}, ens_mean: {ens_mean_traj.shape}")
print(f"Trajectory: {len(traj_viz)} steps (boundary-aware grid)")
# Out:
# GT: (5, 128, 128), ens_mean: (5, 128, 128)
# Trajectory: 26 steps (boundary-aware grid)

# %% [markdown]
# ### Publication Figures

# %%
from matplotlib.gridspec import GridSpec

FIG_TAG = 'DynFM_spde'
FIG_DIR = os.path.join('figures', FIG_TAG)
os.makedirs(FIG_DIR, exist_ok=True)

obs_phys  = batch.input[0].float().numpy() * s_norm + m_norm
gt_phys   = batch.tgt[0].float().numpy()   * s_norm + m_norm
mean_phys = ens_mean.float().numpy()        * s_norm + m_norm
std_phys  = ens_std.float().numpy()         * s_norm
mbr0_phys = ensemble[0].float().numpy()     * s_norm + m_norm

vmax_f = float(np.nanpercentile(np.abs(gt_phys), 99))
vmin_f = -vmax_f
vmax_s = float(np.nanpercentile(std_phys, 99))

cmap_f = plt.cm.RdBu_r.copy(); cmap_f.set_bad('lightgray')
cmap_s = plt.cm.Reds.copy();   cmap_s.set_bad('lightgray')

def _save_strip(data, filename, vmin, vmax, cmap):
    nc = data.shape[0]
    FW, FH, CB_H = 2.0, 2.0, 0.28
    fig = plt.figure(figsize=(nc*FW, FH+CB_H+0.06))
    gs = GridSpec(2, nc, left=0.01, right=0.99, top=0.99, bottom=0.01,
                  height_ratios=[FH, CB_H], hspace=0.06, wspace=0.03)
    for c in range(nc):
        ax = fig.add_subplot(gs[0, c])
        ax.imshow(data[c], origin='lower', cmap=cmap, vmin=vmin, vmax=vmax)
        ax.axis('off')
    ax_cb = fig.add_subplot(gs[1, :])
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    sm.set_array([])
    fig.colorbar(sm, cax=ax_cb, orientation='horizontal').ax.tick_params(labelsize=9)
    fpath = os.path.join(FIG_DIR, f'{filename}.png')
    fig.savefig(fpath, dpi=200, bbox_inches='tight')
    print(f'  Saved: {fpath}'); plt.show()

for data, fname, vmin, vmax, cmap in [
    (obs_phys,  f'{FIG_TAG}_obs',      vmin_f, vmax_f, cmap_f),
    (gt_phys,   f'{FIG_TAG}_gt',       vmin_f, vmax_f, cmap_f),
    (mean_phys, f'{FIG_TAG}_mean',     vmin_f, vmax_f, cmap_f),
    (std_phys,  f'{FIG_TAG}_spread',   0,      vmax_s, cmap_s),
    (mbr0_phys, f'{FIG_TAG}_member0',  vmin_f, vmax_f, cmap_f),
]:
    _save_strip(data, fname, vmin, vmax, cmap)
# Out:
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
#   Saved: figures/DynFM_spde/DynFM_spde_obs.png
#   Saved: figures/DynFM_spde/DynFM_spde_gt.png
#   Saved: figures/DynFM_spde/DynFM_spde_mean.png
#   Saved: figures/DynFM_spde/DynFM_spde_spread.png
#   Saved: figures/DynFM_spde/DynFM_spde_member0.png

# %% [markdown]
# ### Transport Process — ODE trajectory
#
# Full trajectory from noise (t=0) through spin-up → IC → physical frames.
# Vertical dashed line marks the spin-up / physical boundary.

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np

# ── Build process tensor from traj_viz ─────────────────────────────────────────
proc = torch.stack(traj_viz, dim=0)[:, 0, 0, :, :]   # (n_actual+1, H, W)
nfr  = proc.shape[0]
t_viz = np.array(traj_times_viz)

def solver_time(si):
    return round(t_viz[si], 3)

# ── Physical frame indices (using traj_times_viz) ─────────────────────────────
SF = SPINUP_FRAC
frame_times = [SF + k * (1 - SF) / max(C - 1, 1) for k in range(C)]
phys_indices_list = [int(np.argmin(np.abs(t_viz - ft))) for ft in frame_times]

phys_frames    = proc[phys_indices_list].cpu().numpy()        # (C, H, W)
phys_times_lst = [solver_time(i) for i in phys_indices_list]
gt_phys_frames = batch.tgt[0].float().numpy()
obs_frames     = np.nan_to_num(batch.input[0].float().numpy(), nan=0.0)

vmin_all, vmax_all = -2, 2

# ── Build step_indices ─────────────────────────────────────────────────────────
phys0        = phys_indices_list[0]
N_SPINUP_COL = 4
spinup_steps = sorted({
    round(k * (phys0 - 1) / max(N_SPINUP_COL - 1, 1))
    for k in range(N_SPINUP_COL)
    if round(k * (phys0 - 1) / max(N_SPINUP_COL - 1, 1)) < phys0
})

phys_and_intermed = []
for k, pi in enumerate(phys_indices_list):
    phys_and_intermed.append(pi)
    if k < len(phys_indices_list) - 1:
        mid = int((pi + phys_indices_list[k + 1]) / 2)
        phys_and_intermed.append(mid)

step_indices         = spinup_steps + phys_and_intermed
step_indices_display = step_indices
n_top                = len(step_indices_display)

phys_step_set = set(phys_indices_list)
spinup_cols   = [j for j, si in enumerate(step_indices_display)
                 if si not in phys_step_set and t_viz[si] <= SF + 1e-6]

phys_col = [step_indices_display.index(pi) for pi in phys_indices_list]

print(f"step_indices ({n_top} cols) = {step_indices}")
print(f"phys_col                   = {phys_col}")
print(f"spinup_cols                = {spinup_cols}")

# ── Figure layout ──────────────────────────────────────────────────────────────
FIG_W   = max(n_top * 1.55, 18)
FIG_H   = 11.5
PUB_FS  = 11
TOP_FS  = 10

fig = plt.figure(figsize=(FIG_W, FIG_H))
gs  = fig.add_gridspec(
    4, n_top,
    height_ratios=[3, 2, 2, 2],
    hspace=0.25, wspace=0.04,
    left=0.10, right=0.98, top=0.93, bottom=0.14,
)

axes_top = [fig.add_subplot(gs[0, j]) for j in range(n_top)]
axes_mid = {k: fig.add_subplot(gs[1, col]) for k, col in enumerate(phys_col)}
axes_bot = {k: fig.add_subplot(gs[2, col]) for k, col in enumerate(phys_col)}
axes_obs = {k: fig.add_subplot(gs[3, col]) for k, col in enumerate(phys_col)}

# ── Row 0: transport strip ────────────────────────────────────────────────────
for j, si in enumerate(step_indices_display):
    ax    = axes_top[j]
    s_val = t_viz[si]
    ax.imshow(proc[si].cpu().numpy(), origin="lower",
              cmap="RdBu_r", vmin=vmin_all, vmax=vmax_all, interpolation="nearest")
    col_t = "steelblue" if s_val <= SF + 1e-6 else "tomato"
    ax.set_title(f"t={s_val:.2f}", fontsize=TOP_FS, color=col_t, pad=2, fontweight="bold")
    ax.axis("off")
    if si in phys_step_set:
        for sp in ax.spines.values():
            sp.set_visible(True); sp.set_edgecolor("limegreen"); sp.set_linewidth(2.5)

# ── Rows 1–3: prediction / GT / obs ──────────────────────────────────────────
for k in range(C):
    axes_mid[k].imshow(phys_frames[k], origin="lower", cmap="RdBu_r",
                       vmin=vmin_all, vmax=vmax_all, interpolation="nearest")
    axes_mid[k].axis("off")
    for sp in axes_mid[k].spines.values():
        sp.set_visible(True); sp.set_edgecolor("limegreen"); sp.set_linewidth(2)

    axes_bot[k].imshow(gt_phys_frames[k], origin="lower", cmap="RdBu_r",
                       vmin=vmin_all, vmax=vmax_all, interpolation="nearest")
    axes_bot[k].axis("off")

    axes_obs[k].imshow(obs_frames[k], origin="lower", cmap="RdBu_r",
                       vmin=vmin_all, vmax=vmax_all, interpolation="nearest")
    axes_obs[k].axis("off")

# ── Row labels ────────────────────────────────────────────────────────────────
fig.canvas.draw()
label_x = axes_top[0].get_position().x0 - 0.012
rows_meta = [
    (axes_top[0],  "Transport\nprocess"),
    (axes_mid[0],  "DynFM\nprediction"),
    (axes_bot[0],  "Ground\ntruth"),
    (axes_obs[0],  "Observations"),
]
for ax_ref, lbl in rows_meta:
    pos = ax_ref.get_position()
    yc  = (pos.y0 + pos.y1) / 2
    fig.text(label_x, yc, lbl, va="center", ha="right",
             fontsize=PUB_FS, color="black", fontweight="bold", rotation=0,
             fontfamily="DejaVu Sans")

# ── Arrows: transport strip → prediction row ─────────────────────────────────
for k, col in enumerate(phys_col):
    sb = axes_top[col].get_position()
    db = axes_mid[k].get_position()
    xm = (sb.x0 + sb.x1) / 2
    fig.add_artist(mpatches.FancyArrowPatch(
        (xm, sb.y0 - 0.003), (xm, db.y1 + 0.003),
        transform=fig.transFigure, arrowstyle="-|>",
        color="blueviolet", mutation_scale=10, linewidth=1.5,
    ))

# ── Spin-up brace above top strip ────────────────────────────────────────────
if spinup_cols:
    p0   = axes_top[spinup_cols[0]].get_position()
    p1   = axes_top[spinup_cols[-1]].get_position()
    xL, xR = p0.x0, p1.x1
    yT   = p0.y1 + 0.016
    th   = 0.007
    for xt in [xL, xR]:
        fig.add_artist(plt.Line2D([xt, xt], [yT, yT - th],
            transform=fig.transFigure, color="steelblue", linewidth=1.4, clip_on=False))
    fig.add_artist(plt.Line2D([xL, xR], [yT, yT],
        transform=fig.transFigure, color="steelblue", linewidth=1.4, clip_on=False))
    fig.text((xL + xR) / 2, yT + 0.003,
             f"Spin-up  (t ≤ {SF:.2f})",
             ha="center", va="bottom", fontsize=PUB_FS - 1, color="steelblue")

# ── Horizontal colorbar at bottom ────────────────────────────────────────────
cbar_ax = fig.add_axes([0.15, 0.04, 0.70, 0.018])
sm = plt.cm.ScalarMappable(cmap="RdBu_r",
                            norm=plt.Normalize(vmin=vmin_all, vmax=vmax_all))
sm.set_array([])
cbar = fig.colorbar(sm, cax=cbar_ax, orientation="horizontal")
cbar.set_label("Gaussian Process", fontsize=PUB_FS + 1, fontweight="bold")
cbar.ax.tick_params(labelsize=PUB_FS - 1)

fpath = os.path.join(FIG_DIR, f'{FIG_TAG}_transport.png')
fig.savefig(fpath, dpi=200, bbox_inches='tight')
print(f'  Saved: {fpath}')
plt.show()

# ── Variance collapse with per-frame GT stds ─────────────────────────────────
step_stds = np.array([proc[k].cpu().numpy().std() for k in range(nfr)])
gt_std    = batch.tgt[0].float().numpy().std()
gt_frame_stds = [batch.tgt[0, k].float().numpy().std() for k in range(C)]

fig2, ax2 = plt.subplots(figsize=(8, 3.5))
ax2.plot(t_viz, step_stds, marker="o", markersize=4, color="dimgray", label="Member 0 (trajectory)")
ax2.axhline(gt_std, color="green", linestyle="--", alpha=0.5, label=f"GT std (global) = {gt_std:.3f}")
ax2.axvspan(0.0, SF, alpha=0.10, color="steelblue",
            label=f"Spin-up (t ≤ {SF:.2f})")
ax2.axvspan(SF, 1.0, alpha=0.10, color="tomato", label="Physical regime")

for k, (ft, gs) in enumerate(zip(frame_times, gt_frame_stds)):
    lbl = f"GT frame stds" if k == 0 else None
    ax2.plot(ft, gs, marker='D', color='darkgreen', markersize=8, zorder=5, label=lbl)
    ax2.annotate(f'{gs:.3f}', (ft, gs), textcoords="offset points",
                 xytext=(0, 8), ha='center', fontsize=7, color='darkgreen')

for k, (ft, pi) in enumerate(zip(frame_times, phys_indices_list)):
    pred_std = step_stds[pi]
    lbl = f"Pred frame stds" if k == 0 else None
    ax2.plot(ft, pred_std, marker='s', color='red', markersize=7, zorder=5, label=lbl)
    ax2.annotate(f'{pred_std:.3f}', (ft, pred_std), textcoords="offset points",
                 xytext=(0, -12), ha='center', fontsize=7, color='red')

ax2.set_xlabel("ODE time  t  (0 = pure noise, 1 = final frame)", fontsize=PUB_FS)
ax2.set_ylabel("Spatial std", fontsize=PUB_FS)
ax2.set_title("Variance evolution — spin-up → physical", fontsize=PUB_FS + 1)
ax2.legend(fontsize=PUB_FS - 2, loc='upper left')
ax2.grid(True, alpha=0.3)
plt.tight_layout()
fpath2 = os.path.join(FIG_DIR, f'DynFM_spde_variance_collapse.png')
fig2.savefig(fpath2, dpi=200, bbox_inches='tight')
print(f'  Saved: {fpath2}')
plt.show()

print(f"\nStd step 0 (noise): {step_stds[0]:.4f}   Std last step: {step_stds[-1]:.4f}   GT std (global): {gt_std:.4f}")
print(f"Per-frame GT stds:  {['%.4f' % s for s in gt_frame_stds]}")
print(f"Per-frame pred stds: {['%.4f' % step_stds[pi] for pi in phys_indices_list]}")
# Out:
# step_indices (13 cols) = [0, 2, 4, 6, 7, 9, 11, 13, 16, 18, 21, 23, 25]
# phys_col                   = [4, 6, 8, 10, 12]
# spinup_cols                = [0, 1, 2, 3]
#   Saved: figures/DynFM_spde/DynFM_spde_transport.png
#   Saved: figures/DynFM_spde/DynFM_spde_variance_collapse.png
# Std step 0 (noise): 0.9969   Std last step: 1.3052   GT std (global): 0.9939
# Per-frame GT stds:  ['1.0020', '0.9968', '0.9932', '0.9867', '0.9887']
# Per-frame pred stds: ['0.8262', '1.0281', '1.1168', '1.2065', '1.3052']

# %% [markdown]
# ## Metrics — DynFM vs GT
#
# | Metric | Description |
# |---|---|
# | **Score** | $1 - \text{RMSE}/\sigma_{\text{GT}}$ |
# | **RMSE** | Root Mean Square Error |
# | **CRPS** | Continuous Ranked Probability Score |
# | **lambda_x** | Resolved scale at spectral score = 0.5 |

# %%
import sys
sys.path.append('../..')
from spectral_utils import radial_psd_2d, psd_spectral_score, resolved_scale

DX = 1.0   # pixel spacing

# ── Full test-set evaluation ─────────────────────────────────────────────
# Loops over EVERY batch of datamodule.test_dataloader() (not just the first
# one used for the illustrative figures above) and EVERY timestep of the
# assimilation window (not just T_EVAL=C//2), regenerating a fresh ensemble
# each time via the DynFM boundary-aware Heun sampler. This is the expensive
# part (N_SAMPLES x n_test_samples ODE integrations) -- N_SAMPLES was reduced
# from 50 to 20 in methods.yaml specifically to keep a full-test-set pass
# affordable. SSH_GF is a continuous z-scored field, so unlike SIC there is
# no MIZ-style domain restriction -- metrics are aggregated over the whole
# spatial domain.
_all = {'score': [], 'rmse': [], 'sigma_gt': [], 'sigma_pred': [], 'crps': [], 'lambda_x': []}
_n_pairs = 0

seed_everything(42)
for _tb in datamodule.test_dataloader():
    _gt_b = _tb.tgt.to(device=device, dtype=dtype)     # (B, C, H, W)
    _y_b  = _tb.input.to(device=device, dtype=dtype)    # (B, C, H, W)
    _Bb, _Cb, _Hb, _Wb = _gt_b.shape
    _valid_b   = ~torch.isnan(_gt_b)
    _obsmask_b = ~torch.isnan(_y_b)

    for _bi in range(_Bb):
        with torch.no_grad():
            _members = []
            for _s in range(N_SAMPLES):
                _noise = torch.randn(1, 1, _Hb, _Wb, device=device, dtype=dtype)
                _, _traj, _traj_times = dynfm_heun_sample(
                    ema_unet, _noise, _y_b[_bi:_bi + 1], n_steps=N_STEPS,
                    spinup_frac=SPINUP_FRAC, precondition=True,
                )
                _frames = extract_dynfm_frames(_traj, _traj_times, _Cb, SPINUP_FRAC)
                _member = torch.cat(_frames, dim=1)   # (1, C, H, W)
                _members.append(_member.cpu())
        _ens_b = torch.cat(_members, dim=0)            # (N, C, H, W) normalised
        _ens_mean_b = _ens_b.mean(0)                    # (C, H, W)

        for _t in range(_Cb):
            _valid_t = _valid_b[_bi, _t].cpu().numpy()
            if _valid_t.sum() < 10:
                continue
            _gt_p   = _gt_b[_bi, _t].float().cpu().numpy() * s_norm + m_norm
            _mean_p = _ens_mean_b[_t].float().numpy()      * s_norm + m_norm
            _ens_p  = _ens_b[:, _t].float().numpy()        * s_norm + m_norm

            _gt_v, _pred_v = _gt_p[_valid_t], _mean_p[_valid_t]
            _sigma = float(np.std(_gt_v))
            if _sigma <= 0:
                continue
            _rmse  = float(np.sqrt(np.mean((_pred_v - _gt_v) ** 2)))
            _score = 1.0 - _rmse / _sigma
            _sigma_pred = float(np.std(_pred_v))

            _gt_f   = np.nan_to_num(_gt_p,   nan=0.0)
            _pred_f = np.nan_to_num(_mean_p, nan=0.0)
            _wl, _, _, _spec = psd_spectral_score(_pred_f, _gt_f, dx=DX)
            _lam = resolved_scale(_wl, _spec, threshold=0.5)

            _crps_val = np.nan
            if HAS_PROPERSCORING:
                _obs_t  = _obsmask_b[_bi, _t].cpu().numpy()
                _obs_ij = np.argwhere(_valid_t & _obs_t)
                if len(_obs_ij) > 0:
                    _stride = max(1, len(_obs_ij) // 50)   # subsample -- CRPS is O(n) Python loop
                    _crps_val = float(np.mean([
                        crps_ensemble(float(_gt_p[i, j]), _ens_p[:, i, j])
                        for i, j in _obs_ij[::_stride]
                    ]))

            _all['score'].append(_score)
            _all['rmse'].append(_rmse)
            _all['sigma_gt'].append(_sigma)
            _all['sigma_pred'].append(_sigma_pred)
            _all['crps'].append(_crps_val)
            _all['lambda_x'].append(_lam)
            _n_pairs += 1

print(f"Evaluated {_n_pairs} (test sample, timestep) pairs across the full test set")

def _agg(vals):
    a = np.asarray(vals, dtype=float)
    a = a[~np.isnan(a)]
    return (float(np.mean(a)), float(np.std(a))) if len(a) else (np.nan, np.nan)

_score_m, _score_s = _agg(_all['score'])
_rmse_m, _rmse_s = _agg(_all['rmse'])
_sgt_m, _sgt_s = _agg(_all['sigma_gt'])
_spr_m, _spr_s = _agg(_all['sigma_pred'])
_crps_m, _crps_s = _agg(_all['crps'])
_lam_m, _lam_s = _agg(_all['lambda_x'])

row_dynfm = {
    'Method'    : 'DynFM (ens. mean, full test set)',
    'Score'     : f'{_score_m:.3f} ± {_score_s:.3f}',
    'RMSE'      : f'{_rmse_m:.4f} ± {_rmse_s:.4f}',
    'sigma_GT'  : f'{_sgt_m:.4f} ± {_sgt_s:.4f}',
    'sigma_pred': f'{_spr_m:.4f} ± {_spr_s:.4f}',
    'CRPS'      : f'{_crps_m:.4f} ± {_crps_s:.4f}' if not np.isnan(_crps_m) else '--',
    'lambda_x'  : f'{_lam_m:.1f} ± {_lam_s:.1f}' if not np.isnan(_lam_m) else '?',
}
df_metrics = pd.DataFrame([row_dynfm]).set_index('Method')
df_metrics.columns = ['Score','RMSE','sigma_GT','sigma_pred','CRPS','lambda_x [px]']
print(f'\n## Metrics -- full test set (whole domain), n={_n_pairs} (sample,t) pairs\n')
display(df_metrics)

# ── Illustrative PSD plot (single example, T_EVAL=C//2 of the first test
# batch, same one used by the figures above) -- qualitative check only, NOT
# the quantitative table (that's df_metrics above, full test set now).
T_EVAL = C // 2
gt_p_ex   = batch.tgt[0, T_EVAL].float().numpy() * s_norm + m_norm
mean_p_ex = ens_mean[T_EVAL].float().numpy()      * s_norm + m_norm

wl_dynfm, _, _, spec_dynfm = psd_spectral_score(mean_p_ex, gt_p_ex, dx=DX)
_, psd_gt_r, psd_err_dynfm, _ = psd_spectral_score(mean_p_ex, gt_p_ex, dx=DX)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))
ax = axes[0]
v = np.isfinite(wl_dynfm) & np.isfinite(psd_gt_r) & (psd_gt_r > 0)
ax.semilogy(wl_dynfm[v], psd_gt_r[v], 'k-', lw=2, label='GT')
ve = np.isfinite(wl_dynfm) & np.isfinite(psd_err_dynfm) & (psd_err_dynfm > 0)
ax.semilogy(wl_dynfm[ve], psd_err_dynfm[ve], 'C1--', lw=1.5, label='DynFM error')
ax.set_xlabel('Wavelength'); ax.set_ylabel('PSD')
ax.set_title(f'PSD (illustrative, t={T_EVAL})')
ax.legend(); ax.grid(True, alpha=0.3)

ax = axes[1]
lambda_x_dynfm = resolved_scale(wl_dynfm, spec_dynfm)
lbl = f'DynFM (lambda_x={lambda_x_dynfm:.1f})' if not np.isnan(lambda_x_dynfm) else 'DynFM'
vs = np.isfinite(wl_dynfm) & np.isfinite(spec_dynfm)
ax.plot(wl_dynfm[vs], spec_dynfm[vs], 'C1-', lw=2, label=lbl)
ax.axhline(0.5, color='gray', ls='--'); ax.set_ylim(-0.3, 1.05)
ax.set_xlabel('Wavelength'); ax.set_ylabel('Spectral score')
ax.set_title('Spectral score (illustrative)')
ax.legend(); ax.grid(True, alpha=0.3)
plt.tight_layout(); plt.show()
# Out:
# [rank: 0] Global seed set to 42
# Evaluated 225 (test sample, timestep) pairs across the full test set
#
# ## Metrics -- full test set (whole domain), n=225 (sample,t) pairs
#                                            Score             RMSE  \
# Method
# DynFM (ens. mean, full test set)  -0.088 ± 0.166  0.2711 ± 0.0419
#
#                                          sigma_GT       sigma_pred  \
# Method
# DynFM (ens. mean, full test set)  0.2492 ± 0.0058  0.2743 ± 0.0456
#
#                                              CRPS lambda_x [px]
# Method
# DynFM (ens. mean, full test set)  0.0229 ± 0.0090   39.3 ± 28.7

# %%
# --- metrics serialization (patch_notebook_params.py) ---
import os
os.makedirs(os.path.dirname(METRICS_CSV) or '.', exist_ok=True)
_df_out = df_metrics.reset_index() if df_metrics.index.name == 'Method' else df_metrics
_df_out.to_csv(METRICS_CSV, index=False)
print(f'Metrics written to {METRICS_CSV}')
# Out:
# Metrics written to /Odyssey/private/m19beauc/4dvarnet-starter-devs/consistency/sbatch_submission/results/GP/DynFM_metrics_train.csv
