# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [15]</a>'.</span>

# %%
# --- parameters (patch_notebook_params.py) ---
MAX_EPOCHS = 2000
N_SAMPLES = 10           # run_metrics.py forces 50 for generative methods
RESET_TRAINING = False
CUDA_VISIBLE_DEVICES = "0"
METRICS_CSV = "results/metrics.csv"

# %%
# Parameters
MAX_EPOCHS = 2000
N_SAMPLES = 1
RESET_TRAINING = False
CUDA_VISIBLE_DEVICES = "0"
METRICS_CSV = "/Odyssey/private/m19beauc/4dvarnet-starter-devs/consistency/sbatch_submission/results/GP/FM_metrics_train.csv"

# %%
# --- epoch heartbeat (patch_notebook_params.py) ---
import pytorch_lightning as _pl

class EpochHeartbeat(_pl.Callback):
    """Prints one clear progress line every `every_n_epochs` epochs, so
    sbatch logs show training progress without the noise of a per-batch
    tqdm progress bar (which doesn't render well once redirected to a
    plain log file).    """

    def __init__(self, every_n_epochs: int = 1):
        self.every_n_epochs = every_n_epochs

    def on_train_epoch_end(self, trainer, pl_module):
        epoch = trainer.current_epoch + 1
        if epoch % self.every_n_epochs != 0 and epoch != trainer.max_epochs:
            return
        parts = []
        for k, v in sorted(trainer.callback_metrics.items()):
            try:
                parts.append(f'{k}={float(v):.4f}')
            except (TypeError, ValueError):
                pass
        print(f'[progress] epoch {epoch}/{trainer.max_epochs} | ' + ' | '.join(parts), flush=True)

# %% [markdown]
# ## 🛠️ Setup & Imports

# %%
# !nvidia-smi
# Out:
# Sun Aug  9 14:49:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.172.08             Driver Version: 570.172.08     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 NVL                Off |   00000000:E3:00.0 Off |                    0 |
# | N/A   81C    P0            259W /  400W |   64329MiB /  95830MiB |    100%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A          959693      C   python                                64320MiB |
# +-----------------------------------------------------------------------------------------+

# %%
import os; os.environ["CUDA_VISIBLE_DEVICES"] = CUDA_VISIBLE_DEVICES

# %%
import math
import os
import zipfile
import glob
from dataclasses import dataclass
from typing import Optional, Tuple

import numpy as np
import xarray as xr
import pandas as pd
import torch
from pytorch_lightning import LightningModule, Trainer, seed_everything
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from matplotlib import pyplot as plt
from torchinfo import summary

import sys
sys.path.append('../..')    # → consistency/  (pour flowmatching_models_FM)
sys.path.append('../../..')  # → 4dvarnet-starter-devs/  (pour src)

from flowmatching_models_FM import (
    UNetFM, UNetFMConfig,
    LitFlowMatchingModel, LitFMConfig,
    LogScaleModel,
    heun_sample, euler_sample,
    neglogpdf, neglogcdf,
    sample_uniform_time, masked_average,
)

try:
    from properscoring import crps_ensemble
    HAS_PROPERSCORING = True
except ImportError:
    HAS_PROPERSCORING = False
    print("⚠️  properscoring non installé — CRPS désactivé. Installer avec: pip install properscoring")

# %% [markdown]
# ## 🧠 Implementation
#
# ### DataModule — SPDE Diffusion Dataset

# %%
from src.data_notebook_spde import SPDEDataModule

SPDE_PATH = "../../../data/SPDE_diffusion_dataset_1.nc"

ds_inspect = xr.open_dataset(SPDE_PATH)
print(ds_inspect)
print("\nVariables:")
for v in ds_inspect.data_vars:
    print(f"  {v}: {ds_inspect[v].dims}  shape={ds_inspect[v].shape}  dtype={ds_inspect[v].dtype}")
ds_inspect.close()
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 300, lat: 128, lon: 128)
# Coordinates:
#   * lon        (lon) int64 0 1 2 3 4 5 6 7 8 ... 120 121 122 123 124 125 126 127
#   * lat        (lat) int64 0 1 2 3 4 5 6 7 8 ... 120 121 122 123 124 125 126 127
#   * time       (time) int64 0 1 2 3 4 5 6 7 ... 292 293 294 295 296 297 298 299
# Data variables:
#     x          (time, lat, lon) float32 ...
#     y          (time, lat, lon) float32 ...
#     OI         (time, lat, lon) float64 ...
#     H11        (lat, lon) float32 ...
#     H22        (lat, lon) float32 ...
#     H12        (lat, lon) float32 ...
#     Time       (time) int64 ...
#     longitude  (lon) int64 ...
#     latitude   (lat) int64 ...
# Attributes:
#     description:  SPDE-based diffusion GP
#
# Variables:
#   x: ('time', 'lat', 'lon')  shape=(300, 128, 128)  dtype=float32
#   y: ('time', 'lat', 'lon')  shape=(300, 128, 128)  dtype=float32
#   OI: ('time', 'lat', 'lon')  shape=(300, 128, 128)  dtype=float64
#   H11: ('lat', 'lon')  shape=(128, 128)  dtype=float32
#   H22: ('lat', 'lon')  shape=(128, 128)  dtype=float32
#   H12: ('lat', 'lon')  shape=(128, 128)  dtype=float32
#   Time: ('time',)  shape=(300,)  dtype=int64
#   longitude: ('lon',)  shape=(128,)  dtype=int64
#   latitude: ('lat',)  shape=(128,)  dtype=int64

# %%
datamodule = SPDEDataModule(
    path=SPDE_PATH,
    window_size=5,
    stride=1,
    train_ratio=0.7,
    val_ratio=0.15,
    dl_kw={"batch_size": 1, "num_workers": 1},
)
datamodule.setup()

sample = datamodule.train_ds[0]
C = datamodule.window_size
print(f"window_size (C) = {C}")
print(f"TrainingItem shapes — input (y): {sample.input.shape}, tgt (x): {sample.tgt.shape}")

fig, axes = plt.subplots(1, C, figsize=(3 * C, 3))
for t_idx, ax in enumerate(axes):
    ax.imshow(sample.tgt[t_idx], origin="lower", cmap="RdBu_r")
    ax.set_title(f"x GT — t={t_idx}", fontsize=8)
    ax.axis("off")
plt.suptitle("Training sample — ground truth x", y=1.01)
plt.tight_layout(); plt.show()

fig, axes = plt.subplots(1, C, figsize=(3 * C, 3))
for t_idx, ax in enumerate(axes):
    ax.imshow(sample.input[t_idx], origin="lower", cmap="RdBu_r")
    ax.set_title(f"y obs — t={t_idx}", fontsize=8)
    ax.axis("off")
plt.suptitle("Training sample — observations y (NaN = non-observé)", y=1.01)
plt.tight_layout(); plt.show()
# Out:
# [SPDEDataModule] T=300, window=5, stride=1 → 296 windows: train=207, val=44, test=45
# [SPDEDataModule] Norm stats (mean, std): (-0.00018237734911963344, 0.249156191945076)
# window_size (C) = 5
# TrainingItem shapes — input (y): (5, 128, 128), tgt (x): (5, 128, 128)

# %% [markdown]
# ### UNetFM — Velocity-prediction network
#
# The network takes as input the concatenation `(x_noisy, y_filled, mask_obs)` → `3×C` input channels,
# and outputs a velocity field of `C` channels.
#
# A reflection padding to the nearest multiple of 8 is applied at input and removed at output.
# The noise level `σ` is encoded as a sinusoidal embedding injected into each UNetBlock via AdaGN.

# %%
C = datamodule.window_size
cfg = UNetFMConfig(channels=C)
net = UNetFM(cfg)

summary(
    net,
    input_size=(
        (1, C, 100, 100),   # x_t  — noisy interpolant
        (1, C, 100, 100),   # y    — observations (NaN tolerated)
        (1,),               # t    — pseudo-time scalar
    ),
)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# UNetFM                                        [1, 5, 100, 100]          --
# ├─Conv2d: 1-1                                 [1, 64, 104, 104]         8,704
# ├─TimeEmbedding: 1-2                          [1, 128, 1, 1]            64
# │    └─Sequential: 2-1                        [1, 128, 1, 1]            --
# │    │    └─Linear: 3-1                       [1, 512]                  66,048
# │    │    └─SiLU: 3-2                         [1, 512]                  --
# │    │    └─Linear: 3-3                       [1, 128]                  65,664
# │    │    └─Rearrange: 3-4                    [1, 128, 1, 1]            --
# ├─ModuleList: 1-3                             --                        --
# │    └─UNetBlock: 2-2                         [1, 64, 104, 104]         --
# │    │    └─Sequential: 3-5                   [1, 64, 104, 104]         37,056
# │    │    └─Sequential: 3-6                   [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-7                   [1, 64, 104, 104]         37,056
# │    │    └─Conv2d: 3-8                       [1, 64, 104, 104]         4,160
# │    └─UNetBlock: 2-3                         [1, 64, 104, 104]         --
# │    │    └─Sequential: 3-9                   [1, 64, 104, 104]         37,056
# │    │    └─Sequential: 3-10                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-11                  [1, 64, 104, 104]         37,056
# │    │    └─Conv2d: 3-12                      [1, 64, 104, 104]         4,160
# │    └─Downsample: 2-4                        [1, 64, 52, 52]           --
# │    │    └─Sequential: 3-13                  [1, 64, 52, 52]           16,448
# │    └─UNetBlock: 2-5                         [1, 128, 52, 52]          --
# │    │    └─Sequential: 3-14                  [1, 128, 52, 52]          73,984
# │    │    └─Sequential: 3-15                  [1, 128, 1, 1]            16,512
# │    │    └─Sequential: 3-16                  [1, 128, 52, 52]          147,840
# │    │    └─Conv2d: 3-17                      [1, 128, 52, 52]          8,320
# │    └─UNetBlock: 2-6                         [1, 128, 52, 52]          --
# │    │    └─Sequential: 3-18                  [1, 128, 52, 52]          147,840
# │    │    └─Sequential: 3-19                  [1, 128, 1, 1]            16,512
# │    │    └─Sequential: 3-20                  [1, 128, 52, 52]          147,840
# │    │    └─Conv2d: 3-21                      [1, 128, 52, 52]          16,512
# │    └─Downsample: 2-7                        [1, 128, 26, 26]          --
# │    │    └─Sequential: 3-22                  [1, 128, 26, 26]          65,664
# ├─ModuleList: 1-4                             --                        --
# │    └─UNetBlockWithSelfAttention: 2-8        [1, 256, 26, 26]          --
# │    │    └─UNetBlock: 3-23                   [1, 256, 26, 26]          952,064
# │    │    └─SelfAttention: 3-24               [1, 256, 26, 26]          328,960
# │    └─UNetBlockWithSelfAttention: 2-9        [1, 256, 26, 26]          --
# │    │    └─UNetBlock: 3-25                   [1, 256, 26, 26]          1,280,000
# │    │    └─SelfAttention: 3-26               [1, 256, 26, 26]          328,960
# │    └─UNetBlockWithSelfAttention: 2-10       [1, 256, 26, 26]          --
# │    │    └─UNetBlock: 3-27                   [1, 256, 26, 26]          1,280,000
# │    │    └─SelfAttention: 3-28               [1, 256, 26, 26]          328,960
# │    └─UNetBlockWithSelfAttention: 2-11       [1, 256, 26, 26]          --
# │    │    └─UNetBlock: 3-29                   [1, 256, 26, 26]          1,280,000
# │    │    └─SelfAttention: 3-30               [1, 256, 26, 26]          328,960
# │    └─Downsample: 2-12                       [1, 256, 13, 13]          --
# │    │    └─Sequential: 3-31                  [1, 256, 13, 13]          262,400
# │    └─UNetBlockWithSelfAttention: 2-13       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-32                   [1, 256, 13, 13]          1,280,000
# │    │    └─SelfAttention: 3-33               [1, 256, 13, 13]          328,960
# │    └─UNetBlockWithSelfAttention: 2-14       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-34                   [1, 256, 13, 13]          1,280,000
# │    │    └─SelfAttention: 3-35               [1, 256, 13, 13]          328,960
# │    └─UNetBlockWithSelfAttention: 2-15       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-36                   [1, 256, 13, 13]          1,280,000
# │    │    └─SelfAttention: 3-37               [1, 256, 13, 13]          328,960
# │    └─UNetBlockWithSelfAttention: 2-16       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-38                   [1, 256, 13, 13]          1,280,000
# │    │    └─SelfAttention: 3-39               [1, 256, 13, 13]          328,960
# ├─ModuleList: 1-5                             --                        --
# │    └─UNetBlockWithSelfAttention: 2-17       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-40                   [1, 256, 13, 13]          1,935,872
# │    │    └─SelfAttention: 3-41               [1, 256, 13, 13]          328,960
# │    └─UNetBlockWithSelfAttention: 2-18       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-42                   [1, 256, 13, 13]          1,935,872
# │    │    └─SelfAttention: 3-43               [1, 256, 13, 13]          328,960
# │    └─UNetBlockWithSelfAttention: 2-19       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-44                   [1, 256, 13, 13]          1,935,872
# │    │    └─SelfAttention: 3-45               [1, 256, 13, 13]          328,960
# │    └─UNetBlockWithSelfAttention: 2-20       [1, 256, 13, 13]          --
# │    │    └─UNetBlock: 3-46                   [1, 256, 13, 13]          1,935,872
# │    │    └─SelfAttention: 3-47               [1, 256, 13, 13]          328,960
# │    └─Upsample: 2-21                         [1, 256, 26, 26]          --
# │    │    └─Sequential: 3-48                  [1, 256, 26, 26]          590,080
# │    └─UNetBlockWithSelfAttention: 2-22       [1, 256, 26, 26]          --
# │    │    └─UNetBlock: 3-49                   [1, 256, 26, 26]          1,935,872
# │    │    └─SelfAttention: 3-50               [1, 256, 26, 26]          328,960
# │    └─UNetBlockWithSelfAttention: 2-23       [1, 256, 26, 26]          --
# │    │    └─UNetBlock: 3-51                   [1, 256, 26, 26]          1,935,872
# │    │    └─SelfAttention: 3-52               [1, 256, 26, 26]          328,960
# │    └─UNetBlockWithSelfAttention: 2-24       [1, 256, 26, 26]          --
# │    │    └─UNetBlock: 3-53                   [1, 256, 26, 26]          1,935,872
# │    │    └─SelfAttention: 3-54               [1, 256, 26, 26]          328,960
# │    └─UNetBlockWithSelfAttention: 2-25       [1, 128, 26, 26]          --
# │    │    └─UNetBlock: 3-55                   [1, 128, 26, 26]          820,992
# │    │    └─SelfAttention: 3-56               [1, 128, 26, 26]          82,560
# ├─ModuleList: 1-6                             --                        --
# │    └─Upsample: 2-26                         [1, 128, 52, 52]          --
# │    │    └─Sequential: 3-57                  [1, 128, 52, 52]          147,584
# │    └─UNetBlock: 2-27                        [1, 128, 52, 52]          --
# │    │    └─Sequential: 3-58                  [1, 128, 52, 52]          295,552
# │    │    └─Sequential: 3-59                  [1, 128, 1, 1]            16,512
# │    │    └─Sequential: 3-60                  [1, 128, 52, 52]          147,840
# │    │    └─Conv2d: 3-61                      [1, 128, 52, 52]          32,896
# │    └─UNetBlock: 2-28                        [1, 64, 52, 52]           --
# │    │    └─Sequential: 3-62                  [1, 64, 52, 52]           148,032
# │    │    └─Sequential: 3-63                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-64                  [1, 64, 52, 52]           37,056
# │    │    └─Conv2d: 3-65                      [1, 64, 52, 52]           16,448
# │    └─Upsample: 2-29                         [1, 64, 104, 104]         --
# │    │    └─Sequential: 3-66                  [1, 64, 104, 104]         36,928
# │    └─UNetBlock: 2-30                        [1, 64, 104, 104]         --
# │    │    └─Sequential: 3-67                  [1, 64, 104, 104]         74,048
# │    │    └─Sequential: 3-68                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-69                  [1, 64, 104, 104]         37,056
# │    │    └─Conv2d: 3-70                      [1, 64, 104, 104]         8,256
# │    └─UNetBlock: 2-31                        [1, 64, 104, 104]         --
# │    │    └─Sequential: 3-71                  [1, 64, 104, 104]         74,048
# │    │    └─Sequential: 3-72                  [1, 64, 1, 1]             8,256
# │    │    └─Sequential: 3-73                  [1, 64, 104, 104]         37,056
# │    │    └─Conv2d: 3-74                      [1, 64, 104, 104]         8,256
# ├─Conv2d: 1-7                                 [1, 5, 104, 104]          2,885
# ===============================================================================================
# Total params: 32,269,829
# Trainable params: 32,269,765
# Non-trainable params: 64
# Total mult-adds (Units.GIGABYTES): 20.33
# ===============================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 358.70
# Params size (MB): 129.08
# Estimated Total Size (MB): 488.18
# ===============================================================================================

# %% [markdown]
# ### LightningModule — LitFlowMatchingModel
#
# Uses the linear interpolant of Flow Matching: $x_t = (1-t)\,x_0 + t\,x_1$, $v^* = x_1 - x_0$.
#
# The training step:
# 1. Sample $t \sim \mathcal{U}(0,1)$
# 2. Build $x_t = (1-t)\,\epsilon + t\,x_0$ where $\epsilon \sim \mathcal{N}(0, I)$
# 3. Train the network to predict the velocity $v^* = x_0 - \epsilon$

# %%
# LitFlowMatchingModel is fully self-contained in flowmatching_models_FM.py.
# Inspect its docstring:
help(LitFlowMatchingModel)
# Out:
# Help on class LitFlowMatchingModel in module flowmatching_models_FM:
#
# class LitFlowMatchingModel(pytorch_lightning.core.module.LightningModule)
#  |  LitFlowMatchingModel(network: 'UNetFM', config: 'LitFMConfig', n_log_scale_embedding: 'int' = 128) -> 'None'
#  |
#  |  Flow Matching Lightning module for the SPDE dataset.
#  |
#  |  Parameters
#  |  ----------
#  |  network     : ``UNetFM`` (student / live model)
#  |  config      : ``LitFMConfig``
#  |  n_log_scale_embedding : embedding dim for the ``LogScaleModel``
#  |
#  |  Method resolution order:
#  |      LitFlowMatchingModel
#  |      pytorch_lightning.core.module.LightningModule
#  |      lightning_fabric.utilities.device_dtype_mixin._DeviceDtypeModuleMixin
#  |      pytorch_lightning.core.mixins.hparams_mixin.HyperparametersMixin
#  |      pytorch_lightning.core.hooks.ModelHooks
#  |      pytorch_lightning.core.hooks.DataHooks
#  |      pytorch_lightning.core.hooks.CheckpointHooks
#  |      torch.nn.modules.module.Module
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, network: 'UNetFM', config: 'LitFMConfig', n_log_scale_embedding: 'int' = 128) -> 'None'
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  configure_optimizers(self)
#  |      Choose what optimizers and learning-rate schedulers to use in your optimization. Normally you'd need one.
#  |      But in the case of GANs or similar you might have multiple. Optimization with multiple optimizers only works in
#  |      the manual optimization mode.
#  |
#  |      Return:
#  |          Any of these 6 options.
#  |
#  |          - **Single optimizer**.
#  |          - **List or Tuple** of optimizers.
#  |          - **Two lists** - The first list has multiple optimizers, and the second has multiple LR schedulers
#  |            (or multiple ``lr_scheduler_config``).
#  |          - **Dictionary**, with an ``"optimizer"`` key, and (optionally) a ``"lr_scheduler"``
#  |            key whose value is a single LR scheduler or ``lr_scheduler_config``.
#  |          - **None** - Fit will run without any optimizer.
#  |
#  |      The ``lr_scheduler_config`` is a dictionary which contains the scheduler and its associated configuration.
#  |      The default configuration is shown below.
#  |
#  |      .. code-block:: python
#  |
#  |          lr_scheduler_config = {
#  |              # REQUIRED: The scheduler instance
#  |              "scheduler": lr_scheduler,
#  |              # The unit of the scheduler's step size, could also be 'step'.
#  |              # 'epoch' updates the scheduler on epoch end whereas 'step'
#  |              # updates it after a optimizer update.
#  |              "interval": "epoch",
#  |              # How many epochs/steps should pass between calls to
#  |              # `scheduler.step()`. 1 corresponds to updating the learning
#  |              # rate after every epoch/step.
#  |              "frequency": 1,
#  |              # Metric to to monitor for schedulers like `ReduceLROnPlateau`
#  |              "monitor": "val_loss",
#  |              # If set to `True`, will enforce that the value specified 'monitor'
#  |              # is available when the scheduler is updated, thus stopping
#  |              # training if not found. If set to `False`, it will only produce a warning
#  |              "strict": True,
#  |              # If using the `LearningRateMonitor` callback to monitor the
#  |              # learning rate progress, this keyword can be used to specify
#  |              # a custom logged name
#  |              "name": None,
#  |          }
#  |
#  |      When there are schedulers in which the ``.step()`` method is conditioned on a value, such as the
#  |      :class:`torch.optim.lr_scheduler.ReduceLROnPlateau` scheduler, Lightning requires that the
#  |      ``lr_scheduler_config`` contains the keyword ``"monitor"`` set to the metric name that the scheduler
#  |      should be conditioned on.
#  |
#  |      .. testcode::
#  |
#  |          # The ReduceLROnPlateau scheduler requires a monitor
#  |          def configure_optimizers(self):
#  |              optimizer = Adam(...)
#  |              return {
#  |                  "optimizer": optimizer,
#  |                  "lr_scheduler": {
#  |                      "scheduler": ReduceLROnPlateau(optimizer, ...),
#  |                      "monitor": "metric_to_track",
#  |                      "frequency": "indicates how often the metric is updated"
#  |                      # If "monitor" references validation metrics, then "frequency" should be set to a
#  |                      # multiple of "trainer.check_val_every_n_epoch".
#  |                  },
#  |              }
#  |
#  |
#  |          # In the case of two optimizers, only one using the ReduceLROnPlateau scheduler
#  |          def configure_optimizers(self):
#  |              optimizer1 = Adam(...)
#  |              optimizer2 = SGD(...)
#  |              scheduler1 = ReduceLROnPlateau(optimizer1, ...)
#  |              scheduler2 = LambdaLR(optimizer2, ...)
#  |              return (
#  |                  {
#  |                      "optimizer": optimizer1,
#  |                      "lr_scheduler": {
#  |                          "scheduler": scheduler1,
#  |                          "monitor": "metric_to_track",
#  |                      },
#  |                  },
#  |                  {"optimizer": optimizer2, "lr_scheduler": scheduler2},
#  |              )
#  |
#  |      Metrics can be made available to monitor by simply logging it using
#  |      ``self.log('metric_to_track', metric_val)`` in your :class:`~pytorch_lightning.core.module.LightningModule`.
#  |
#  |      Note:
#  |          Some things to know:
#  |
#  |          - Lightning calls ``.backward()`` and ``.step()`` automatically in case of automatic optimization.
#  |          - If a learning rate scheduler is specified in ``configure_optimizers()`` with key
#  |            ``"interval"`` (default "epoch") in the scheduler configuration, Lightning will call
#  |            the scheduler's ``.step()`` method automatically in case of automatic optimization.
#  |          - If you use 16-bit precision (``precision=16``), Lightning will automatically handle the optimizer.
#  |          - If you use :class:`torch.optim.LBFGS`, Lightning handles the closure function automatically for you.
#  |          - If you use multiple optimizers, you will have to switch to 'manual optimization' mode and step them
#  |            yourself.
#  |          - If you need to control how often the optimizer steps, override the :meth:`optimizer_step` hook.
#  |
#  |  on_fit_start(self) -> 'None'
#  |      Called at the very beginning of fit.
#  |
#  |      If on DDP it is called on every process
#  |
#  |  on_train_batch_end(self, outputs, batch, batch_idx: 'int') -> 'None'
#  |      Called in the training loop after the batch.
#  |
#  |      Args:
#  |          outputs: The outputs of training_step(x)
#  |          batch: The batched data as it is returned by the training DataLoader.
#  |          batch_idx: the index of the batch
#  |
#  |  on_train_epoch_end(self) -> 'None'
#  |      Called in the training loop at the very end of the epoch.
#  |
#  |      To access all batch outputs at the end of the epoch, you can cache step outputs as an attribute of the
#  |      :class:`~pytorch_lightning.LightningModule` and access them in this hook:
#  |
#  |      .. code-block:: python
#  |
#  |          class MyLightningModule(L.LightningModule):
#  |              def __init__(self):
#  |                  super().__init__()
#  |                  self.training_step_outputs = []
#  |
#  |              def training_step(self):
#  |                  loss = ...
#  |                  self.training_step_outputs.append(loss)
#  |                  return loss
#  |
#  |              def on_train_epoch_end(self):
#  |                  # do something with all training_step outputs, for example:
#  |                  epoch_mean = torch.stack(self.training_step_outputs).mean()
#  |                  self.log("training_epoch_mean", epoch_mean)
#  |                  # free up the memory
#  |                  self.training_step_outputs.clear()
#  |
#  |  training_step(self, batch, batch_idx: 'int')
#  |      Here you compute and return the training loss and some additional metrics for e.g. the progress bar or
#  |      logger.
#  |
#  |      Args:
#  |          batch (:class:`~torch.Tensor` | (:class:`~torch.Tensor`, ...) | [:class:`~torch.Tensor`, ...]):
#  |              The output of your :class:`~torch.utils.data.DataLoader`. A tensor, tuple or list.
#  |          batch_idx (``int``): Integer displaying index of this batch
#  |
#  |      Return:
#  |          Any of.
#  |
#  |          - :class:`~torch.Tensor` - The loss tensor
#  |          - ``dict`` - A dictionary. Can include any keys, but must include the key ``'loss'``
#  |          - ``None`` - Training will skip to the next batch. This is only for automatic optimization.
#  |              This is not supported for multi-GPU, TPU, IPU, or DeepSpeed.
#  |
#  |      In this step you'd normally do the forward pass and calculate the loss for a batch.
#  |      You can also do fancier things like multiple forward passes or something model specific.
#  |
#  |      Example::
#  |
#  |          def training_step(self, batch, batch_idx):
#  |              x, y, z = batch
#  |              out = self.encoder(x)
#  |              loss = self.loss(out, x)
#  |              return loss
#  |
#  |      To use multiple optimizers, you can switch to 'manual optimization' and control their stepping:
#  |
#  |      .. code-block:: python
#  |
#  |          def __init__(self):
#  |              super().__init__()
#  |              self.automatic_optimization = False
#  |
#  |
#  |          # Multiple optimizers (e.g.: GANs)
#  |          def training_step(self, batch, batch_idx):
#  |              opt1, opt2 = self.optimizers()
#  |
#  |              # do training_step with encoder
#  |              ...
#  |              opt1.step()
#  |              # do training_step with decoder
#  |              ...
#  |              opt2.step()
#  |
#  |      Note:
#  |          When ``accumulate_grad_batches`` > 1, the loss returned here will be automatically
#  |          normalized by ``accumulate_grad_batches`` internally.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pytorch_lightning.core.module.LightningModule:
#  |
#  |  __getstate__(self) -> Dict[str, Any]
#  |      Helper for pickle.
#  |
#  |  all_gather(self, data: Union[torch.Tensor, Dict, List, Tuple], group: Optional[Any] = None, sync_grads: bool = False) -> Union[torch.Tensor, Dict, List, Tuple]
#  |      Gather tensors or collections of tensors from multiple processes.
#  |
#  |      This method needs to be called on all processes. Failing to do so will cause your program to stall forever.
#  |
#  |      Args:
#  |          data: int, float, tensor of shape (batch, ...), or a (possibly nested) collection thereof.
#  |          group: the process group to gather results from. Defaults to all processes (world)
#  |          sync_grads: flag that allows users to synchronize gradients for the all_gather operation
#  |
#  |      Return:
#  |          A tensor of shape (world_size, batch, ...), or if the input was a collection
#  |          the output will also be a collection with tensors of this shape.
#  |
#  |  backward(self, loss: torch.Tensor, *args: Any, **kwargs: Any) -> None
#  |      Called to perform backward on the loss returned in :meth:`training_step`. Override this hook with your
#  |      own implementation if you need to.
#  |
#  |      Args:
#  |          loss: The loss tensor returned by :meth:`training_step`. If gradient accumulation is used, the loss here
#  |              holds the normalized value (scaled by 1 / accumulation steps).
#  |
#  |      Example::
#  |
#  |          def backward(self, loss):
#  |              loss.backward()
#  |
#  |  clip_gradients(self, optimizer: torch.optim.optimizer.Optimizer, gradient_clip_val: Union[int, float, NoneType] = None, gradient_clip_algorithm: Optional[str] = None) -> None
#  |      Handles gradient clipping internally.
#  |
#  |      Note:
#  |          - Do not override this method. If you want to customize gradient clipping, consider using
#  |            :meth:`configure_gradient_clipping` method.
#  |          - For manual optimization (``self.automatic_optimization = False``), if you want to use
#  |            gradient clipping, consider calling
#  |            ``self.clip_gradients(opt, gradient_clip_val=0.5, gradient_clip_algorithm="norm")``
#  |            manually in the training step.
#  |
#  |      Args:
#  |          optimizer: Current optimizer being used.
#  |          gradient_clip_val: The value at which to clip gradients.
#  |          gradient_clip_algorithm: The gradient clipping algorithm to use. Pass ``gradient_clip_algorithm="value"``
#  |              to clip by value, and ``gradient_clip_algorithm="norm"`` to clip by norm.
#  |
#  |  configure_callbacks(self) -> Union[Sequence[pytorch_lightning.callbacks.callback.Callback], pytorch_lightning.callbacks.callback.Callback]
#  |      Configure model-specific callbacks. When the model gets attached, e.g., when ``.fit()`` or ``.test()``
#  |      gets called, the list or a callback returned here will be merged with the list of callbacks passed to the
#  |      Trainer's ``callbacks`` argument. If a callback returned here has the same type as one or several callbacks
#  |      already present in the Trainer's callbacks list, it will take priority and replace them. In addition,
#  |      Lightning will make sure :class:`~pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint` callbacks
#  |      run last.
#  |
#  |      Return:
#  |          A callback or a list of callbacks which will extend the list of callbacks in the Trainer.
#  |
#  |      Example::
#  |
#  |          def configure_callbacks(self):
#  |              early_stop = EarlyStopping(monitor="val_acc", mode="max")
#  |              checkpoint = ModelCheckpoint(monitor="val_loss")
#  |              return [early_stop, checkpoint]
#  |
#  |  configure_gradient_clipping(self, optimizer: torch.optim.optimizer.Optimizer, gradient_clip_val: Union[int, float, NoneType] = None, gradient_clip_algorithm: Optional[str] = None) -> None
#  |      Perform gradient clipping for the optimizer parameters. Called before :meth:`optimizer_step`.
#  |
#  |      Args:
#  |          optimizer: Current optimizer being used.
#  |          gradient_clip_val: The value at which to clip gradients. By default, value passed in Trainer
#  |              will be available here.
#  |          gradient_clip_algorithm: The gradient clipping algorithm to use. By default, value
#  |              passed in Trainer will be available here.
#  |
#  |      Example::
#  |
#  |          def configure_gradient_clipping(self, optimizer, gradient_clip_val, gradient_clip_algorithm):
#  |              # Implement your own custom logic to clip gradients
#  |              # You can call `self.clip_gradients` with your settings:
#  |              self.clip_gradients(
#  |                  optimizer,
#  |                  gradient_clip_val=gradient_clip_val,
#  |                  gradient_clip_algorithm=gradient_clip_algorithm
#  |              )
#  |
#  |  forward(self, *args: Any, **kwargs: Any) -> Any
#  |      Same as :meth:`torch.nn.Module.forward`.
#  |
#  |      Args:
#  |          *args: Whatever you decide to pass into the forward method.
#  |          **kwargs: Keyword arguments are also possible.
#  |
#  |      Return:
#  |          Your model's output
#  |
#  |  freeze(self) -> None
#  |      Freeze all params for inference.
#  |
#  |      Example::
#  |
#  |          model = MyLightningModule(...)
#  |          model.freeze()
#  |
#  |  log(self, name: str, value: Union[torchmetrics.metric.Metric, torch.Tensor, int, float], prog_bar: bool = False, logger: Optional[bool] = None, on_step: Optional[bool] = None, on_epoch: Optional[bool] = None, reduce_fx: Union[str, Callable] = 'mean', enable_graph: bool = False, sync_dist: bool = False, sync_dist_group: Optional[Any] = None, add_dataloader_idx: bool = True, batch_size: Optional[int] = None, metric_attribute: Optional[str] = None, rank_zero_only: bool = False) -> None
#  |      Log a key, value pair.
#  |
#  |      Example::
#  |
#  |          self.log('train_loss', loss)
#  |
#  |      The default behavior per hook is documented here: :ref:`extensions/logging:Automatic Logging`.
#  |
#  |      Args:
#  |          name: key to log.
#  |          value: value to log. Can be a ``float``, ``Tensor``, or a ``Metric``.
#  |          prog_bar: if ``True`` logs to the progress bar.
#  |          logger: if ``True`` logs to the logger.
#  |          on_step: if ``True`` logs at this step. The default value is determined by the hook.
#  |              See :ref:`extensions/logging:Automatic Logging` for details.
#  |          on_epoch: if ``True`` logs epoch accumulated metrics. The default value is determined by the hook.
#  |              See :ref:`extensions/logging:Automatic Logging` for details.
#  |          reduce_fx: reduction function over step values for end of epoch. :meth:`torch.mean` by default.
#  |          enable_graph: if ``True``, will not auto detach the graph.
#  |          sync_dist: if ``True``, reduces the metric across devices. Use with care as this may lead to a significant
#  |              communication overhead.
#  |          sync_dist_group: the DDP group to sync across.
#  |          add_dataloader_idx: if ``True``, appends the index of the current dataloader to
#  |              the name (when using multiple dataloaders). If False, user needs to give unique names for
#  |              each dataloader to not mix the values.
#  |          batch_size: Current batch_size. This will be directly inferred from the loaded batch,
#  |              but for some data structures you might need to explicitly provide it.
#  |          metric_attribute: To restore the metric state, Lightning requires the reference of the
#  |              :class:`torchmetrics.Metric` in your model. This is found automatically if it is a model attribute.
#  |          rank_zero_only: Whether the value will be logged only on rank 0. This will prevent synchronization which
#  |              would produce a deadlock as not all processes would perform this log call.
#  |
#  |  log_dict(self, dictionary: Mapping[str, Union[torchmetrics.metric.Metric, torch.Tensor, int, float]], prog_bar: bool = False, logger: Optional[bool] = None, on_step: Optional[bool] = None, on_epoch: Optional[bool] = None, reduce_fx: Union[str, Callable] = 'mean', enable_graph: bool = False, sync_dist: bool = False, sync_dist_group: Optional[Any] = None, add_dataloader_idx: bool = True, batch_size: Optional[int] = None, rank_zero_only: bool = False) -> None
#  |      Log a dictionary of values at once.
#  |
#  |      Example::
#  |
#  |          values = {'loss': loss, 'acc': acc, ..., 'metric_n': metric_n}
#  |          self.log_dict(values)
#  |
#  |      Args:
#  |          dictionary: key value pairs.
#  |              The values can be a ``float``, ``Tensor``, ``Metric``, or ``MetricCollection``.
#  |          prog_bar: if ``True`` logs to the progress base.
#  |          logger: if ``True`` logs to the logger.
#  |          on_step: if ``True`` logs at this step.
#  |              ``None`` auto-logs for training_step but not validation/test_step.
#  |              The default value is determined by the hook.
#  |              See :ref:`extensions/logging:Automatic Logging` for details.
#  |          on_epoch: if ``True`` logs epoch accumulated metrics.
#  |              ``None`` auto-logs for val/test step but not ``training_step``.
#  |              The default value is determined by the hook.
#  |              See :ref:`extensions/logging:Automatic Logging` for details.
#  |          reduce_fx: reduction function over step values for end of epoch. :meth:`torch.mean` by default.
#  |          enable_graph: if ``True``, will not auto-detach the graph
#  |          sync_dist: if ``True``, reduces the metric across GPUs/TPUs. Use with care as this may lead to a significant
#  |              communication overhead.
#  |          sync_dist_group: the ddp group to sync across.
#  |          add_dataloader_idx: if ``True``, appends the index of the current dataloader to
#  |              the name (when using multiple). If ``False``, user needs to give unique names for
#  |              each dataloader to not mix values.
#  |          batch_size: Current batch size. This will be directly inferred from the loaded batch,
#  |              but some data structures might need to explicitly provide it.
#  |          rank_zero_only: Whether the value will be logged only on rank 0. This will prevent synchronization which
#  |              would produce a deadlock as not all processes would perform this log call.
#  |
#  |  lr_scheduler_step(self, scheduler: Union[torch.optim.lr_scheduler.LRScheduler, torch.optim.lr_scheduler.ReduceLROnPlateau], metric: Optional[Any]) -> None
#  |      Override this method to adjust the default way the
#  |      :class:`~pytorch_lightning.trainer.trainer.Trainer` calls each scheduler.
#  |      By default, Lightning calls ``step()`` and as shown in the example
#  |      for each scheduler based on its ``interval``.
#  |
#  |      Args:
#  |          scheduler: Learning rate scheduler.
#  |          metric: Value of the monitor used for schedulers like ``ReduceLROnPlateau``.
#  |
#  |      Examples::
#  |
#  |          # DEFAULT
#  |          def lr_scheduler_step(self, scheduler, metric):
#  |              if metric is None:
#  |                  scheduler.step()
#  |              else:
#  |                  scheduler.step(metric)
#  |
#  |          # Alternative way to update schedulers if it requires an epoch value
#  |          def lr_scheduler_step(self, scheduler, metric):
#  |              scheduler.step(epoch=self.current_epoch)
#  |
#  |  lr_schedulers(self) -> Union[NoneType, List[Union[lightning_fabric.utilities.types.LRScheduler, lightning_fabric.utilities.types.ReduceLROnPlateau]], lightning_fabric.utilities.types.LRScheduler, lightning_fabric.utilities.types.ReduceLROnPlateau]
#  |      Returns the learning rate scheduler(s) that are being used during training. Useful for manual optimization.
#  |
#  |      Returns:
#  |          A single scheduler, or a list of schedulers in case multiple ones are present, or ``None`` if no
#  |          schedulers were returned in :meth:`configure_optimizers`.
#  |
#  |  manual_backward(self, loss: torch.Tensor, *args: Any, **kwargs: Any) -> None
#  |      Call this directly from your :meth:`training_step` when doing optimizations manually. By using this,
#  |      Lightning can ensure that all the proper scaling gets applied when using mixed precision.
#  |
#  |      See :ref:`manual optimization<common/optimization:Manual optimization>` for more examples.
#  |
#  |      Example::
#  |
#  |          def training_step(...):
#  |              opt = self.optimizers()
#  |              loss = ...
#  |              opt.zero_grad()
#  |              # automatically applies scaling, etc...
#  |              self.manual_backward(loss)
#  |              opt.step()
#  |
#  |      Args:
#  |          loss: The tensor on which to compute gradients. Must have a graph attached.
#  |          *args: Additional positional arguments to be forwarded to :meth:`~torch.Tensor.backward`
#  |          **kwargs: Additional keyword arguments to be forwarded to :meth:`~torch.Tensor.backward`
#  |
#  |  optimizer_step(self, epoch: int, batch_idx: int, optimizer: Union[torch.optim.optimizer.Optimizer, pytorch_lightning.core.optimizer.LightningOptimizer], optimizer_closure: Optional[Callable[[], Any]] = None) -> None
#  |      Override this method to adjust the default way the :class:`~pytorch_lightning.trainer.trainer.Trainer`
#  |      calls the optimizer.
#  |
#  |      By default, Lightning calls ``step()`` and ``zero_grad()`` as shown in the example.
#  |      This method (and ``zero_grad()``) won't be called during the accumulation phase when
#  |      ``Trainer(accumulate_grad_batches != 1)``. Overriding this hook has no benefit with manual optimization.
#  |
#  |      Args:
#  |          epoch: Current epoch
#  |          batch_idx: Index of current batch
#  |          optimizer: A PyTorch optimizer
#  |          optimizer_closure: The optimizer closure. This closure must be executed as it includes the
#  |              calls to ``training_step()``, ``optimizer.zero_grad()``, and ``backward()``.
#  |
#  |      Examples::
#  |
#  |          # DEFAULT
#  |          def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure):
#  |              optimizer.step(closure=optimizer_closure)
#  |
#  |          # Learning rate warm-up
#  |          def optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure):
#  |              # update params
#  |              optimizer.step(closure=optimizer_closure)
#  |
#  |              # manually warm up lr without a scheduler
#  |              if self.trainer.global_step < 500:
#  |                  lr_scale = min(1.0, float(self.trainer.global_step + 1) / 500.0)
#  |                  for pg in optimizer.param_groups:
#  |                      pg["lr"] = lr_scale * self.learning_rate
#  |
#  |  optimizer_zero_grad(self, epoch: int, batch_idx: int, optimizer: torch.optim.optimizer.Optimizer) -> None
#  |      Override this method to change the default behaviour of ``optimizer.zero_grad()``.
#  |
#  |      Args:
#  |          epoch: Current epoch
#  |          batch_idx: Index of current batch
#  |          optimizer: A PyTorch optimizer
#  |
#  |      Examples::
#  |
#  |          # DEFAULT
#  |          def optimizer_zero_grad(self, epoch, batch_idx, optimizer):
#  |              optimizer.zero_grad()
#  |
#  |          # Set gradients to `None` instead of zero to improve performance (not required on `torch>=2.0.0`).
#  |          def optimizer_zero_grad(self, epoch, batch_idx, optimizer):
#  |              optimizer.zero_grad(set_to_none=True)
#  |
#  |      See :meth:`torch.optim.Optimizer.zero_grad` for the explanation of the above example.
#  |
#  |  optimizers(self, use_pl_optimizer: bool = True) -> Union[torch.optim.optimizer.Optimizer, pytorch_lightning.core.optimizer.LightningOptimizer, lightning_fabric.wrappers._FabricOptimizer, List[torch.optim.optimizer.Optimizer], List[pytorch_lightning.core.optimizer.LightningOptimizer], List[lightning_fabric.wrappers._FabricOptimizer]]
#  |      Returns the optimizer(s) that are being used during training. Useful for manual optimization.
#  |
#  |      Args:
#  |          use_pl_optimizer: If ``True``, will wrap the optimizer(s) in a
#  |              :class:`~pytorch_lightning.core.optimizer.LightningOptimizer` for automatic handling of precision and
#  |              profiling.
#  |
#  |      Returns:
#  |          A single optimizer, or a list of optimizers in case multiple ones are present.
#  |
#  |  predict_step(self, batch: Any, batch_idx: int, dataloader_idx: int = 0) -> Any
#  |      Step function called during :meth:`~pytorch_lightning.trainer.trainer.Trainer.predict`. By default, it
#  |      calls :meth:`~pytorch_lightning.core.module.LightningModule.forward`. Override to add any processing logic.
#  |
#  |      The :meth:`~pytorch_lightning.core.module.LightningModule.predict_step` is used
#  |      to scale inference on multi-devices.
#  |
#  |      To prevent an OOM error, it is possible to use :class:`~pytorch_lightning.callbacks.BasePredictionWriter`
#  |      callback to write the predictions to disk or database after each batch or on epoch end.
#  |
#  |      The :class:`~pytorch_lightning.callbacks.BasePredictionWriter` should be used while using a spawn
#  |      based accelerator. This happens for ``Trainer(strategy="ddp_spawn")``
#  |      or training on 8 TPU cores with ``Trainer(accelerator="tpu", devices=8)`` as predictions won't be returned.
#  |
#  |      Example ::
#  |
#  |          class MyModel(LightningModule):
#  |
#  |              def predict_step(self, batch, batch_idx, dataloader_idx=0):
#  |                  return self(batch)
#  |
#  |          dm = ...
#  |          model = MyModel()
#  |          trainer = Trainer(accelerator="gpu", devices=2)
#  |          predictions = trainer.predict(model, dm)
#  |
#  |
#  |      Args:
#  |          batch: Current batch.
#  |          batch_idx: Index of current batch.
#  |          dataloader_idx: Index of the current dataloader.
#  |
#  |      Return:
#  |          Predicted output
#  |
#  |  print(self, *args: Any, **kwargs: Any) -> None
#  |      Prints only from process 0. Use this in any distributed mode to log only once.
#  |
#  |      Args:
#  |          *args: The thing to print. The same as for Python's built-in print function.
#  |          **kwargs: The same as for Python's built-in print function.
#  |
#  |      Example::
#  |
#  |          def forward(self, x):
#  |              self.print(x, 'in forward')
#  |
#  |  test_step(self, *args: Any, **kwargs: Any) -> Union[torch.Tensor, Dict[str, Any], NoneType]
#  |      Operates on a single batch of data from the test set. In this step you'd normally generate examples or
#  |      calculate anything of interest such as accuracy.
#  |
#  |      Args:
#  |          batch: The output of your :class:`~torch.utils.data.DataLoader`.
#  |          batch_idx: The index of this batch.
#  |          dataloader_id: The index of the dataloader that produced this batch.
#  |              (only if multiple test dataloaders used).
#  |
#  |      Return:
#  |         Any of.
#  |
#  |          - Any object or value
#  |          - ``None`` - Testing will skip to the next batch
#  |
#  |      .. code-block:: python
#  |
#  |          # if you have one test dataloader:
#  |          def test_step(self, batch, batch_idx):
#  |              ...
#  |
#  |
#  |          # if you have multiple test dataloaders:
#  |          def test_step(self, batch, batch_idx, dataloader_idx=0):
#  |              ...
#  |
#  |      Examples::
#  |
#  |          # CASE 1: A single test dataset
#  |          def test_step(self, batch, batch_idx):
#  |              x, y = batch
#  |
#  |              # implement your own
#  |              out = self(x)
#  |              loss = self.loss(out, y)
#  |
#  |              # log 6 example images
#  |              # or generated text... or whatever
#  |              sample_imgs = x[:6]
#  |              grid = torchvision.utils.make_grid(sample_imgs)
#  |              self.logger.experiment.add_image('example_images', grid, 0)
#  |
#  |              # calculate acc
#  |              labels_hat = torch.argmax(out, dim=1)
#  |              test_acc = torch.sum(y == labels_hat).item() / (len(y) * 1.0)
#  |
#  |              # log the outputs!
#  |              self.log_dict({'test_loss': loss, 'test_acc': test_acc})
#  |
#  |      If you pass in multiple test dataloaders, :meth:`test_step` will have an additional argument. We recommend
#  |      setting the default value of 0 so that you can quickly switch between single and multiple dataloaders.
#  |
#  |      .. code-block:: python
#  |
#  |          # CASE 2: multiple test dataloaders
#  |          def test_step(self, batch, batch_idx, dataloader_idx=0):
#  |              # dataloader_idx tells you which dataset this is.
#  |              ...
#  |
#  |      Note:
#  |          If you don't need to test you don't need to implement this method.
#  |
#  |      Note:
#  |          When the :meth:`test_step` is called, the model has been put in eval mode and
#  |          PyTorch gradients have been disabled. At the end of the test epoch, the model goes back
#  |          to training mode and gradients are enabled.
#  |
#  |  to_onnx(self, file_path: Union[str, pathlib.Path], input_sample: Optional[Any] = None, **kwargs: Any) -> None
#  |      Saves the model in ONNX format.
#  |
#  |      Args:
#  |          file_path: The path of the file the onnx model should be saved to.
#  |          input_sample: An input for tracing. Default: None (Use self.example_input_array)
#  |          **kwargs: Will be passed to torch.onnx.export function.
#  |
#  |      Example::
#  |
#  |          class SimpleModel(LightningModule):
#  |              def __init__(self):
#  |                  super().__init__()
#  |                  self.l1 = torch.nn.Linear(in_features=64, out_features=4)
#  |
#  |              def forward(self, x):
#  |                  return torch.relu(self.l1(x.view(x.size(0), -1)
#  |
#  |          model = SimpleModel()
#  |          input_sample = torch.randn(1, 64)
#  |          model.to_onnx("export.onnx", input_sample, export_params=True)
#  |
#  |  to_torchscript(self, file_path: Union[str, pathlib.Path, NoneType] = None, method: Optional[str] = 'script', example_inputs: Optional[Any] = None, **kwargs: Any) -> Union[torch.ScriptModule, Dict[str, torch.ScriptModule]]
#  |      By default compiles the whole model to a :class:`~torch.jit.ScriptModule`. If you want to use tracing,
#  |      please provided the argument ``method='trace'`` and make sure that either the `example_inputs` argument is
#  |      provided, or the model has :attr:`example_input_array` set. If you would like to customize the modules that
#  |      are scripted you should override this method. In case you want to return multiple modules, we recommend
#  |      using a dictionary.
#  |
#  |      Args:
#  |          file_path: Path where to save the torchscript. Default: None (no file saved).
#  |          method: Whether to use TorchScript's script or trace method. Default: 'script'
#  |          example_inputs: An input to be used to do tracing when method is set to 'trace'.
#  |            Default: None (uses :attr:`example_input_array`)
#  |          **kwargs: Additional arguments that will be passed to the :func:`torch.jit.script` or
#  |            :func:`torch.jit.trace` function.
#  |
#  |      Note:
#  |          - Requires the implementation of the
#  |            :meth:`~pytorch_lightning.core.module.LightningModule.forward` method.
#  |          - The exported script will be set to evaluation mode.
#  |          - It is recommended that you install the latest supported version of PyTorch
#  |            to use this feature without limitations. See also the :mod:`torch.jit`
#  |            documentation for supported features.
#  |
#  |      Example::
#  |
#  |          class SimpleModel(LightningModule):
#  |              def __init__(self):
#  |                  super().__init__()
#  |                  self.l1 = torch.nn.Linear(in_features=64, out_features=4)
#  |
#  |              def forward(self, x):
#  |                  return torch.relu(self.l1(x.view(x.size(0), -1)))
#  |
#  |          model = SimpleModel()
#  |          model.to_torchscript(file_path="model.pt")
#  |
#  |          torch.jit.save(model.to_torchscript(
#  |              file_path="model_trace.pt", method='trace', example_inputs=torch.randn(1, 64))
#  |          )
#  |
#  |      Return:
#  |          This LightningModule as a torchscript, regardless of whether `file_path` is
#  |          defined or not.
#  |
#  |  toggle_optimizer(self, optimizer: Union[torch.optim.optimizer.Optimizer, pytorch_lightning.core.optimizer.LightningOptimizer]) -> None
#  |      Makes sure only the gradients of the current optimizer's parameters are calculated in the training step to
#  |      prevent dangling gradients in multiple-optimizer setup.
#  |
#  |      It works with :meth:`untoggle_optimizer` to make sure ``param_requires_grad_state`` is properly reset.
#  |
#  |      Args:
#  |          optimizer: The optimizer to toggle.
#  |
#  |  unfreeze(self) -> None
#  |      Unfreeze all parameters for training.
#  |
#  |      .. code-block:: python
#  |
#  |          model = MyLightningModule(...)
#  |          model.unfreeze()
#  |
#  |  untoggle_optimizer(self, optimizer: Union[torch.optim.optimizer.Optimizer, pytorch_lightning.core.optimizer.LightningOptimizer]) -> None
#  |      Resets the state of required gradients that were toggled with :meth:`toggle_optimizer`.
#  |
#  |      Args:
#  |          optimizer: The optimizer to untoggle.
#  |
#  |  validation_step(self, *args: Any, **kwargs: Any) -> Union[torch.Tensor, Dict[str, Any], NoneType]
#  |      Operates on a single batch of data from the validation set. In this step you'd might generate examples or
#  |      calculate anything of interest like accuracy.
#  |
#  |      Args:
#  |          batch: The output of your :class:`~torch.utils.data.DataLoader`.
#  |          batch_idx: The index of this batch.
#  |          dataloader_idx: The index of the dataloader that produced this batch.
#  |              (only if multiple val dataloaders used)
#  |
#  |      Return:
#  |          - Any object or value
#  |          - ``None`` - Validation will skip to the next batch
#  |
#  |      .. code-block:: python
#  |
#  |          # if you have one val dataloader:
#  |          def validation_step(self, batch, batch_idx):
#  |              ...
#  |
#  |
#  |          # if you have multiple val dataloaders:
#  |          def validation_step(self, batch, batch_idx, dataloader_idx=0):
#  |              ...
#  |
#  |      Examples::
#  |
#  |          # CASE 1: A single validation dataset
#  |          def validation_step(self, batch, batch_idx):
#  |              x, y = batch
#  |
#  |              # implement your own
#  |              out = self(x)
#  |              loss = self.loss(out, y)
#  |
#  |              # log 6 example images
#  |              # or generated text... or whatever
#  |              sample_imgs = x[:6]
#  |              grid = torchvision.utils.make_grid(sample_imgs)
#  |              self.logger.experiment.add_image('example_images', grid, 0)
#  |
#  |              # calculate acc
#  |              labels_hat = torch.argmax(out, dim=1)
#  |              val_acc = torch.sum(y == labels_hat).item() / (len(y) * 1.0)
#  |
#  |              # log the outputs!
#  |              self.log_dict({'val_loss': loss, 'val_acc': val_acc})
#  |
#  |      If you pass in multiple val dataloaders, :meth:`validation_step` will have an additional argument. We recommend
#  |      setting the default value of 0 so that you can quickly switch between single and multiple dataloaders.
#  |
#  |      .. code-block:: python
#  |
#  |          # CASE 2: multiple validation dataloaders
#  |          def validation_step(self, batch, batch_idx, dataloader_idx=0):
#  |              # dataloader_idx tells you which dataset this is.
#  |              ...
#  |
#  |      Note:
#  |          If you don't need to validate you don't need to implement this method.
#  |
#  |      Note:
#  |          When the :meth:`validation_step` is called, the model has been put in eval mode
#  |          and PyTorch gradients have been disabled. At the end of validation,
#  |          the model goes back to training mode and gradients are enabled.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from pytorch_lightning.core.module.LightningModule:
#  |
#  |  load_from_checkpoint(checkpoint_path: Union[str, pathlib.Path, IO], map_location: Union[torch.device, str, int, Callable[[Union[torch.device, str, int]], Union[torch.device, str, int]], Dict[Union[torch.device, str, int], Union[torch.device, str, int]], NoneType] = None, hparams_file: Union[str, pathlib.Path, NoneType] = None, strict: bool = True, **kwargs: Any) -> Self from builtins.type
#  |      Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint
#  |      it stores the arguments passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#  |
#  |      Any arguments specified through \*\*kwargs will override args stored in ``"hyper_parameters"``.
#  |
#  |      Args:
#  |          checkpoint_path: Path to checkpoint. This can also be a URL, or file-like object
#  |          map_location:
#  |              If your checkpoint saved a GPU model and you now load on CPUs
#  |              or a different number of GPUs, use this to map to the new setup.
#  |              The behaviour is the same as in :func:`torch.load`.
#  |          hparams_file: Optional path to a ``.yaml`` or ``.csv`` file with hierarchical structure
#  |              as in this example::
#  |
#  |                  drop_prob: 0.2
#  |                  dataloader:
#  |                      batch_size: 32
#  |
#  |              You most likely won't need this since Lightning will always save the hyperparameters
#  |              to the checkpoint.
#  |              However, if your checkpoint weights don't have the hyperparameters saved,
#  |              use this method to pass in a ``.yaml`` file with the hparams you'd like to use.
#  |              These will be converted into a :class:`~dict` and passed into your
#  |              :class:`LightningModule` for use.
#  |
#  |              If your model's ``hparams`` argument is :class:`~argparse.Namespace`
#  |              and ``.yaml`` file has hierarchical structure, you need to refactor your model to treat
#  |              ``hparams`` as :class:`~dict`.
#  |          strict: Whether to strictly enforce that the keys in :attr:`checkpoint_path` match the keys
#  |              returned by this module's state dict.
#  |          \**kwargs: Any extra keyword args needed to init the model. Can also be used to override saved
#  |              hyperparameter values.
#  |
#  |      Return:
#  |          :class:`LightningModule` instance with loaded weights and hyperparameters (if available).
#  |
#  |      Note:
#  |          ``load_from_checkpoint`` is a **class** method. You should use your :class:`LightningModule`
#  |          **class** to call it instead of the :class:`LightningModule` instance.
#  |
#  |      Example::
#  |
#  |          # load weights without mapping ...
#  |          model = MyLightningModule.load_from_checkpoint('path/to/checkpoint.ckpt')
#  |
#  |          # or load weights mapping all weights from GPU 1 to GPU 0 ...
#  |          map_location = {'cuda:1':'cuda:0'}
#  |          model = MyLightningModule.load_from_checkpoint(
#  |              'path/to/checkpoint.ckpt',
#  |              map_location=map_location
#  |          )
#  |
#  |          # or load weights and hyperparameters from separate files.
#  |          model = MyLightningModule.load_from_checkpoint(
#  |              'path/to/checkpoint.ckpt',
#  |              hparams_file='/path/to/hparams_file.yaml'
#  |          )
#  |
#  |          # override some of the params with new values
#  |          model = MyLightningModule.load_from_checkpoint(
#  |              PATH,
#  |              num_layers=128,
#  |              pretrained_ckpt_path=NEW_PATH,
#  |          )
#  |
#  |          # predict
#  |          pretrained_model.eval()
#  |          pretrained_model.freeze()
#  |          y_hat = pretrained_model(x)
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from pytorch_lightning.core.module.LightningModule:
#  |
#  |  current_epoch
#  |      The current epoch in the ``Trainer``, or 0 if not attached.
#  |
#  |  global_rank
#  |      The index of the current process across all nodes and devices.
#  |
#  |  global_step
#  |      Total training batches seen across all epochs.
#  |
#  |      If no Trainer is attached, this propery is 0.
#  |
#  |  local_rank
#  |      The index of the current process within a single node.
#  |
#  |  logger
#  |      Reference to the logger object in the Trainer.
#  |
#  |  loggers
#  |      Reference to the list of loggers in the Trainer.
#  |
#  |  on_gpu
#  |      Returns ``True`` if this model is currently located on a GPU.
#  |
#  |      Useful to set flags around the LightningModule for different CPU vs GPU behavior.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pytorch_lightning.core.module.LightningModule:
#  |
#  |  automatic_optimization
#  |      If set to ``False`` you are responsible for calling ``.backward()``, ``.step()``, ``.zero_grad()``.
#  |
#  |  example_input_array
#  |      The example input array is a specification of what the module can consume in the :meth:`forward` method.
#  |      The return type is interpreted as follows:
#  |
#  |      -   Single tensor: It is assumed the model takes a single argument, i.e.,
#  |          ``model.forward(model.example_input_array)``
#  |      -   Tuple: The input array should be interpreted as a sequence of positional arguments, i.e.,
#  |          ``model.forward(*model.example_input_array)``
#  |      -   Dict: The input array represents named keyword arguments, i.e.,
#  |          ``model.forward(**model.example_input_array)``
#  |
#  |  fabric
#  |
#  |  trainer
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from pytorch_lightning.core.module.LightningModule:
#  |
#  |  CHECKPOINT_HYPER_PARAMS_KEY = 'hyper_parameters'
#  |
#  |  CHECKPOINT_HYPER_PARAMS_NAME = 'hparams_name'
#  |
#  |  CHECKPOINT_HYPER_PARAMS_TYPE = 'hparams_type'
#  |
#  |  __jit_unused_properties__ = ['example_input_array', 'on_gpu', 'current...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from lightning_fabric.utilities.device_dtype_mixin._DeviceDtypeModuleMixin:
#  |
#  |  cpu(self) -> Self
#  |      See :meth:`torch.nn.Module.cpu`.
#  |
#  |  cuda(self, device: Union[torch.device, int, NoneType] = None) -> Self
#  |      Moves all model parameters and buffers to the GPU. This also makes associated parameters and buffers
#  |      different objects. So it should be called before constructing optimizer if the module will live on GPU while
#  |      being optimized.
#  |
#  |      Arguments:
#  |          device: If specified, all parameters will be copied to that device. If `None`, the current CUDA device
#  |              index will be used.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  double(self) -> Self
#  |      See :meth:`torch.nn.Module.double`.
#  |
#  |  float(self) -> Self
#  |      See :meth:`torch.nn.Module.float`.
#  |
#  |  half(self) -> Self
#  |      See :meth:`torch.nn.Module.half`.
#  |
#  |  to(self, *args: Any, **kwargs: Any) -> Self
#  |      See :meth:`torch.nn.Module.to`.
#  |
#  |  type(self, dst_type: Union[str, torch.dtype]) -> Self
#  |      See :meth:`torch.nn.Module.type`.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from lightning_fabric.utilities.device_dtype_mixin._DeviceDtypeModuleMixin:
#  |
#  |  device
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from lightning_fabric.utilities.device_dtype_mixin._DeviceDtypeModuleMixin:
#  |
#  |  dtype
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pytorch_lightning.core.mixins.hparams_mixin.HyperparametersMixin:
#  |
#  |  save_hyperparameters(self, *args: Any, ignore: Union[Sequence[str], str, NoneType] = None, frame: Optional[frame] = None, logger: bool = True) -> None
#  |      Save arguments to ``hparams`` attribute.
#  |
#  |      Args:
#  |          args: single object of `dict`, `NameSpace` or `OmegaConf`
#  |              or string names or arguments from class ``__init__``
#  |          ignore: an argument name or a list of argument names from
#  |              class ``__init__`` to be ignored
#  |          frame: a frame object. Default is None
#  |          logger: Whether to send the hyperparameters to the logger. Default: True
#  |
#  |      Example::
#  |          >>> from pytorch_lightning.core.mixins import HyperparametersMixin
#  |          >>> class ManuallyArgsModel(HyperparametersMixin):
#  |          ...     def __init__(self, arg1, arg2, arg3):
#  |          ...         super().__init__()
#  |          ...         # manually assign arguments
#  |          ...         self.save_hyperparameters('arg1', 'arg3')
# ...
#  |             with respect to module outputs.
#  |          3. If none of the module outputs require gradients, then the hooks will not fire.
#  |
#  |      The hook should have the following signature::
#  |
#  |          hook(module, grad_input, grad_output) -> tuple(Tensor) or None
#  |
#  |      The :attr:`grad_input` and :attr:`grad_output` are tuples that contain the gradients
#  |      with respect to the inputs and outputs respectively. The hook should
#  |      not modify its arguments, but it can optionally return a new gradient with
#  |      respect to the input that will be used in place of :attr:`grad_input` in
#  |      subsequent computations. :attr:`grad_input` will only correspond to the inputs given
#  |      as positional arguments and all kwarg arguments are ignored. Entries
#  |      in :attr:`grad_input` and :attr:`grad_output` will be ``None`` for all non-Tensor
#  |      arguments.
#  |
#  |      For technical reasons, when this hook is applied to a Module, its forward function will
#  |      receive a view of each Tensor passed to the Module. Similarly the caller will receive a view
#  |      of each Tensor returned by the Module's forward function.
#  |
#  |      .. warning ::
#  |          Modifying inputs or outputs inplace is not allowed when using backward hooks and
#  |          will raise an error.
#  |
#  |      Args:
#  |          hook (Callable): The user-defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``backward`` hooks on this
#  |              :class:`torch.nn.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``backward`` hooks on
#  |              this :class:`torch.nn.Module`. Note that global
#  |              ``backward`` hooks registered with
#  |              :func:`register_module_full_backward_hook` will fire before
#  |              all hooks registered by this method.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_full_backward_pre_hook(self, hook: collections.abc.Callable[['Module', tuple[torch.Tensor, ...] | torch.Tensor], tuple[torch.Tensor, ...] | torch.Tensor | None], prepend: bool = False) -> torch.utils.hooks.RemovableHandle
#  |      Register a backward pre-hook on the module.
#  |
#  |      The hook will be called every time the gradients for the module are computed.
#  |      The hook should have the following signature::
#  |
#  |          hook(module, grad_output) -> tuple[Tensor, ...], Tensor or None
#  |
#  |      The :attr:`grad_output` is a tuple. The hook should
#  |      not modify its arguments, but it can optionally return a new gradient with
#  |      respect to the output that will be used in place of :attr:`grad_output` in
#  |      subsequent computations. Entries in :attr:`grad_output` will be ``None`` for
#  |      all non-Tensor arguments.
#  |
#  |      For technical reasons, when this hook is applied to a Module, its forward function will
#  |      receive a view of each Tensor passed to the Module. Similarly the caller will receive a view
#  |      of each Tensor returned by the Module's forward function.
#  |
#  |      .. warning ::
#  |          Modifying inputs inplace is not allowed when using backward hooks and
#  |          will raise an error.
#  |
#  |      Args:
#  |          hook (Callable): The user-defined hook to be registered.
#  |          prepend (bool): If true, the provided ``hook`` will be fired before
#  |              all existing ``backward_pre`` hooks on this
#  |              :class:`torch.nn.Module`. Otherwise, the provided
#  |              ``hook`` will be fired after all existing ``backward_pre`` hooks
#  |              on this :class:`torch.nn.Module`. Note that global
#  |              ``backward_pre`` hooks registered with
#  |              :func:`register_module_full_backward_pre_hook` will fire before
#  |              all hooks registered by this method.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_load_state_dict_post_hook(self, hook)
#  |      Register a post-hook to be run after module's :meth:`~nn.Module.load_state_dict` is called.
#  |
#  |      It should have the following signature::
#  |          hook(module, incompatible_keys) -> None
#  |
#  |      The ``module`` argument is the current module that this hook is registered
#  |      on, and the ``incompatible_keys`` argument is a ``NamedTuple`` consisting
#  |      of attributes ``missing_keys`` and ``unexpected_keys``. ``missing_keys``
#  |      is a ``list`` of ``str`` containing the missing keys and
#  |      ``unexpected_keys`` is a ``list`` of ``str`` containing the unexpected keys.
#  |
#  |      The given incompatible_keys can be modified inplace if needed.
#  |
#  |      Note that the checks performed when calling :func:`load_state_dict` with
#  |      ``strict=True`` are affected by modifications the hook makes to
#  |      ``missing_keys`` or ``unexpected_keys``, as expected. Additions to either
#  |      set of keys will result in an error being thrown when ``strict=True``, and
#  |      clearing out both missing and unexpected keys will avoid an error.
#  |
#  |      Returns:
#  |          :class:`torch.utils.hooks.RemovableHandle`:
#  |              a handle that can be used to remove the added hook by calling
#  |              ``handle.remove()``
#  |
#  |  register_load_state_dict_pre_hook(self, hook)
#  |      Register a pre-hook to be run before module's :meth:`~nn.Module.load_state_dict` is called.
#  |
#  |      It should have the following signature::
#  |          hook(module, state_dict, prefix, local_metadata, strict, missing_keys, unexpected_keys, error_msgs) -> None  # noqa: B950
#  |
#  |      Arguments:
#  |          hook (Callable): Callable hook that will be invoked before
#  |              loading the state dict.
#  |
#  |  register_module(self, name: str, module: Optional[ForwardRef('Module')]) -> None
#  |      Alias for :func:`add_module`.
#  |
#  |  register_parameter(self, name: str, param: torch.nn.parameter.Parameter | None) -> None
#  |      Add a parameter to the module.
#  |
#  |      The parameter can be accessed as an attribute using given name.
#  |
#  |      Args:
#  |          name (str): name of the parameter. The parameter can be accessed
#  |              from this module using the given name
#  |          param (Parameter or None): parameter to be added to the module. If
#  |              ``None``, then operations that run on parameters, such as :attr:`cuda`,
#  |              are ignored. If ``None``, the parameter is **not** included in the
#  |              module's :attr:`state_dict`.
#  |
#  |  register_state_dict_post_hook(self, hook)
#  |      Register a post-hook for the :meth:`~torch.nn.Module.state_dict` method.
#  |
#  |      It should have the following signature::
#  |          hook(module, state_dict, prefix, local_metadata) -> None
#  |
#  |      The registered hooks can modify the ``state_dict`` inplace.
#  |
#  |  register_state_dict_pre_hook(self, hook)
#  |      Register a pre-hook for the :meth:`~torch.nn.Module.state_dict` method.
#  |
#  |      It should have the following signature::
#  |          hook(module, prefix, keep_vars) -> None
#  |
#  |      The registered hooks can be used to perform pre-processing before the ``state_dict``
#  |      call is made.
#  |
#  |  requires_grad_(self, requires_grad: bool = True) -> Self
#  |      Change if autograd should record operations on parameters in this module.
#  |
#  |      This method sets the parameters' :attr:`requires_grad` attributes
#  |      in-place.
#  |
#  |      This method is helpful for freezing part of the module for finetuning
#  |      or training parts of a model individually (e.g., GAN training).
#  |
#  |      See :ref:`locally-disable-grad-doc` for a comparison between
#  |      `.requires_grad_()` and several similar mechanisms that may be confused with it.
#  |
#  |      Args:
#  |          requires_grad (bool): whether autograd should record operations on
#  |                                parameters in this module. Default: ``True``.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  set_extra_state(self, state: Any) -> None
#  |      Set extra state contained in the loaded `state_dict`.
#  |
#  |      This function is called from :func:`load_state_dict` to handle any extra state
#  |      found within the `state_dict`. Implement this function and a corresponding
#  |      :func:`get_extra_state` for your module if you need to store extra state within its
#  |      `state_dict`.
#  |
#  |      Args:
#  |          state (dict): Extra state from the `state_dict`
#  |
#  |  set_submodule(self, target: str, module: 'Module', strict: bool = False) -> None
#  |      Set the submodule given by ``target`` if it exists, otherwise throw an error.
#  |
#  |      .. note::
#  |          If ``strict`` is set to ``False`` (default), the method will replace an existing submodule
#  |          or create a new submodule if the parent module exists. If ``strict`` is set to ``True``,
#  |          the method will only attempt to replace an existing submodule and throw an error if
#  |          the submodule does not exist.
#  |
#  |      For example, let's say you have an ``nn.Module`` ``A`` that
#  |      looks like this:
#  |
#  |      .. code-block:: text
#  |
#  |          A(
#  |              (net_b): Module(
#  |                  (net_c): Module(
#  |                      (conv): Conv2d(3, 3, 3)
#  |                  )
#  |                  (linear): Linear(3, 3)
#  |              )
#  |          )
#  |
#  |      (The diagram shows an ``nn.Module`` ``A``. ``A`` has a nested
#  |      submodule ``net_b``, which itself has two submodules ``net_c``
#  |      and ``linear``. ``net_c`` then has a submodule ``conv``.)
#  |
#  |      To override the ``Conv2d`` with a new submodule ``Linear``, you
#  |      could call ``set_submodule("net_b.net_c.conv", nn.Linear(1, 1))``
#  |      where ``strict`` could be ``True`` or ``False``
#  |
#  |      To add a new submodule ``Conv2d`` to the existing ``net_b`` module,
#  |      you would call ``set_submodule("net_b.conv", nn.Conv2d(1, 1, 1))``.
#  |
#  |      In the above if you set ``strict=True`` and call
#  |      ``set_submodule("net_b.conv", nn.Conv2d(1, 1, 1), strict=True)``, an AttributeError
#  |      will be raised because ``net_b`` does not have a submodule named ``conv``.
#  |
#  |      Args:
#  |          target: The fully-qualified string name of the submodule
#  |              to look for. (See above example for how to specify a
#  |              fully-qualified string.)
#  |          module: The module to set the submodule to.
#  |          strict: If ``False``, the method will replace an existing submodule
#  |              or create a new submodule if the parent module exists. If ``True``,
#  |              the method will only attempt to replace an existing submodule and throw an error
#  |              if the submodule doesn't already exist.
#  |
#  |      Raises:
#  |          ValueError: If the ``target`` string is empty or if ``module`` is not an instance of ``nn.Module``.
#  |          AttributeError: If at any point along the path resulting from
#  |              the ``target`` string the (sub)path resolves to a non-existent
#  |              attribute name or an object that is not an instance of ``nn.Module``.
#  |
#  |  share_memory(self) -> Self
#  |      See :meth:`torch.Tensor.share_memory_`.
#  |
#  |  state_dict(self, *args, destination=None, prefix='', keep_vars=False)
#  |      Return a dictionary containing references to the whole state of the module.
#  |
#  |      Both parameters and persistent buffers (e.g. running averages) are
#  |      included. Keys are corresponding parameter and buffer names.
#  |      Parameters and buffers set to ``None`` are not included.
#  |
#  |      .. note::
#  |          The returned object is a shallow copy. It contains references
#  |          to the module's parameters and buffers.
#  |
#  |      .. warning::
#  |          Currently ``state_dict()`` also accepts positional arguments for
#  |          ``destination``, ``prefix`` and ``keep_vars`` in order. However,
#  |          this is being deprecated and keyword arguments will be enforced in
#  |          future releases.
#  |
#  |      .. warning::
#  |          Please avoid the use of argument ``destination`` as it is not
#  |          designed for end-users.
#  |
#  |      Args:
#  |          destination (dict, optional): If provided, the state of module will
#  |              be updated into the dict and the same object is returned.
#  |              Otherwise, an ``OrderedDict`` will be created and returned.
#  |              Default: ``None``.
#  |          prefix (str, optional): a prefix added to parameter and buffer
#  |              names to compose the keys in state_dict. Default: ``''``.
#  |          keep_vars (bool, optional): by default the :class:`~torch.Tensor` s
#  |              returned in the state dict are detached from autograd. If it's
#  |              set to ``True``, detaching will not be performed.
#  |              Default: ``False``.
#  |
#  |      Returns:
#  |          dict:
#  |              a dictionary containing a whole state of the module
#  |
#  |      Example::
#  |
#  |          >>> # xdoctest: +SKIP("undefined vars")
#  |          >>> module.state_dict().keys()
#  |          ['bias', 'weight']
#  |
#  |  to_empty(self, *, device: str | torch.device | int | None, recurse: bool = True) -> Self
#  |      Move the parameters and buffers to the specified device without copying storage.
#  |
#  |      Args:
#  |          device (:class:`torch.device`): The desired device of the parameters
#  |              and buffers in this module.
#  |          recurse (bool): Whether parameters and buffers of submodules should
#  |              be recursively moved to the specified device.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  train(self, mode: bool = True) -> Self
#  |      Set the module in training mode.
#  |
#  |      This has an effect only on certain modules. See the documentation of
#  |      particular modules for details of their behaviors in training/evaluation
#  |      mode, i.e., whether they are affected, e.g. :class:`Dropout`, :class:`BatchNorm`,
#  |      etc.
#  |
#  |      Args:
#  |          mode (bool): whether to set training mode (``True``) or evaluation
#  |                       mode (``False``). Default: ``True``.
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  xpu(self, device: int | torch.device | None = None) -> Self
#  |      Move all model parameters and buffers to the XPU.
#  |
#  |      This also makes associated parameters and buffers different objects. So
#  |      it should be called before constructing optimizer if the module will
#  |      live on XPU while being optimized.
#  |
#  |      .. note::
#  |          This method modifies the module in-place.
#  |
#  |      Arguments:
#  |          device (int, optional): if specified, all parameters will be
#  |              copied to that device
#  |
#  |      Returns:
#  |          Module: self
#  |
#  |  zero_grad(self, set_to_none: bool = True) -> None
#  |      Reset gradients of all model parameters.
#  |
#  |      See similar function under :class:`torch.optim.Optimizer` for more context.
#  |
#  |      Args:
#  |          set_to_none (bool): instead of setting to zero, set the grads to None.
#  |              See :meth:`torch.optim.Optimizer.zero_grad` for details.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from torch.nn.modules.module.Module:
#  |
#  |  T_destination = ~T_destination
#  |
#  |  call_super_init = False
#  |
#  |  dump_patches = False

# %% [markdown]
# ## 🚀 Training

# %%
def is_valid_checkpoint(path: str) -> bool:
    try:
        import zipfile
        with zipfile.ZipFile(path, 'r') as zf:
            zf.testzip()
        return True
    except Exception:
        return False

def find_best_valid_checkpoint(ckpt_dir: str) -> Optional[str]:
    if not os.path.isdir(ckpt_dir):
        return None
    last = os.path.join(ckpt_dir, "last.ckpt")
    if os.path.exists(last) and is_valid_checkpoint(last):
        print(f"✅ Valid checkpoint: {last}")
        return last
    all_ckpts = sorted(
        [p for p in glob.glob(os.path.join(ckpt_dir, "*.ckpt")) if "last" not in p],
        key=lambda p: float(p.split("train_loss=")[-1].replace(".ckpt", ""))
        if "train_loss=" in p else float("inf"),
    )
    for p in all_ckpts:
        if is_valid_checkpoint(p):
            print(f"✅ Valid checkpoint: {p}")
            return p
    print("❌ No valid checkpoint found. Starting from scratch.")
    return None

# ── Paths ──────────────────────────────────────────────────────────────────
C = datamodule.window_size

LOG_DIR     = "logs_FM_spde"
CKPT_DIR    = os.path.join(LOG_DIR, "checkpoints")
MODEL_PATH  = os.path.join(LOG_DIR, "best_model")

# RESET_TRAINING set by the parameters cell above
if RESET_TRAINING:
    import shutil
    for d in [CKPT_DIR, MODEL_PATH]:
        if os.path.exists(d):
            shutil.rmtree(d)
    resume_ckpt = None
    print("RESET_TRAINING=True -- starting from scratch")
else:
    resume_ckpt = find_best_valid_checkpoint(CKPT_DIR)

# ── Model ──────────────────────────────────────────────────────────────────
network   = UNetFM(UNetFMConfig(channels=C))
lit_fm    = LitFlowMatchingModel(
    network=network,
    config=LitFMConfig(lr_scheduler_iters=1000, eval_n_steps=20),
)

# ── Trainer ────────────────────────────────────────────────────────────────
trainer = Trainer(enable_progress_bar=False, 
    accelerator="gpu",
    max_epochs=MAX_EPOCHS,
    accumulate_grad_batches=4,
    precision="16-mixed",
    log_every_n_steps=1,
    logger=TensorBoardLogger(".", name=LOG_DIR, version=""),
    callbacks=[
        LearningRateMonitor(logging_interval="step"),
        ModelCheckpoint(
            dirpath=CKPT_DIR,
            monitor="train_loss",
            save_top_k=3,
            save_last=True,
            filename="{epoch:03d}-{step}-{train_loss:.4f}",
        ),
    ],
)

seed_everything(42)
trainer.callbacks.append(EpochHeartbeat(every_n_epochs=1))
trainer.fit(lit_fm, datamodule, ckpt_path=resume_ckpt)

# ── Save EMA model ─────────────────────────────────────────────────────────
ema_net = lit_fm.ema_model.module
ema_net.save_pretrained(MODEL_PATH)
print(f"✅ EMA model saved to: {MODEL_PATH}")
# Out:
# ✅ Valid checkpoint: logs_FM_spde/checkpoints/last.ckpt
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/lightning_fabric/plugins/environments/slurm.py:168: PossibleUserWarning: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /Odyssey/private/m19beauc/conda_envs/4dvarnet-starte ...
#   rank_zero_warn(
# Using 16bit Automatic Mixed Precision (AMP)
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/plugins/precision/amp.py:53: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [rank: 0] Global seed set to 42
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/trainer/configuration_validator.py:69: UserWarning: You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.
#   rank_zero_warn("You passed in a `val_dataloader` but have no `validation_step`. Skipping val loop.")
# You are using a CUDA device ('NVIDIA H100 NVL') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:617: UserWarning: Checkpoint directory /Odyssey/private/m19beauc/4dvarnet-starter-devs/consistency/Notebooks/Notebooks_GP/logs_FM_spde/checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# Restoring states from the checkpoint path at logs_FM_spde/checkpoints/last.ckpt
# [SPDEDataModule] T=300, window=5, stride=1 → 296 windows: train=207, val=44, test=45
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/utilities/migration/utils.py:55: PossibleUserWarning: The loaded checkpoint was produced with Lightning v2.0.9, which is newer than your current Lightning version: v2.0.7
#   rank_zero_warn(
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:337: UserWarning: The dirpath has changed from 'logs_FM_spde/v2/checkpoints' to '/Odyssey/private/m19beauc/4dvarnet-starter-devs/consistency/Notebooks/Notebooks_GP/logs_FM_spde/checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
#   warnings.warn(
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#   | Name      | Type          | Params
# --------------------------------------------
# 0 | network   | UNetFM        | 32.3 M
# 1 | log_scale | LogScaleModel | 17.2 K
# 2 | ema_model | AveragedModel | 32.3 M
# --------------------------------------------
# 32.3 M    Trainable params
# 32.3 M    Non-trainable params
# 64.6 M    Total params
# 258.227   Total estimated model params size (MB)
# ✅ Val batch cached: tgt=torch.Size([1, 5, 128, 128])
# Restored all states from the checkpoint at logs_FM_spde/checkpoints/last.ckpt
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/utilities/_pytree.py:21: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return [pytree], LeafSpec()
# /Odyssey/private/m19beauc/conda_envs/4dvarnet-starter/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:438: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 96 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# [progress] epoch 267/2000 | train_loss=1.1977 | train_loss_epoch=1.1977 | train_loss_step=1.3257
# [Epoch 266]  Val RMSE (20 Heun steps, EMA) = 0.8942
# [progress] epoch 268/2000 | train_loss=1.2017 | train_loss_epoch=1.2017 | train_loss_step=1.1966 | val_rmse_ema=0.8942
# [Epoch 267]  Val RMSE (20 Heun steps, EMA) = 0.8940
# [progress] epoch 269/2000 | train_loss=1.2153 | train_loss_epoch=1.2153 | train_loss_step=1.3838 | val_rmse_ema=0.8940
# [Epoch 268]  Val RMSE (20 Heun steps, EMA) = 0.8913
# [progress] epoch 270/2000 | train_loss=1.2178 | train_loss_epoch=1.2178 | train_loss_step=0.9400 | val_rmse_ema=0.8913
# [Epoch 269]  Val RMSE (20 Heun steps, EMA) = 0.8866
# [progress] epoch 271/2000 | train_loss=1.2219 | train_loss_epoch=1.2219 | train_loss_step=1.4411 | val_rmse_ema=0.8866
# [Epoch 270]  Val RMSE (20 Heun steps, EMA) = 0.8957
# [progress] epoch 272/2000 | train_loss=1.1951 | train_loss_epoch=1.1951 | train_loss_step=1.2020 | val_rmse_ema=0.8957
# [Epoch 271]  Val RMSE (20 Heun steps, EMA) = 0.8967
# [progress] epoch 273/2000 | train_loss=1.1871 | train_loss_epoch=1.1871 | train_loss_step=1.1236 | val_rmse_ema=0.8967
# [Epoch 272]  Val RMSE (20 Heun steps, EMA) = 0.8849
# [progress] epoch 274/2000 | train_loss=1.1691 | train_loss_epoch=1.1691 | train_loss_step=1.2649 | val_rmse_ema=0.8849
# [Epoch 273]  Val RMSE (20 Heun steps, EMA) = 0.8909
# [progress] epoch 275/2000 | train_loss=1.1603 | train_loss_epoch=1.1603 | train_loss_step=1.3716 | val_rmse_ema=0.8909
# [Epoch 274]  Val RMSE (20 Heun steps, EMA) = 0.8933
# [progress] epoch 276/2000 | train_loss=1.1964 | train_loss_epoch=1.1964 | train_loss_step=0.9318 | val_rmse_ema=0.8933
# [Epoch 275]  Val RMSE (20 Heun steps, EMA) = 0.8866
# [progress] epoch 277/2000 | train_loss=1.1825 | train_loss_epoch=1.1825 | train_loss_step=1.2368 | val_rmse_ema=0.8866
# [Epoch 276]  Val RMSE (20 Heun steps, EMA) = 0.8880
# [progress] epoch 278/2000 | train_loss=1.1727 | train_loss_epoch=1.1727 | train_loss_step=0.9512 | val_rmse_ema=0.8880
# [Epoch 277]  Val RMSE (20 Heun steps, EMA) = 0.8801
# [progress] epoch 279/2000 | train_loss=1.1808 | train_loss_epoch=1.1808 | train_loss_step=1.4520 | val_rmse_ema=0.8801
# [Epoch 278]  Val RMSE (20 Heun steps, EMA) = 0.8857
# [progress] epoch 280/2000 | train_loss=1.1669 | train_loss_epoch=1.1669 | train_loss_step=1.1345 | val_rmse_ema=0.8857
# [Epoch 279]  Val RMSE (20 Heun steps, EMA) = 0.8908
# [progress] epoch 281/2000 | train_loss=1.1872 | train_loss_epoch=1.1872 | train_loss_step=1.0061 | val_rmse_ema=0.8908
# [Epoch 280]  Val RMSE (20 Heun steps, EMA) = 0.8878
# [progress] epoch 282/2000 | train_loss=1.1921 | train_loss_epoch=1.1921 | train_loss_step=0.9213 | val_rmse_ema=0.8878
# [Epoch 281]  Val RMSE (20 Heun steps, EMA) = 0.8835
# [progress] epoch 283/2000 | train_loss=1.1870 | train_loss_epoch=1.1870 | train_loss_step=1.4345 | val_rmse_ema=0.8835
# [Epoch 282]  Val RMSE (20 Heun steps, EMA) = 0.8896
# [progress] epoch 284/2000 | train_loss=1.1913 | train_loss_epoch=1.1913 | train_loss_step=1.1903 | val_rmse_ema=0.8896
# [Epoch 283]  Val RMSE (20 Heun steps, EMA) = 0.8887
# [progress] epoch 285/2000 | train_loss=1.1748 | train_loss_epoch=1.1748 | train_loss_step=1.3665 | val_rmse_ema=0.8887
# [Epoch 284]  Val RMSE (20 Heun steps, EMA) = 0.8850
# [progress] epoch 286/2000 | train_loss=1.1840 | train_loss_epoch=1.1840 | train_loss_step=1.4114 | val_rmse_ema=0.8850
# [Epoch 285]  Val RMSE (20 Heun steps, EMA) = 0.8853
# [progress] epoch 287/2000 | train_loss=1.1857 | train_loss_epoch=1.1857 | train_loss_step=1.1382 | val_rmse_ema=0.8853
# [Epoch 286]  Val RMSE (20 Heun steps, EMA) = 0.8802
# [progress] epoch 288/2000 | train_loss=1.1721 | train_loss_epoch=1.1721 | train_loss_step=1.1864 | val_rmse_ema=0.8802
# [Epoch 287]  Val RMSE (20 Heun steps, EMA) = 0.8867
# [progress] epoch 289/2000 | train_loss=1.1981 | train_loss_epoch=1.1981 | train_loss_step=1.2202 | val_rmse_ema=0.8867
# [Epoch 288]  Val RMSE (20 Heun steps, EMA) = 0.8881
# [progress] epoch 290/2000 | train_loss=1.1635 | train_loss_epoch=1.1635 | train_loss_step=1.3022 | val_rmse_ema=0.8881
# [Epoch 289]  Val RMSE (20 Heun steps, EMA) = 0.8878
# [progress] epoch 291/2000 | train_loss=1.1788 | train_loss_epoch=1.1788 | train_loss_step=1.1341 | val_rmse_ema=0.8878
# [Epoch 290]  Val RMSE (20 Heun steps, EMA) = 0.8933
# [progress] epoch 292/2000 | train_loss=1.1772 | train_loss_epoch=1.1772 | train_loss_step=1.0255 | val_rmse_ema=0.8933
# [Epoch 291]  Val RMSE (20 Heun steps, EMA) = 0.8834
# [progress] epoch 293/2000 | train_loss=1.2001 | train_loss_epoch=1.2001 | train_loss_step=1.4432 | val_rmse_ema=0.8834
# [Epoch 292]  Val RMSE (20 Heun steps, EMA) = 0.8879
# [progress] epoch 294/2000 | train_loss=1.1798 | train_loss_epoch=1.1798 | train_loss_step=1.0394 | val_rmse_ema=0.8879
# [Epoch 293]  Val RMSE (20 Heun steps, EMA) = 0.8842
# [progress] epoch 295/2000 | train_loss=1.1908 | train_loss_epoch=1.1908 | train_loss_step=1.2868 | val_rmse_ema=0.8842
# [Epoch 294]  Val RMSE (20 Heun steps, EMA) = 0.8804
# [progress] epoch 296/2000 | train_loss=1.1875 | train_loss_epoch=1.1875 | train_loss_step=1.4380 | val_rmse_ema=0.8804
# [Epoch 295]  Val RMSE (20 Heun steps, EMA) = 0.8847
# [progress] epoch 297/2000 | train_loss=1.1806 | train_loss_epoch=1.1806 | train_loss_step=1.0075 | val_rmse_ema=0.8847
# [Epoch 296]  Val RMSE (20 Heun steps, EMA) = 0.8825
# [progress] epoch 298/2000 | train_loss=1.1674 | train_loss_epoch=1.1674 | train_loss_step=1.4072 | val_rmse_ema=0.8825
# [Epoch 297]  Val RMSE (20 Heun steps, EMA) = 0.8818
# [progress] epoch 299/2000 | train_loss=1.1870 | train_loss_epoch=1.1870 | train_loss_step=1.4012 | val_rmse_ema=0.8818
# [Epoch 298]  Val RMSE (20 Heun steps, EMA) = 0.8823
# [progress] epoch 300/2000 | train_loss=1.1658 | train_loss_epoch=1.1658 | train_loss_step=1.3872 | val_rmse_ema=0.8823
# [Epoch 299]  Val RMSE (20 Heun steps, EMA) = 0.8810
# [progress] epoch 301/2000 | train_loss=1.1716 | train_loss_epoch=1.1716 | train_loss_step=1.1563 | val_rmse_ema=0.8810
# [Epoch 300]  Val RMSE (20 Heun steps, EMA) = 0.8796
# [progress] epoch 302/2000 | train_loss=1.1867 | train_loss_epoch=1.1867 | train_loss_step=1.1880 | val_rmse_ema=0.8796
# [Epoch 301]  Val RMSE (20 Heun steps, EMA) = 0.8793
# [progress] epoch 303/2000 | train_loss=1.1867 | train_loss_epoch=1.1867 | train_loss_step=1.3109 | val_rmse_ema=0.8793
# [Epoch 302]  Val RMSE (20 Heun steps, EMA) = 0.8811
# [progress] epoch 304/2000 | train_loss=1.1987 | train_loss_epoch=1.1987 | train_loss_step=1.3437 | val_rmse_ema=0.8811
# [Epoch 303]  Val RMSE (20 Heun steps, EMA) = 0.8741
# [progress] epoch 305/2000 | train_loss=1.1617 | train_loss_epoch=1.1617 | train_loss_step=0.9251 | val_rmse_ema=0.8741
# [Epoch 304]  Val RMSE (20 Heun steps, EMA) = 0.8771
# [progress] epoch 306/2000 | train_loss=1.1585 | train_loss_epoch=1.1585 | train_loss_step=0.8191 | val_rmse_ema=0.8771
# [Epoch 305]  Val RMSE (20 Heun steps, EMA) = 0.8782
# [progress] epoch 307/2000 | train_loss=1.1823 | train_loss_epoch=1.1823 | train_loss_step=1.1861 | val_rmse_ema=0.8782
# [Epoch 306]  Val RMSE (20 Heun steps, EMA) = 0.8729
# [progress] epoch 308/2000 | train_loss=1.1930 | train_loss_epoch=1.1930 | train_loss_step=1.0108 | val_rmse_ema=0.8729
# [Epoch 307]  Val RMSE (20 Heun steps, EMA) = 0.8748
# [progress] epoch 309/2000 | train_loss=1.1481 | train_loss_epoch=1.1481 | train_loss_step=0.9822 | val_rmse_ema=0.8748
# [Epoch 308]  Val RMSE (20 Heun steps, EMA) = 0.8746
# [progress] epoch 310/2000 | train_loss=1.1731 | train_loss_epoch=1.1731 | train_loss_step=1.2639 | val_rmse_ema=0.8746
# [Epoch 309]  Val RMSE (20 Heun steps, EMA) = 0.8811
# [progress] epoch 311/2000 | train_loss=1.1592 | train_loss_epoch=1.1592 | train_loss_step=1.1758 | val_rmse_ema=0.8811
# [Epoch 310]  Val RMSE (20 Heun steps, EMA) = 0.8771
# [progress] epoch 312/2000 | train_loss=1.1744 | train_loss_epoch=1.1744 | train_loss_step=0.9628 | val_rmse_ema=0.8771
# [Epoch 311]  Val RMSE (20 Heun steps, EMA) = 0.8827
# [progress] epoch 313/2000 | train_loss=1.1671 | train_loss_epoch=1.1671 | train_loss_step=0.9835 | val_rmse_ema=0.8827
# [Epoch 312]  Val RMSE (20 Heun steps, EMA) = 0.8753
# [progress] epoch 314/2000 | train_loss=1.1580 | train_loss_epoch=1.1580 | train_loss_step=1.2785 | val_rmse_ema=0.8753
# [Epoch 313]  Val RMSE (20 Heun steps, EMA) = 0.8756
# [progress] epoch 315/2000 | train_loss=1.1966 | train_loss_epoch=1.1966 | train_loss_step=1.4269 | val_rmse_ema=0.8756
# [Epoch 314]  Val RMSE (20 Heun steps, EMA) = 0.8812
# [progress] epoch 316/2000 | train_loss=1.1478 | train_loss_epoch=1.1478 | train_loss_step=1.1923 | val_rmse_ema=0.8812
# [Epoch 315]  Val RMSE (20 Heun steps, EMA) = 0.8693
# [progress] epoch 317/2000 | train_loss=1.1333 | train_loss_epoch=1.1333 | train_loss_step=1.3568 | val_rmse_ema=0.8693
# [Epoch 316]  Val RMSE (20 Heun steps, EMA) = 0.8717
# [progress] epoch 318/2000 | train_loss=1.1573 | train_loss_epoch=1.1573 | train_loss_step=1.1078 | val_rmse_ema=0.8717
# [Epoch 317]  Val RMSE (20 Heun steps, EMA) = 0.8722
# [progress] epoch 319/2000 | train_loss=1.1568 | train_loss_epoch=1.1568 | train_loss_step=1.3797 | val_rmse_ema=0.8722
# [Epoch 318]  Val RMSE (20 Heun steps, EMA) = 0.8756
# [progress] epoch 320/2000 | train_loss=1.1850 | train_loss_epoch=1.1850 | train_loss_step=1.3067 | val_rmse_ema=0.8756
# [Epoch 319]  Val RMSE (20 Heun steps, EMA) = 0.8754
# [progress] epoch 321/2000 | train_loss=1.1550 | train_loss_epoch=1.1550 | train_loss_step=0.7814 | val_rmse_ema=0.8754
# [Epoch 320]  Val RMSE (20 Heun steps, EMA) = 0.8772
# [progress] epoch 322/2000 | train_loss=1.1456 | train_loss_epoch=1.1456 | train_loss_step=0.7709 | val_rmse_ema=0.8772
# [Epoch 321]  Val RMSE (20 Heun steps, EMA) = 0.8745
# [progress] epoch 323/2000 | train_loss=1.1570 | train_loss_epoch=1.1570 | train_loss_step=1.2921 | val_rmse_ema=0.8745
# [Epoch 322]  Val RMSE (20 Heun steps, EMA) = 0.8776
# [progress] epoch 324/2000 | train_loss=1.1723 | train_loss_epoch=1.1723 | train_loss_step=0.7563 | val_rmse_ema=0.8776
# [Epoch 323]  Val RMSE (20 Heun steps, EMA) = 0.8772
# [progress] epoch 325/2000 | train_loss=1.1671 | train_loss_epoch=1.1671 | train_loss_step=1.0638 | val_rmse_ema=0.8772
# [Epoch 324]  Val RMSE (20 Heun steps, EMA) = 0.8777
# [progress] epoch 326/2000 | train_loss=1.1694 | train_loss_epoch=1.1694 | train_loss_step=1.4366 | val_rmse_ema=0.8777
# [Epoch 325]  Val RMSE (20 Heun steps, EMA) = 0.8720
# [progress] epoch 327/2000 | train_loss=1.1603 | train_loss_epoch=1.1603 | train_loss_step=1.2644 | val_rmse_ema=0.8720
# [Epoch 326]  Val RMSE (20 Heun steps, EMA) = 0.8753
# [progress] epoch 328/2000 | train_loss=1.1333 | train_loss_epoch=1.1333 | train_loss_step=0.7483 | val_rmse_ema=0.8753
# [Epoch 327]  Val RMSE (20 Heun steps, EMA) = 0.8753
# [progress] epoch 329/2000 | train_loss=1.1477 | train_loss_epoch=1.1477 | train_loss_step=1.4402 | val_rmse_ema=0.8753
# [Epoch 328]  Val RMSE (20 Heun steps, EMA) = 0.8773
# [progress] epoch 330/2000 | train_loss=1.1457 | train_loss_epoch=1.1457 | train_loss_step=1.3617 | val_rmse_ema=0.8773
# [Epoch 329]  Val RMSE (20 Heun steps, EMA) = 0.8753
# [progress] epoch 331/2000 | train_loss=1.1535 | train_loss_epoch=1.1535 | train_loss_step=0.8870 | val_rmse_ema=0.8753
# [Epoch 330]  Val RMSE (20 Heun steps, EMA) = 0.8760
# [progress] epoch 332/2000 | train_loss=1.1339 | train_loss_epoch=1.1339 | train_loss_step=0.8595 | val_rmse_ema=0.8760
# [Epoch 331]  Val RMSE (20 Heun steps, EMA) = 0.8692
# [progress] epoch 333/2000 | train_loss=1.1307 | train_loss_epoch=1.1307 | train_loss_step=1.0682 | val_rmse_ema=0.8692
# [Epoch 332]  Val RMSE (20 Heun steps, EMA) = 0.8741
# [progress] epoch 334/2000 | train_loss=1.1424 | train_loss_epoch=1.1424 | train_loss_step=1.4337 | val_rmse_ema=0.8741
# [Epoch 333]  Val RMSE (20 Heun steps, EMA) = 0.8784
# [progress] epoch 335/2000 | train_loss=1.1504 | train_loss_epoch=1.1504 | train_loss_step=1.4011 | val_rmse_ema=0.8784
# [Epoch 334]  Val RMSE (20 Heun steps, EMA) = 0.8799
# [progress] epoch 336/2000 | train_loss=1.1418 | train_loss_epoch=1.1418 | train_loss_step=1.3325 | val_rmse_ema=0.8799
# [Epoch 335]  Val RMSE (20 Heun steps, EMA) = 0.8707
# [progress] epoch 337/2000 | train_loss=1.1562 | train_loss_epoch=1.1562 | train_loss_step=1.3890 | val_rmse_ema=0.8707
# [Epoch 336]  Val RMSE (20 Heun steps, EMA) = 0.8791
# [progress] epoch 338/2000 | train_loss=1.1332 | train_loss_epoch=1.1332 | train_loss_step=1.4294 | val_rmse_ema=0.8791
# [Epoch 337]  Val RMSE (20 Heun steps, EMA) = 0.8726
# [progress] epoch 339/2000 | train_loss=1.1523 | train_loss_epoch=1.1523 | train_loss_step=1.3754 | val_rmse_ema=0.8726
# [Epoch 338]  Val RMSE (20 Heun steps, EMA) = 0.8747
# [progress] epoch 340/2000 | train_loss=1.1470 | train_loss_epoch=1.1470 | train_loss_step=1.1910 | val_rmse_ema=0.8747
# [Epoch 339]  Val RMSE (20 Heun steps, EMA) = 0.8723
# [progress] epoch 341/2000 | train_loss=1.1391 | train_loss_epoch=1.1391 | train_loss_step=0.7519 | val_rmse_ema=0.8723
# [Epoch 340]  Val RMSE (20 Heun steps, EMA) = 0.8706
# [progress] epoch 342/2000 | train_loss=1.1462 | train_loss_epoch=1.1462 | train_loss_step=1.1857 | val_rmse_ema=0.8706
# [Epoch 341]  Val RMSE (20 Heun steps, EMA) = 0.8755
# [progress] epoch 343/2000 | train_loss=1.1584 | train_loss_epoch=1.1584 | train_loss_step=1.1187 | val_rmse_ema=0.8755
# [Epoch 342]  Val RMSE (20 Heun steps, EMA) = 0.8738
# [progress] epoch 344/2000 | train_loss=1.1499 | train_loss_epoch=1.1499 | train_loss_step=1.0450 | val_rmse_ema=0.8738
# [Epoch 343]  Val RMSE (20 Heun steps, EMA) = 0.8714
# [progress] epoch 345/2000 | train_loss=1.1345 | train_loss_epoch=1.1345 | train_loss_step=1.1348 | val_rmse_ema=0.8714
# [Epoch 344]  Val RMSE (20 Heun steps, EMA) = 0.8699
# [progress] epoch 346/2000 | train_loss=1.1260 | train_loss_epoch=1.1260 | train_loss_step=1.2345 | val_rmse_ema=0.8699
# [Epoch 345]  Val RMSE (20 Heun steps, EMA) = 0.8705
# [progress] epoch 347/2000 | train_loss=1.1472 | train_loss_epoch=1.1472 | train_loss_step=1.4210 | val_rmse_ema=0.8705
# [Epoch 346]  Val RMSE (20 Heun steps, EMA) = 0.8710
# [progress] epoch 348/2000 | train_loss=1.1543 | train_loss_epoch=1.1543 | train_loss_step=1.3816 | val_rmse_ema=0.8710
# [Epoch 347]  Val RMSE (20 Heun steps, EMA) = 0.8764
# [progress] epoch 349/2000 | train_loss=1.1084 | train_loss_epoch=1.1084 | train_loss_step=0.8045 | val_rmse_ema=0.8764
# [Epoch 348]  Val RMSE (20 Heun steps, EMA) = 0.8713
# [progress] epoch 350/2000 | train_loss=1.1125 | train_loss_epoch=1.1125 | train_loss_step=0.7486 | val_rmse_ema=0.8713
# [Epoch 349]  Val RMSE (20 Heun steps, EMA) = 0.8771
# [progress] epoch 351/2000 | train_loss=1.1381 | train_loss_epoch=1.1381 | train_loss_step=0.7247 | val_rmse_ema=0.8771
# [Epoch 350]  Val RMSE (20 Heun steps, EMA) = 0.8737
# [progress] epoch 352/2000 | train_loss=1.1272 | train_loss_epoch=1.1272 | train_loss_step=0.7723 | val_rmse_ema=0.8737
# [Epoch 351]  Val RMSE (20 Heun steps, EMA) = 0.8737
# [progress] epoch 353/2000 | train_loss=1.1331 | train_loss_epoch=1.1331 | train_loss_step=0.8403 | val_rmse_ema=0.8737
# [Epoch 352]  Val RMSE (20 Heun steps, EMA) = 0.8725
# [progress] epoch 354/2000 | train_loss=1.1548 | train_loss_epoch=1.1548 | train_loss_step=0.8178 | val_rmse_ema=0.8725
# [Epoch 353]  Val RMSE (20 Heun steps, EMA) = 0.8736
# [progress] epoch 355/2000 | train_loss=1.1144 | train_loss_epoch=1.1144 | train_loss_step=1.0884 | val_rmse_ema=0.8736
# [Epoch 354]  Val RMSE (20 Heun steps, EMA) = 0.8772
# [progress] epoch 356/2000 | train_loss=1.1057 | train_loss_epoch=1.1057 | train_loss_step=1.1957 | val_rmse_ema=0.8772
# [Epoch 355]  Val RMSE (20 Heun steps, EMA) = 0.8720
# [progress] epoch 357/2000 | train_loss=1.1467 | train_loss_epoch=1.1467 | train_loss_step=0.9370 | val_rmse_ema=0.8720
# [Epoch 356]  Val RMSE (20 Heun steps, EMA) = 0.8737
# [progress] epoch 358/2000 | train_loss=1.1610 | train_loss_epoch=1.1610 | train_loss_step=1.4269 | val_rmse_ema=0.8737
# [Epoch 357]  Val RMSE (20 Heun steps, EMA) = 0.8773
# [progress] epoch 359/2000 | train_loss=1.1557 | train_loss_epoch=1.1557 | train_loss_step=1.3087 | val_rmse_ema=0.8773
# [Epoch 358]  Val RMSE (20 Heun steps, EMA) = 0.8725
# [progress] epoch 360/2000 | train_loss=1.1170 | train_loss_epoch=1.1170 | train_loss_step=0.8211 | val_rmse_ema=0.8725
# [Epoch 359]  Val RMSE (20 Heun steps, EMA) = 0.8742
# [progress] epoch 361/2000 | train_loss=1.1496 | train_loss_epoch=1.1496 | train_loss_step=1.4123 | val_rmse_ema=0.8742
# [Epoch 360]  Val RMSE (20 Heun steps, EMA) = 0.8759
# [progress] epoch 362/2000 | train_loss=1.1218 | train_loss_epoch=1.1218 | train_loss_step=1.4225 | val_rmse_ema=0.8759
# [Epoch 361]  Val RMSE (20 Heun steps, EMA) = 0.8743
# [progress] epoch 363/2000 | train_loss=1.1407 | train_loss_epoch=1.1407 | train_loss_step=1.3190 | val_rmse_ema=0.8743
# [Epoch 362]  Val RMSE (20 Heun steps, EMA) = 0.8726
# [progress] epoch 364/2000 | train_loss=1.0914 | train_loss_epoch=1.0914 | train_loss_step=1.3551 | val_rmse_ema=0.8726
# [Epoch 363]  Val RMSE (20 Heun steps, EMA) = 0.8727
# [progress] epoch 365/2000 | train_loss=1.1148 | train_loss_epoch=1.1148 | train_loss_step=0.9932 | val_rmse_ema=0.8727
# [Epoch 364]  Val RMSE (20 Heun steps, EMA) = 0.8740
# [progress] epoch 366/2000 | train_loss=1.1038 | train_loss_epoch=1.1038 | train_loss_step=1.4351 | val_rmse_ema=0.8740
# [Epoch 365]  Val RMSE (20 Heun steps, EMA) = 0.8728
# [progress] epoch 367/2000 | train_loss=1.1063 | train_loss_epoch=1.1063 | train_loss_step=1.3221 | val_rmse_ema=0.8728
# [Epoch 366]  Val RMSE (20 Heun steps, EMA) = 0.8730
# [progress] epoch 368/2000 | train_loss=1.0984 | train_loss_epoch=1.0984 | train_loss_step=1.3589 | val_rmse_ema=0.8730
# [Epoch 367]  Val RMSE (20 Heun steps, EMA) = 0.8713
# [progress] epoch 369/2000 | train_loss=1.1143 | train_loss_epoch=1.1143 | train_loss_step=0.8207 | val_rmse_ema=0.8713
# [Epoch 368]  Val RMSE (20 Heun steps, EMA) = 0.8742
# [progress] epoch 370/2000 | train_loss=1.1446 | train_loss_epoch=1.1446 | train_loss_step=0.9225 | val_rmse_ema=0.8742
# [Epoch 369]  Val RMSE (20 Heun steps, EMA) = 0.8757
# [progress] epoch 371/2000 | train_loss=1.1056 | train_loss_epoch=1.1056 | train_loss_step=1.4439 | val_rmse_ema=0.8757
# [Epoch 370]  Val RMSE (20 Heun steps, EMA) = 0.8724
# [progress] epoch 372/2000 | train_loss=1.1238 | train_loss_epoch=1.1238 | train_loss_step=0.9836 | val_rmse_ema=0.8724
# [Epoch 371]  Val RMSE (20 Heun steps, EMA) = 0.8772
# [progress] epoch 373/2000 | train_loss=1.1262 | train_loss_epoch=1.1262 | train_loss_step=1.3922 | val_rmse_ema=0.8772
# [Epoch 372]  Val RMSE (20 Heun steps, EMA) = 0.8769
# [progress] epoch 374/2000 | train_loss=1.1150 | train_loss_epoch=1.1150 | train_loss_step=0.6985 | val_rmse_ema=0.8769
# [Epoch 373]  Val RMSE (20 Heun steps, EMA) = 0.8715
# [progress] epoch 375/2000 | train_loss=1.1358 | train_loss_epoch=1.1358 | train_loss_step=0.7367 | val_rmse_ema=0.8715
# [Epoch 374]  Val RMSE (20 Heun steps, EMA) = 0.8765
# [progress] epoch 376/2000 | train_loss=1.1480 | train_loss_epoch=1.1480 | train_loss_step=1.0846 | val_rmse_ema=0.8765
# [Epoch 375]  Val RMSE (20 Heun steps, EMA) = 0.8732
# [progress] epoch 377/2000 | train_loss=1.1147 | train_loss_epoch=1.1147 | train_loss_step=1.3512 | val_rmse_ema=0.8732
# [Epoch 376]  Val RMSE (20 Heun steps, EMA) = 0.8749
# [progress] epoch 378/2000 | train_loss=1.1152 | train_loss_epoch=1.1152 | train_loss_step=1.0964 | val_rmse_ema=0.8749
# [Epoch 377]  Val RMSE (20 Heun steps, EMA) = 0.8740
# [progress] epoch 379/2000 | train_loss=1.1344 | train_loss_epoch=1.1344 | train_loss_step=0.9892 | val_rmse_ema=0.8740
# [Epoch 378]  Val RMSE (20 Heun steps, EMA) = 0.8696
# [progress] epoch 380/2000 | train_loss=1.1191 | train_loss_epoch=1.1191 | train_loss_step=1.1487 | val_rmse_ema=0.8696
# [Epoch 379]  Val RMSE (20 Heun steps, EMA) = 0.8748
# [progress] epoch 381/2000 | train_loss=1.1264 | train_loss_epoch=1.1264 | train_loss_step=1.3688 | val_rmse_ema=0.8748
# [Epoch 380]  Val RMSE (20 Heun steps, EMA) = 0.8769
# [progress] epoch 382/2000 | train_loss=1.0984 | train_loss_epoch=1.0984 | train_loss_step=0.7460 | val_rmse_ema=0.8769
# [Epoch 381]  Val RMSE (20 Heun steps, EMA) = 0.8705
# [progress] epoch 383/2000 | train_loss=1.1034 | train_loss_epoch=1.1034 | train_loss_step=1.3713 | val_rmse_ema=0.8705
# [Epoch 382]  Val RMSE (20 Heun steps, EMA) = 0.8708
# [progress] epoch 384/2000 | train_loss=1.1093 | train_loss_epoch=1.1093 | train_loss_step=1.3274 | val_rmse_ema=0.8708
# [Epoch 383]  Val RMSE (20 Heun steps, EMA) = 0.8744
# [progress] epoch 385/2000 | train_loss=1.0911 | train_loss_epoch=1.0911 | train_loss_step=1.0312 | val_rmse_ema=0.8744
# [Epoch 384]  Val RMSE (20 Heun steps, EMA) = 0.8742
# [progress] epoch 386/2000 | train_loss=1.1241 | train_loss_epoch=1.1241 | train_loss_step=1.0627 | val_rmse_ema=0.8742
# [Epoch 385]  Val RMSE (20 Heun steps, EMA) = 0.8743
# [progress] epoch 387/2000 | train_loss=1.1294 | train_loss_epoch=1.1294 | train_loss_step=1.0768 | val_rmse_ema=0.8743
# [Epoch 386]  Val RMSE (20 Heun steps, EMA) = 0.8788
# [progress] epoch 388/2000 | train_loss=1.1160 | train_loss_epoch=1.1160 | train_loss_step=1.3758 | val_rmse_ema=0.8788
# [Epoch 387]  Val RMSE (20 Heun steps, EMA) = 0.8783
# [progress] epoch 389/2000 | train_loss=1.1145 | train_loss_epoch=1.1145 | train_loss_step=1.3310 | val_rmse_ema=0.8783
# [Epoch 388]  Val RMSE (20 Heun steps, EMA) = 0.8751
# [progress] epoch 390/2000 | train_loss=1.1095 | train_loss_epoch=1.1095 | train_loss_step=1.1651 | val_rmse_ema=0.8751
# [Epoch 389]  Val RMSE (20 Heun steps, EMA) = 0.8758
# [progress] epoch 391/2000 | train_loss=1.0933 | train_loss_epoch=1.0933 | train_loss_step=0.7726 | val_rmse_ema=0.8758
# [Epoch 390]  Val RMSE (20 Heun steps, EMA) = 0.8761
# [progress] epoch 392/2000 | train_loss=1.1164 | train_loss_epoch=1.1164 | train_loss_step=1.2615 | val_rmse_ema=0.8761
# [Epoch 391]  Val RMSE (20 Heun steps, EMA) = 0.8748
# [progress] epoch 393/2000 | train_loss=1.1116 | train_loss_epoch=1.1116 | train_loss_step=1.1639 | val_rmse_ema=0.8748
# [Epoch 392]  Val RMSE (20 Heun steps, EMA) = 0.8770
# [progress] epoch 394/2000 | train_loss=1.0539 | train_loss_epoch=1.0539 | train_loss_step=0.6475 | val_rmse_ema=0.8770
# [Epoch 393]  Val RMSE (20 Heun steps, EMA) = 0.8740
# [progress] epoch 395/2000 | train_loss=1.1147 | train_loss_epoch=1.1147 | train_loss_step=1.2880 | val_rmse_ema=0.8740
# [Epoch 394]  Val RMSE (20 Heun steps, EMA) = 0.8760
# [progress] epoch 396/2000 | train_loss=1.0821 | train_loss_epoch=1.0821 | train_loss_step=1.4338 | val_rmse_ema=0.8760
# [Epoch 395]  Val RMSE (20 Heun steps, EMA) = 0.8762
# [progress] epoch 397/2000 | train_loss=1.0935 | train_loss_epoch=1.0935 | train_loss_step=1.3614 | val_rmse_ema=0.8762
# [Epoch 396]  Val RMSE (20 Heun steps, EMA) = 0.8716
# [progress] epoch 398/2000 | train_loss=1.0803 | train_loss_epoch=1.0803 | train_loss_step=1.2585 | val_rmse_ema=0.8716
# [Epoch 397]  Val RMSE (20 Heun steps, EMA) = 0.8738
# [progress] epoch 399/2000 | train_loss=1.0900 | train_loss_epoch=1.0900 | train_loss_step=1.3718 | val_rmse_ema=0.8738
# [Epoch 398]  Val RMSE (20 Heun steps, EMA) = 0.8796
# [progress] epoch 400/2000 | train_loss=1.1043 | train_loss_epoch=1.1043 | train_loss_step=1.0936 | val_rmse_ema=0.8796
# [Epoch 399]  Val RMSE (20 Heun steps, EMA) = 0.8687
# [progress] epoch 401/2000 | train_loss=1.0693 | train_loss_epoch=1.0693 | train_loss_step=1.1567 | val_rmse_ema=0.8687
# [Epoch 400]  Val RMSE (20 Heun steps, EMA) = 0.8703
# [progress] epoch 402/2000 | train_loss=1.0791 | train_loss_epoch=1.0791 | train_loss_step=1.0611 | val_rmse_ema=0.8703
# [Epoch 401]  Val RMSE (20 Heun steps, EMA) = 0.8744
# [progress] epoch 403/2000 | train_loss=1.0983 | train_loss_epoch=1.0983 | train_loss_step=1.3966 | val_rmse_ema=0.8744
# [Epoch 402]  Val RMSE (20 Heun steps, EMA) = 0.8734
# [progress] epoch 404/2000 | train_loss=1.1156 | train_loss_epoch=1.1156 | train_loss_step=1.3206 | val_rmse_ema=0.8734
# [Epoch 403]  Val RMSE (20 Heun steps, EMA) = 0.8726
# [progress] epoch 405/2000 | train_loss=1.0731 | train_loss_epoch=1.0731 | train_loss_step=1.4399 | val_rmse_ema=0.8726
# [Epoch 404]  Val RMSE (20 Heun steps, EMA) = 0.8768
# [progress] epoch 406/2000 | train_loss=1.0947 | train_loss_epoch=1.0947 | train_loss_step=0.7756 | val_rmse_ema=0.8768
# [Epoch 405]  Val RMSE (20 Heun steps, EMA) = 0.8724
# [progress] epoch 407/2000 | train_loss=1.0739 | train_loss_epoch=1.0739 | train_loss_step=0.7248 | val_rmse_ema=0.8724
# [Epoch 406]  Val RMSE (20 Heun steps, EMA) = 0.8731
# [progress] epoch 408/2000 | train_loss=1.1130 | train_loss_epoch=1.1130 | train_loss_step=0.7541 | val_rmse_ema=0.8731
# [Epoch 407]  Val RMSE (20 Heun steps, EMA) = 0.8708
# [progress] epoch 409/2000 | train_loss=1.0784 | train_loss_epoch=1.0784 | train_loss_step=0.9618 | val_rmse_ema=0.8708
# [Epoch 408]  Val RMSE (20 Heun steps, EMA) = 0.8743
# [progress] epoch 410/2000 | train_loss=1.0835 | train_loss_epoch=1.0835 | train_loss_step=1.3224 | val_rmse_ema=0.8743
# [Epoch 409]  Val RMSE (20 Heun steps, EMA) = 0.8730
# [progress] epoch 411/2000 | train_loss=1.0865 | train_loss_epoch=1.0865 | train_loss_step=1.4207 | val_rmse_ema=0.8730
# [Epoch 410]  Val RMSE (20 Heun steps, EMA) = 0.8713
# [progress] epoch 412/2000 | train_loss=1.1104 | train_loss_epoch=1.1104 | train_loss_step=0.7537 | val_rmse_ema=0.8713
# [Epoch 411]  Val RMSE (20 Heun steps, EMA) = 0.8767
# [progress] epoch 413/2000 | train_loss=1.1126 | train_loss_epoch=1.1126 | train_loss_step=1.1027 | val_rmse_ema=0.8767
# [Epoch 412]  Val RMSE (20 Heun steps, EMA) = 0.8728
# [progress] epoch 414/2000 | train_loss=1.0882 | train_loss_epoch=1.0882 | train_loss_step=0.9021 | val_rmse_ema=0.8728
# [Epoch 413]  Val RMSE (20 Heun steps, EMA) = 0.8721
# [progress] epoch 415/2000 | train_loss=1.1188 | train_loss_epoch=1.1188 | train_loss_step=0.9704 | val_rmse_ema=0.8721
# [Epoch 414]  Val RMSE (20 Heun steps, EMA) = 0.8749
# [progress] epoch 416/2000 | train_loss=1.1273 | train_loss_epoch=1.1273 | train_loss_step=0.8111 | val_rmse_ema=0.8749
# [Epoch 415]  Val RMSE (20 Heun steps, EMA) = 0.8744
# [progress] epoch 417/2000 | train_loss=1.0667 | train_loss_epoch=1.0667 | train_loss_step=0.6911 | val_rmse_ema=0.8744
# [Epoch 416]  Val RMSE (20 Heun steps, EMA) = 0.8745
# [progress] epoch 418/2000 | train_loss=1.0721 | train_loss_epoch=1.0721 | train_loss_step=1.0240 | val_rmse_ema=0.8745
# [Epoch 417]  Val RMSE (20 Heun steps, EMA) = 0.8753
# [progress] epoch 419/2000 | train_loss=1.0746 | train_loss_epoch=1.0746 | train_loss_step=0.7890 | val_rmse_ema=0.8753
# [Epoch 418]  Val RMSE (20 Heun steps, EMA) = 0.8723
# [progress] epoch 420/2000 | train_loss=1.0988 | train_loss_epoch=1.0988 | train_loss_step=0.9645 | val_rmse_ema=0.8723
# [Epoch 419]  Val RMSE (20 Heun steps, EMA) = 0.8767
# [progress] epoch 421/2000 | train_loss=1.0877 | train_loss_epoch=1.0877 | train_loss_step=1.3190 | val_rmse_ema=0.8767
# [Epoch 420]  Val RMSE (20 Heun steps, EMA) = 0.8771
# [progress] epoch 422/2000 | train_loss=1.0832 | train_loss_epoch=1.0832 | train_loss_step=1.3789 | val_rmse_ema=0.8771
# [Epoch 421]  Val RMSE (20 Heun steps, EMA) = 0.8733
# [progress] epoch 423/2000 | train_loss=1.1033 | train_loss_epoch=1.1033 | train_loss_step=1.3938 | val_rmse_ema=0.8733
# [Epoch 422]  Val RMSE (20 Heun steps, EMA) = 0.8710
# [progress] epoch 424/2000 | train_loss=1.0833 | train_loss_epoch=1.0833 | train_loss_step=1.1878 | val_rmse_ema=0.8710
# [Epoch 423]  Val RMSE (20 Heun steps, EMA) = 0.8750
# [progress] epoch 425/2000 | train_loss=1.0802 | train_loss_epoch=1.0802 | train_loss_step=1.3358 | val_rmse_ema=0.8750
# [Epoch 424]  Val RMSE (20 Heun steps, EMA) = 0.8780
# [progress] epoch 426/2000 | train_loss=1.0758 | train_loss_epoch=1.0758 | train_loss_step=1.2391 | val_rmse_ema=0.8780
# [Epoch 425]  Val RMSE (20 Heun steps, EMA) = 0.8727
# [progress] epoch 427/2000 | train_loss=1.0865 | train_loss_epoch=1.0865 | train_loss_step=0.8561 | val_rmse_ema=0.8727
# [Epoch 426]  Val RMSE (20 Heun steps, EMA) = 0.8733
# [progress] epoch 428/2000 | train_loss=1.0804 | train_loss_epoch=1.0804 | train_loss_step=0.7496 | val_rmse_ema=0.8733
# [Epoch 427]  Val RMSE (20 Heun steps, EMA) = 0.8745
# [progress] epoch 429/2000 | train_loss=1.1059 | train_loss_epoch=1.1059 | train_loss_step=1.4363 | val_rmse_ema=0.8745
# [Epoch 428]  Val RMSE (20 Heun steps, EMA) = 0.8731
# [progress] epoch 430/2000 | train_loss=1.0403 | train_loss_epoch=1.0403 | train_loss_step=1.4464 | val_rmse_ema=0.8731
# [Epoch 429]  Val RMSE (20 Heun steps, EMA) = 0.8740
# [progress] epoch 431/2000 | train_loss=1.0891 | train_loss_epoch=1.0891 | train_loss_step=0.7165 | val_rmse_ema=0.8740
# [Epoch 430]  Val RMSE (20 Heun steps, EMA) = 0.8735
# [progress] epoch 432/2000 | train_loss=1.0735 | train_loss_epoch=1.0735 | train_loss_step=0.9925 | val_rmse_ema=0.8735
# [Epoch 431]  Val RMSE (20 Heun steps, EMA) = 0.8752
# [progress] epoch 433/2000 | train_loss=1.1146 | train_loss_epoch=1.1146 | train_loss_step=1.1287 | val_rmse_ema=0.8752
# [Epoch 432]  Val RMSE (20 Heun steps, EMA) = 0.8768
# [progress] epoch 434/2000 | train_loss=1.0753 | train_loss_epoch=1.0753 | train_loss_step=1.2961 | val_rmse_ema=0.8768
# [Epoch 433]  Val RMSE (20 Heun steps, EMA) = 0.8724
# [progress] epoch 435/2000 | train_loss=1.0817 | train_loss_epoch=1.0817 | train_loss_step=1.3602 | val_rmse_ema=0.8724
# [Epoch 434]  Val RMSE (20 Heun steps, EMA) = 0.8769
# [progress] epoch 436/2000 | train_loss=1.0789 | train_loss_epoch=1.0789 | train_loss_step=1.3551 | val_rmse_ema=0.8769
# [Epoch 435]  Val RMSE (20 Heun steps, EMA) = 0.8774
# [progress] epoch 437/2000 | train_loss=1.0817 | train_loss_epoch=1.0817 | train_loss_step=0.9757 | val_rmse_ema=0.8774
# [Epoch 436]  Val RMSE (20 Heun steps, EMA) = 0.8742
# [progress] epoch 438/2000 | train_loss=1.0868 | train_loss_epoch=1.0868 | train_loss_step=0.6309 | val_rmse_ema=0.8742
# [Epoch 437]  Val RMSE (20 Heun steps, EMA) = 0.8755
# [progress] epoch 439/2000 | train_loss=1.0707 | train_loss_epoch=1.0707 | train_loss_step=0.6250 | val_rmse_ema=0.8755
# [Epoch 438]  Val RMSE (20 Heun steps, EMA) = 0.8735
# [progress] epoch 440/2000 | train_loss=1.1078 | train_loss_epoch=1.1078 | train_loss_step=1.2203 | val_rmse_ema=0.8735
# [Epoch 439]  Val RMSE (20 Heun steps, EMA) = 0.8738
# [progress] epoch 441/2000 | train_loss=1.0890 | train_loss_epoch=1.0890 | train_loss_step=0.9511 | val_rmse_ema=0.8738
# [Epoch 440]  Val RMSE (20 Heun steps, EMA) = 0.8744
# [progress] epoch 442/2000 | train_loss=1.0846 | train_loss_epoch=1.0846 | train_loss_step=0.9926 | val_rmse_ema=0.8744
# [Epoch 441]  Val RMSE (20 Heun steps, EMA) = 0.8745
# [progress] epoch 443/2000 | train_loss=1.0623 | train_loss_epoch=1.0623 | train_loss_step=1.4391 | val_rmse_ema=0.8745
# [Epoch 442]  Val RMSE (20 Heun steps, EMA) = 0.8758
# [progress] epoch 444/2000 | train_loss=1.0626 | train_loss_epoch=1.0626 | train_loss_step=1.3125 | val_rmse_ema=0.8758
# [Epoch 443]  Val RMSE (20 Heun steps, EMA) = 0.8745
# [progress] epoch 445/2000 | train_loss=1.0643 | train_loss_epoch=1.0643 | train_loss_step=1.4449 | val_rmse_ema=0.8745
# [Epoch 444]  Val RMSE (20 Heun steps, EMA) = 0.8752
# [progress] epoch 446/2000 | train_loss=1.0730 | train_loss_epoch=1.0730 | train_loss_step=1.4321 | val_rmse_ema=0.8752
# [Epoch 445]  Val RMSE (20 Heun steps, EMA) = 0.8773
# [progress] epoch 447/2000 | train_loss=1.0647 | train_loss_epoch=1.0647 | train_loss_step=1.2902 | val_rmse_ema=0.8773
# [Epoch 446]  Val RMSE (20 Heun steps, EMA) = 0.8757
# [progress] epoch 448/2000 | train_loss=1.0733 | train_loss_epoch=1.0733 | train_loss_step=1.1737 | val_rmse_ema=0.8757
# [Epoch 447]  Val RMSE (20 Heun steps, EMA) = 0.8794
# [progress] epoch 449/2000 | train_loss=1.1084 | train_loss_epoch=1.1084 | train_loss_step=0.6603 | val_rmse_ema=0.8794
# [Epoch 448]  Val RMSE (20 Heun steps, EMA) = 0.8740
# [progress] epoch 450/2000 | train_loss=1.0551 | train_loss_epoch=1.0551 | train_loss_step=1.3966 | val_rmse_ema=0.8740
# [Epoch 449]  Val RMSE (20 Heun steps, EMA) = 0.8724
# [progress] epoch 451/2000 | train_loss=1.0484 | train_loss_epoch=1.0484 | train_loss_step=1.3167 | val_rmse_ema=0.8724
# [Epoch 450]  Val RMSE (20 Heun steps, EMA) = 0.8749
# [progress] epoch 452/2000 | train_loss=1.0750 | train_loss_epoch=1.0750 | train_loss_step=1.0466 | val_rmse_ema=0.8749
# [Epoch 451]  Val RMSE (20 Heun steps, EMA) = 0.8776
# [progress] epoch 453/2000 | train_loss=1.0816 | train_loss_epoch=1.0816 | train_loss_step=1.0599 | val_rmse_ema=0.8776
# [Epoch 452]  Val RMSE (20 Heun steps, EMA) = 0.8734
# [progress] epoch 454/2000 | train_loss=1.0396 | train_loss_epoch=1.0396 | train_loss_step=1.2776 | val_rmse_ema=0.8734
# [Epoch 453]  Val RMSE (20 Heun steps, EMA) = 0.8753
# [progress] epoch 455/2000 | train_loss=1.0682 | train_loss_epoch=1.0682 | train_loss_step=1.3886 | val_rmse_ema=0.8753
# [Epoch 454]  Val RMSE (20 Heun steps, EMA) = 0.8770
# [progress] epoch 456/2000 | train_loss=1.0786 | train_loss_epoch=1.0786 | train_loss_step=0.8103 | val_rmse_ema=0.8770
# [Epoch 455]  Val RMSE (20 Heun steps, EMA) = 0.8749
# [progress] epoch 457/2000 | train_loss=1.0716 | train_loss_epoch=1.0716 | train_loss_step=1.4074 | val_rmse_ema=0.8749
# [Epoch 456]  Val RMSE (20 Heun steps, EMA) = 0.8761
# [progress] epoch 458/2000 | train_loss=1.0592 | train_loss_epoch=1.0592 | train_loss_step=1.3414 | val_rmse_ema=0.8761
# [Epoch 457]  Val RMSE (20 Heun steps, EMA) = 0.8745
# [progress] epoch 459/2000 | train_loss=1.0738 | train_loss_epoch=1.0738 | train_loss_step=1.1148 | val_rmse_ema=0.8745
# [Epoch 458]  Val RMSE (20 Heun steps, EMA) = 0.8774
# [progress] epoch 460/2000 | train_loss=1.0655 | train_loss_epoch=1.0655 | train_loss_step=1.3041 | val_rmse_ema=0.8774
# [Epoch 459]  Val RMSE (20 Heun steps, EMA) = 0.8753
# [progress] epoch 461/2000 | train_loss=1.0816 | train_loss_epoch=1.0816 | train_loss_step=0.6728 | val_rmse_ema=0.8753
# [Epoch 460]  Val RMSE (20 Heun steps, EMA) = 0.8760
# [progress] epoch 462/2000 | train_loss=1.0761 | train_loss_epoch=1.0761 | train_loss_step=1.2710 | val_rmse_ema=0.8760
# [Epoch 461]  Val RMSE (20 Heun steps, EMA) = 0.8774
# [progress] epoch 463/2000 | train_loss=1.0756 | train_loss_epoch=1.0756 | train_loss_step=0.8010 | val_rmse_ema=0.8774
# [Epoch 462]  Val RMSE (20 Heun steps, EMA) = 0.8785
# [progress] epoch 464/2000 | train_loss=1.0674 | train_loss_epoch=1.0674 | train_loss_step=1.0642 | val_rmse_ema=0.8785
# [Epoch 463]  Val RMSE (20 Heun steps, EMA) = 0.8738
# [progress] epoch 465/2000 | train_loss=1.0841 | train_loss_epoch=1.0841 | train_loss_step=1.1037 | val_rmse_ema=0.8738
# [Epoch 464]  Val RMSE (20 Heun steps, EMA) = 0.8755
# [progress] epoch 466/2000 | train_loss=1.0368 | train_loss_epoch=1.0368 | train_loss_step=1.4020 | val_rmse_ema=0.8755
# [Epoch 465]  Val RMSE (20 Heun steps, EMA) = 0.8771
# [progress] epoch 467/2000 | train_loss=1.0507 | train_loss_epoch=1.0507 | train_loss_step=1.2246 | val_rmse_ema=0.8771
# [Epoch 466]  Val RMSE (20 Heun steps, EMA) = 0.8792
# [progress] epoch 468/2000 | train_loss=1.0866 | train_loss_epoch=1.0866 | train_loss_step=1.2910 | val_rmse_ema=0.8792
# [Epoch 467]  Val RMSE (20 Heun steps, EMA) = 0.8780
# [progress] epoch 469/2000 | train_loss=1.0511 | train_loss_epoch=1.0511 | train_loss_step=0.7966 | val_rmse_ema=0.8780
# [Epoch 468]  Val RMSE (20 Heun steps, EMA) = 0.8777
# [progress] epoch 470/2000 | train_loss=1.0557 | train_loss_epoch=1.0557 | train_loss_step=1.0500 | val_rmse_ema=0.8777
# [Epoch 469]  Val RMSE (20 Heun steps, EMA) = 0.8794
# [progress] epoch 471/2000 | train_loss=1.0646 | train_loss_epoch=1.0646 | train_loss_step=0.6878 | val_rmse_ema=0.8794
# [Epoch 470]  Val RMSE (20 Heun steps, EMA) = 0.8808
# [progress] epoch 472/2000 | train_loss=1.1002 | train_loss_epoch=1.1002 | train_loss_step=1.3415 | val_rmse_ema=0.8808
# [Epoch 471]  Val RMSE (20 Heun steps, EMA) = 0.8787
# [progress] epoch 473/2000 | train_loss=1.0438 | train_loss_epoch=1.0438 | train_loss_step=1.3605 | val_rmse_ema=0.8787
# [Epoch 472]  Val RMSE (20 Heun steps, EMA) = 0.8804
# [progress] epoch 474/2000 | train_loss=1.0248 | train_loss_epoch=1.0248 | train_loss_step=0.8085 | val_rmse_ema=0.8804
# [Epoch 473]  Val RMSE (20 Heun steps, EMA) = 0.8789
# [progress] epoch 475/2000 | train_loss=1.0614 | train_loss_epoch=1.0614 | train_loss_step=1.1038 | val_rmse_ema=0.8789
# [Epoch 474]  Val RMSE (20 Heun steps, EMA) = 0.8816
# [progress] epoch 476/2000 | train_loss=1.0665 | train_loss_epoch=1.0665 | train_loss_step=1.3685 | val_rmse_ema=0.8816
# [Epoch 475]  Val RMSE (20 Heun steps, EMA) = 0.8728
# [progress] epoch 477/2000 | train_loss=1.0737 | train_loss_epoch=1.0737 | train_loss_step=1.1191 | val_rmse_ema=0.8728
# [Epoch 476]  Val RMSE (20 Heun steps, EMA) = 0.8832
# [progress] epoch 478/2000 | train_loss=1.0456 | train_loss_epoch=1.0456 | train_loss_step=0.6951 | val_rmse_ema=0.8832
# [Epoch 477]  Val RMSE (20 Heun steps, EMA) = 0.8833
# [progress] epoch 479/2000 | train_loss=1.0289 | train_loss_epoch=1.0289 | train_loss_step=0.8543 | val_rmse_ema=0.8833
# [Epoch 478]  Val RMSE (20 Heun steps, EMA) = 0.8774
# [progress] epoch 480/2000 | train_loss=1.0403 | train_loss_epoch=1.0403 | train_loss_step=0.5723 | val_rmse_ema=0.8774
# [Epoch 479]  Val RMSE (20 Heun steps, EMA) = 0.8814
# [progress] epoch 481/2000 | train_loss=1.0507 | train_loss_epoch=1.0507 | train_loss_step=1.0541 | val_rmse_ema=0.8814
# [Epoch 480]  Val RMSE (20 Heun steps, EMA) = 0.8757
# [progress] epoch 482/2000 | train_loss=1.0489 | train_loss_epoch=1.0489 | train_loss_step=1.3561 | val_rmse_ema=0.8757
# [Epoch 481]  Val RMSE (20 Heun steps, EMA) = 0.8814
# [progress] epoch 483/2000 | train_loss=1.0680 | train_loss_epoch=1.0680 | train_loss_step=1.0613 | val_rmse_ema=0.8814
# [Epoch 482]  Val RMSE (20 Heun steps, EMA) = 0.8795
# [progress] epoch 484/2000 | train_loss=1.0597 | train_loss_epoch=1.0597 | train_loss_step=1.4275 | val_rmse_ema=0.8795
# [Epoch 483]  Val RMSE (20 Heun steps, EMA) = 0.8825
# [progress] epoch 485/2000 | train_loss=1.0614 | train_loss_epoch=1.0614 | train_loss_step=1.0937 | val_rmse_ema=0.8825
# [Epoch 484]  Val RMSE (20 Heun steps, EMA) = 0.8805
# [progress] epoch 486/2000 | train_loss=1.0965 | train_loss_epoch=1.0965 | train_loss_step=1.3428 | val_rmse_ema=0.8805
# [Epoch 485]  Val RMSE (20 Heun steps, EMA) = 0.8827
# [progress] epoch 487/2000 | train_loss=1.0530 | train_loss_epoch=1.0530 | train_loss_step=1.1884 | val_rmse_ema=0.8827
# [Epoch 486]  Val RMSE (20 Heun steps, EMA) = 0.8820
# [progress] epoch 488/2000 | train_loss=1.0629 | train_loss_epoch=1.0629 | train_loss_step=1.1606 | val_rmse_ema=0.8820
# [Epoch 487]  Val RMSE (20 Heun steps, EMA) = 0.8830
# [progress] epoch 489/2000 | train_loss=1.0493 | train_loss_epoch=1.0493 | train_loss_step=1.3171 | val_rmse_ema=0.8830
# [Epoch 488]  Val RMSE (20 Heun steps, EMA) = 0.8810
# [progress] epoch 490/2000 | train_loss=1.0271 | train_loss_epoch=1.0271 | train_loss_step=0.6904 | val_rmse_ema=0.8810
# [Epoch 489]  Val RMSE (20 Heun steps, EMA) = 0.8783
# [progress] epoch 491/2000 | train_loss=0.9934 | train_loss_epoch=0.9934 | train_loss_step=1.1255 | val_rmse_ema=0.8783
# [Epoch 490]  Val RMSE (20 Heun steps, EMA) = 0.8771
# [progress] epoch 492/2000 | train_loss=1.0611 | train_loss_epoch=1.0611 | train_loss_step=1.2052 | val_rmse_ema=0.8771
# [Epoch 491]  Val RMSE (20 Heun steps, EMA) = 0.8785
# [progress] epoch 493/2000 | train_loss=1.0533 | train_loss_epoch=1.0533 | train_loss_step=1.0861 | val_rmse_ema=0.8785
# [Epoch 492]  Val RMSE (20 Heun steps, EMA) = 0.8775
# [progress] epoch 494/2000 | train_loss=1.0511 | train_loss_epoch=1.0511 | train_loss_step=0.9397 | val_rmse_ema=0.8775
# [Epoch 493]  Val RMSE (20 Heun steps, EMA) = 0.8822
# [progress] epoch 495/2000 | train_loss=1.0318 | train_loss_epoch=1.0318 | train_loss_step=1.1874 | val_rmse_ema=0.8822
# [Epoch 494]  Val RMSE (20 Heun steps, EMA) = 0.8819
# [progress] epoch 496/2000 | train_loss=1.0341 | train_loss_epoch=1.0341 | train_loss_step=1.2488 | val_rmse_ema=0.8819
# [Epoch 495]  Val RMSE (20 Heun steps, EMA) = 0.8813
# [progress] epoch 497/2000 | train_loss=1.0498 | train_loss_epoch=1.0498 | train_loss_step=0.9068 | val_rmse_ema=0.8813
# [Epoch 496]  Val RMSE (20 Heun steps, EMA) = 0.8831
# [progress] epoch 498/2000 | train_loss=1.0140 | train_loss_epoch=1.0140 | train_loss_step=0.8709 | val_rmse_ema=0.8831
# [Epoch 497]  Val RMSE (20 Heun steps, EMA) = 0.8823
# [progress] epoch 499/2000 | train_loss=1.0556 | train_loss_epoch=1.0556 | train_loss_step=0.7831 | val_rmse_ema=0.8823
# [Epoch 498]  Val RMSE (20 Heun steps, EMA) = 0.8764
# [progress] epoch 500/2000 | train_loss=1.0221 | train_loss_epoch=1.0221 | train_loss_step=0.8548 | val_rmse_ema=0.8764
# [Epoch 499]  Val RMSE (20 Heun steps, EMA) = 0.8832
# [progress] epoch 501/2000 | train_loss=1.0099 | train_loss_epoch=1.0099 | train_loss_step=0.9151 | val_rmse_ema=0.8832
# [Epoch 500]  Val RMSE (20 Heun steps, EMA) = 0.8808
# [progress] epoch 502/2000 | train_loss=1.0096 | train_loss_epoch=1.0096 | train_loss_step=1.2467 | val_rmse_ema=0.8808
# [Epoch 501]  Val RMSE (20 Heun steps, EMA) = 0.8801
# [progress] epoch 503/2000 | train_loss=1.0268 | train_loss_epoch=1.0268 | train_loss_step=0.8931 | val_rmse_ema=0.8801
# [Epoch 502]  Val RMSE (20 Heun steps, EMA) = 0.8820
# [progress] epoch 504/2000 | train_loss=0.9969 | train_loss_epoch=0.9969 | train_loss_step=0.5284 | val_rmse_ema=0.8820
# [Epoch 503]  Val RMSE (20 Heun steps, EMA) = 0.8816
# [progress] epoch 505/2000 | train_loss=1.0120 | train_loss_epoch=1.0120 | train_loss_step=0.8102 | val_rmse_ema=0.8816
# [Epoch 504]  Val RMSE (20 Heun steps, EMA) = 0.8852
# [progress] epoch 506/2000 | train_loss=0.9930 | train_loss_epoch=0.9930 | train_loss_step=0.7483 | val_rmse_ema=0.8852
# [Epoch 505]  Val RMSE (20 Heun steps, EMA) = 0.8833
# [progress] epoch 507/2000 | train_loss=1.0442 | train_loss_epoch=1.0442 | train_loss_step=0.9266 | val_rmse_ema=0.8833
# [Epoch 506]  Val RMSE (20 Heun steps, EMA) = 0.8816
# [progress] epoch 508/2000 | train_loss=1.0408 | train_loss_epoch=1.0408 | train_loss_step=0.5987 | val_rmse_ema=0.8816
# [Epoch 507]  Val RMSE (20 Heun steps, EMA) = 0.8834
# [progress] epoch 509/2000 | train_loss=1.0240 | train_loss_epoch=1.0240 | train_loss_step=1.2122 | val_rmse_ema=0.8834
# [Epoch 508]  Val RMSE (20 Heun steps, EMA) = 0.8830
# [progress] epoch 510/2000 | train_loss=1.0249 | train_loss_epoch=1.0249 | train_loss_step=0.9201 | val_rmse_ema=0.8830
# [Epoch 509]  Val RMSE (20 Heun steps, EMA) = 0.8835
# [progress] epoch 511/2000 | train_loss=1.0379 | train_loss_epoch=1.0379 | train_loss_step=1.0282 | val_rmse_ema=0.8835
# [Epoch 510]  Val RMSE (20 Heun steps, EMA) = 0.8827
# [progress] epoch 512/2000 | train_loss=1.0344 | train_loss_epoch=1.0344 | train_loss_step=0.7587 | val_rmse_ema=0.8827
# [Epoch 511]  Val RMSE (20 Heun steps, EMA) = 0.8870
# [progress] epoch 513/2000 | train_loss=1.0147 | train_loss_epoch=1.0147 | train_loss_step=1.3607 | val_rmse_ema=0.8870
# [Epoch 512]  Val RMSE (20 Heun steps, EMA) = 0.8836
# [progress] epoch 514/2000 | train_loss=1.0535 | train_loss_epoch=1.0535 | train_loss_step=0.6163 | val_rmse_ema=0.8836
# [Epoch 513]  Val RMSE (20 Heun steps, EMA) = 0.8864
# [progress] epoch 515/2000 | train_loss=0.9944 | train_loss_epoch=0.9944 | train_loss_step=0.5524 | val_rmse_ema=0.8864
# [Epoch 514]  Val RMSE (20 Heun steps, EMA) = 0.8820
# [progress] epoch 516/2000 | train_loss=1.0252 | train_loss_epoch=1.0252 | train_loss_step=0.9504 | val_rmse_ema=0.8820
# [Epoch 515]  Val RMSE (20 Heun steps, EMA) = 0.8830
# [progress] epoch 517/2000 | train_loss=1.0246 | train_loss_epoch=1.0246 | train_loss_step=1.2823 | val_rmse_ema=0.8830
# [Epoch 516]  Val RMSE (20 Heun steps, EMA) = 0.8845
# [progress] epoch 518/2000 | train_loss=1.0020 | train_loss_epoch=1.0020 | train_loss_step=1.0152 | val_rmse_ema=0.8845
# [Epoch 517]  Val RMSE (20 Heun steps, EMA) = 0.8836
# [progress] epoch 519/2000 | train_loss=1.0432 | train_loss_epoch=1.0432 | train_loss_step=0.6940 | val_rmse_ema=0.8836
# [Epoch 518]  Val RMSE (20 Heun steps, EMA) = 0.8823
# [progress] epoch 520/2000 | train_loss=0.9804 | train_loss_epoch=0.9804 | train_loss_step=1.0402 | val_rmse_ema=0.8823
# [Epoch 519]  Val RMSE (20 Heun steps, EMA) = 0.8812
# [progress] epoch 521/2000 | train_loss=1.0088 | train_loss_epoch=1.0088 | train_loss_step=1.3571 | val_rmse_ema=0.8812
# [Epoch 520]  Val RMSE (20 Heun steps, EMA) = 0.8835
# [progress] epoch 522/2000 | train_loss=1.0159 | train_loss_epoch=1.0159 | train_loss_step=1.2976 | val_rmse_ema=0.8835
# ...
# [Epoch 1908]  Val RMSE (20 Heun steps, EMA) = 0.9100
# [progress] epoch 1910/2000 | train_loss=0.6444 | train_loss_epoch=0.6444 | train_loss_step=0.8167 | val_rmse_ema=0.9100
# [Epoch 1909]  Val RMSE (20 Heun steps, EMA) = 0.9085
# [progress] epoch 1911/2000 | train_loss=0.5650 | train_loss_epoch=0.5650 | train_loss_step=0.6580 | val_rmse_ema=0.9085
# [Epoch 1910]  Val RMSE (20 Heun steps, EMA) = 0.9111
# [progress] epoch 1912/2000 | train_loss=0.6573 | train_loss_epoch=0.6573 | train_loss_step=1.3427 | val_rmse_ema=0.9111
# [Epoch 1911]  Val RMSE (20 Heun steps, EMA) = 0.9101
# [progress] epoch 1913/2000 | train_loss=0.5703 | train_loss_epoch=0.5703 | train_loss_step=0.0577 | val_rmse_ema=0.9101
# [Epoch 1912]  Val RMSE (20 Heun steps, EMA) = 0.9112
# [progress] epoch 1914/2000 | train_loss=0.5586 | train_loss_epoch=0.5586 | train_loss_step=0.1045 | val_rmse_ema=0.9112
# [Epoch 1913]  Val RMSE (20 Heun steps, EMA) = 0.9107
# [progress] epoch 1915/2000 | train_loss=0.6096 | train_loss_epoch=0.6096 | train_loss_step=1.2009 | val_rmse_ema=0.9107
# [Epoch 1914]  Val RMSE (20 Heun steps, EMA) = 0.9121
# [progress] epoch 1916/2000 | train_loss=0.5986 | train_loss_epoch=0.5986 | train_loss_step=1.0799 | val_rmse_ema=0.9121
# [Epoch 1915]  Val RMSE (20 Heun steps, EMA) = 0.9091
# [progress] epoch 1917/2000 | train_loss=0.6327 | train_loss_epoch=0.6327 | train_loss_step=0.3339 | val_rmse_ema=0.9091
# [Epoch 1916]  Val RMSE (20 Heun steps, EMA) = 0.9114
# [progress] epoch 1918/2000 | train_loss=0.6031 | train_loss_epoch=0.6031 | train_loss_step=1.0922 | val_rmse_ema=0.9114
# [Epoch 1917]  Val RMSE (20 Heun steps, EMA) = 0.9094
# [progress] epoch 1919/2000 | train_loss=0.5630 | train_loss_epoch=0.5630 | train_loss_step=-0.0333 | val_rmse_ema=0.9094
# [Epoch 1918]  Val RMSE (20 Heun steps, EMA) = 0.9110
# [progress] epoch 1920/2000 | train_loss=0.5960 | train_loss_epoch=0.5960 | train_loss_step=-0.0137 | val_rmse_ema=0.9110
# [Epoch 1919]  Val RMSE (20 Heun steps, EMA) = 0.9085
# [progress] epoch 1921/2000 | train_loss=0.5655 | train_loss_epoch=0.5655 | train_loss_step=0.7116 | val_rmse_ema=0.9085
# [Epoch 1920]  Val RMSE (20 Heun steps, EMA) = 0.9094
# [progress] epoch 1922/2000 | train_loss=0.5915 | train_loss_epoch=0.5915 | train_loss_step=0.6330 | val_rmse_ema=0.9094
# [Epoch 1921]  Val RMSE (20 Heun steps, EMA) = 0.9098
# [progress] epoch 1923/2000 | train_loss=0.5494 | train_loss_epoch=0.5494 | train_loss_step=-0.0122 | val_rmse_ema=0.9098
# [Epoch 1922]  Val RMSE (20 Heun steps, EMA) = 0.9094
# [progress] epoch 1924/2000 | train_loss=0.5368 | train_loss_epoch=0.5368 | train_loss_step=0.0382 | val_rmse_ema=0.9094
# [Epoch 1923]  Val RMSE (20 Heun steps, EMA) = 0.9096
# [progress] epoch 1925/2000 | train_loss=0.5846 | train_loss_epoch=0.5846 | train_loss_step=0.3638 | val_rmse_ema=0.9096
# [Epoch 1924]  Val RMSE (20 Heun steps, EMA) = 0.9104
# [progress] epoch 1926/2000 | train_loss=0.5874 | train_loss_epoch=0.5874 | train_loss_step=0.4992 | val_rmse_ema=0.9104
# [Epoch 1925]  Val RMSE (20 Heun steps, EMA) = 0.9096
# [progress] epoch 1927/2000 | train_loss=0.5874 | train_loss_epoch=0.5874 | train_loss_step=0.3018 | val_rmse_ema=0.9096
# [Epoch 1926]  Val RMSE (20 Heun steps, EMA) = 0.9093
# [progress] epoch 1928/2000 | train_loss=0.5812 | train_loss_epoch=0.5812 | train_loss_step=1.1599 | val_rmse_ema=0.9093
# [Epoch 1927]  Val RMSE (20 Heun steps, EMA) = 0.9097
# [progress] epoch 1929/2000 | train_loss=0.5179 | train_loss_epoch=0.5179 | train_loss_step=-0.1069 | val_rmse_ema=0.9097
# [Epoch 1928]  Val RMSE (20 Heun steps, EMA) = 0.9095
# [progress] epoch 1930/2000 | train_loss=0.6159 | train_loss_epoch=0.6159 | train_loss_step=0.1102 | val_rmse_ema=0.9095
# [Epoch 1929]  Val RMSE (20 Heun steps, EMA) = 0.9102
# [progress] epoch 1931/2000 | train_loss=0.5295 | train_loss_epoch=0.5295 | train_loss_step=0.1325 | val_rmse_ema=0.9102
# [Epoch 1930]  Val RMSE (20 Heun steps, EMA) = 0.9109
# [progress] epoch 1932/2000 | train_loss=0.5236 | train_loss_epoch=0.5236 | train_loss_step=0.1564 | val_rmse_ema=0.9109
# [Epoch 1931]  Val RMSE (20 Heun steps, EMA) = 0.9105
# [progress] epoch 1933/2000 | train_loss=0.5890 | train_loss_epoch=0.5890 | train_loss_step=0.9107 | val_rmse_ema=0.9105
# [Epoch 1932]  Val RMSE (20 Heun steps, EMA) = 0.9114
# [progress] epoch 1934/2000 | train_loss=0.5825 | train_loss_epoch=0.5825 | train_loss_step=1.3522 | val_rmse_ema=0.9114
# [Epoch 1933]  Val RMSE (20 Heun steps, EMA) = 0.9103
# [progress] epoch 1935/2000 | train_loss=0.5526 | train_loss_epoch=0.5526 | train_loss_step=0.6919 | val_rmse_ema=0.9103
# [Epoch 1934]  Val RMSE (20 Heun steps, EMA) = 0.9106
# [progress] epoch 1936/2000 | train_loss=0.5833 | train_loss_epoch=0.5833 | train_loss_step=-0.0315 | val_rmse_ema=0.9106
# [Epoch 1935]  Val RMSE (20 Heun steps, EMA) = 0.9094
# [progress] epoch 1937/2000 | train_loss=0.5626 | train_loss_epoch=0.5626 | train_loss_step=0.1067 | val_rmse_ema=0.9094
# [Epoch 1936]  Val RMSE (20 Heun steps, EMA) = 0.9100
# [progress] epoch 1938/2000 | train_loss=0.5417 | train_loss_epoch=0.5417 | train_loss_step=0.3748 | val_rmse_ema=0.9100
# [Epoch 1937]  Val RMSE (20 Heun steps, EMA) = 0.9109
# [progress] epoch 1939/2000 | train_loss=0.5943 | train_loss_epoch=0.5943 | train_loss_step=0.3351 | val_rmse_ema=0.9109
# [Epoch 1938]  Val RMSE (20 Heun steps, EMA) = 0.9100
# [progress] epoch 1940/2000 | train_loss=0.6106 | train_loss_epoch=0.6106 | train_loss_step=0.2285 | val_rmse_ema=0.9100
# [Epoch 1939]  Val RMSE (20 Heun steps, EMA) = 0.9087
# [progress] epoch 1941/2000 | train_loss=0.5305 | train_loss_epoch=0.5305 | train_loss_step=0.8164 | val_rmse_ema=0.9087
# [Epoch 1940]  Val RMSE (20 Heun steps, EMA) = 0.9089
# [progress] epoch 1942/2000 | train_loss=0.5488 | train_loss_epoch=0.5488 | train_loss_step=0.8723 | val_rmse_ema=0.9089
# [Epoch 1941]  Val RMSE (20 Heun steps, EMA) = 0.9098
# [progress] epoch 1943/2000 | train_loss=0.5585 | train_loss_epoch=0.5585 | train_loss_step=1.1862 | val_rmse_ema=0.9098
# [Epoch 1942]  Val RMSE (20 Heun steps, EMA) = 0.9097
# [progress] epoch 1944/2000 | train_loss=0.5661 | train_loss_epoch=0.5661 | train_loss_step=0.0163 | val_rmse_ema=0.9097
# [Epoch 1943]  Val RMSE (20 Heun steps, EMA) = 0.9086
# [progress] epoch 1945/2000 | train_loss=0.6318 | train_loss_epoch=0.6318 | train_loss_step=1.4222 | val_rmse_ema=0.9086
# [Epoch 1944]  Val RMSE (20 Heun steps, EMA) = 0.9111
# [progress] epoch 1946/2000 | train_loss=0.5482 | train_loss_epoch=0.5482 | train_loss_step=0.0643 | val_rmse_ema=0.9111
# [Epoch 1945]  Val RMSE (20 Heun steps, EMA) = 0.9111
# [progress] epoch 1947/2000 | train_loss=0.5395 | train_loss_epoch=0.5395 | train_loss_step=1.1746 | val_rmse_ema=0.9111
# [Epoch 1946]  Val RMSE (20 Heun steps, EMA) = 0.9109
# [progress] epoch 1948/2000 | train_loss=0.5530 | train_loss_epoch=0.5530 | train_loss_step=0.1802 | val_rmse_ema=0.9109
# [Epoch 1947]  Val RMSE (20 Heun steps, EMA) = 0.9093
# [progress] epoch 1949/2000 | train_loss=0.5588 | train_loss_epoch=0.5588 | train_loss_step=0.5699 | val_rmse_ema=0.9093
# [Epoch 1948]  Val RMSE (20 Heun steps, EMA) = 0.9112
# [progress] epoch 1950/2000 | train_loss=0.6070 | train_loss_epoch=0.6070 | train_loss_step=0.1740 | val_rmse_ema=0.9112
# [Epoch 1949]  Val RMSE (20 Heun steps, EMA) = 0.9100
# [progress] epoch 1951/2000 | train_loss=0.5676 | train_loss_epoch=0.5676 | train_loss_step=-0.0206 | val_rmse_ema=0.9100
# [Epoch 1950]  Val RMSE (20 Heun steps, EMA) = 0.9089
# [progress] epoch 1952/2000 | train_loss=0.6077 | train_loss_epoch=0.6077 | train_loss_step=0.2694 | val_rmse_ema=0.9089
# [Epoch 1951]  Val RMSE (20 Heun steps, EMA) = 0.9100
# [progress] epoch 1953/2000 | train_loss=0.5386 | train_loss_epoch=0.5386 | train_loss_step=0.5271 | val_rmse_ema=0.9100
# [Epoch 1952]  Val RMSE (20 Heun steps, EMA) = 0.9116
# [progress] epoch 1954/2000 | train_loss=0.6058 | train_loss_epoch=0.6058 | train_loss_step=-0.0179 | val_rmse_ema=0.9116
# [Epoch 1953]  Val RMSE (20 Heun steps, EMA) = 0.9105
# [progress] epoch 1955/2000 | train_loss=0.5360 | train_loss_epoch=0.5360 | train_loss_step=-0.1245 | val_rmse_ema=0.9105
# [Epoch 1954]  Val RMSE (20 Heun steps, EMA) = 0.9109
# [progress] epoch 1956/2000 | train_loss=0.5830 | train_loss_epoch=0.5830 | train_loss_step=1.2439 | val_rmse_ema=0.9109
# [Epoch 1955]  Val RMSE (20 Heun steps, EMA) = 0.9088
# [progress] epoch 1957/2000 | train_loss=0.6299 | train_loss_epoch=0.6299 | train_loss_step=0.1111 | val_rmse_ema=0.9088
# [Epoch 1956]  Val RMSE (20 Heun steps, EMA) = 0.9098
# [progress] epoch 1958/2000 | train_loss=0.6068 | train_loss_epoch=0.6068 | train_loss_step=1.1797 | val_rmse_ema=0.9098
# [Epoch 1957]  Val RMSE (20 Heun steps, EMA) = 0.9087
# [progress] epoch 1959/2000 | train_loss=0.5441 | train_loss_epoch=0.5441 | train_loss_step=0.7011 | val_rmse_ema=0.9087
# [Epoch 1958]  Val RMSE (20 Heun steps, EMA) = 0.9086
# [progress] epoch 1960/2000 | train_loss=0.6288 | train_loss_epoch=0.6288 | train_loss_step=0.6129 | val_rmse_ema=0.9086
# [Epoch 1959]  Val RMSE (20 Heun steps, EMA) = 0.9100
# [progress] epoch 1961/2000 | train_loss=0.5822 | train_loss_epoch=0.5822 | train_loss_step=1.3048 | val_rmse_ema=0.9100
# [Epoch 1960]  Val RMSE (20 Heun steps, EMA) = 0.9092
# [progress] epoch 1962/2000 | train_loss=0.5163 | train_loss_epoch=0.5163 | train_loss_step=-0.0425 | val_rmse_ema=0.9092
# [Epoch 1961]  Val RMSE (20 Heun steps, EMA) = 0.9110
# [progress] epoch 1963/2000 | train_loss=0.5952 | train_loss_epoch=0.5952 | train_loss_step=1.2830 | val_rmse_ema=0.9110
# [Epoch 1962]  Val RMSE (20 Heun steps, EMA) = 0.9103
# [progress] epoch 1964/2000 | train_loss=0.5928 | train_loss_epoch=0.5928 | train_loss_step=1.3243 | val_rmse_ema=0.9103
# [Epoch 1963]  Val RMSE (20 Heun steps, EMA) = 0.9105
# [progress] epoch 1965/2000 | train_loss=0.5408 | train_loss_epoch=0.5408 | train_loss_step=0.1650 | val_rmse_ema=0.9105
# [Epoch 1964]  Val RMSE (20 Heun steps, EMA) = 0.9091
# [progress] epoch 1966/2000 | train_loss=0.5705 | train_loss_epoch=0.5705 | train_loss_step=-0.1161 | val_rmse_ema=0.9091
# [Epoch 1965]  Val RMSE (20 Heun steps, EMA) = 0.9103
# [progress] epoch 1967/2000 | train_loss=0.5858 | train_loss_epoch=0.5858 | train_loss_step=-0.1214 | val_rmse_ema=0.9103
# [Epoch 1966]  Val RMSE (20 Heun steps, EMA) = 0.9105
# [progress] epoch 1968/2000 | train_loss=0.5097 | train_loss_epoch=0.5097 | train_loss_step=0.4676 | val_rmse_ema=0.9105
# [Epoch 1967]  Val RMSE (20 Heun steps, EMA) = 0.9108
# [progress] epoch 1969/2000 | train_loss=0.6026 | train_loss_epoch=0.6026 | train_loss_step=1.4213 | val_rmse_ema=0.9108
# [Epoch 1968]  Val RMSE (20 Heun steps, EMA) = 0.9100
# [progress] epoch 1970/2000 | train_loss=0.5169 | train_loss_epoch=0.5169 | train_loss_step=0.0530 | val_rmse_ema=0.9100
# [Epoch 1969]  Val RMSE (20 Heun steps, EMA) = 0.9120
# [progress] epoch 1971/2000 | train_loss=0.5836 | train_loss_epoch=0.5836 | train_loss_step=1.2624 | val_rmse_ema=0.9120
# [Epoch 1970]  Val RMSE (20 Heun steps, EMA) = 0.9104
# [progress] epoch 1972/2000 | train_loss=0.5153 | train_loss_epoch=0.5153 | train_loss_step=0.3063 | val_rmse_ema=0.9104
# [Epoch 1971]  Val RMSE (20 Heun steps, EMA) = 0.9114
# [progress] epoch 1973/2000 | train_loss=0.5898 | train_loss_epoch=0.5898 | train_loss_step=0.5025 | val_rmse_ema=0.9114
# [Epoch 1972]  Val RMSE (20 Heun steps, EMA) = 0.9118
# [progress] epoch 1974/2000 | train_loss=0.5015 | train_loss_epoch=0.5015 | train_loss_step=1.4247 | val_rmse_ema=0.9118
# [Epoch 1973]  Val RMSE (20 Heun steps, EMA) = 0.9092
# [progress] epoch 1975/2000 | train_loss=0.5032 | train_loss_epoch=0.5032 | train_loss_step=1.3931 | val_rmse_ema=0.9092
# [Epoch 1974]  Val RMSE (20 Heun steps, EMA) = 0.9107
# [progress] epoch 1976/2000 | train_loss=0.5897 | train_loss_epoch=0.5897 | train_loss_step=1.4195 | val_rmse_ema=0.9107
# [Epoch 1975]  Val RMSE (20 Heun steps, EMA) = 0.9097
# [progress] epoch 1977/2000 | train_loss=0.5231 | train_loss_epoch=0.5231 | train_loss_step=0.4262 | val_rmse_ema=0.9097
# [Epoch 1976]  Val RMSE (20 Heun steps, EMA) = 0.9114
# [progress] epoch 1978/2000 | train_loss=0.5237 | train_loss_epoch=0.5237 | train_loss_step=0.1221 | val_rmse_ema=0.9114
# [Epoch 1977]  Val RMSE (20 Heun steps, EMA) = 0.9097
# [progress] epoch 1979/2000 | train_loss=0.5996 | train_loss_epoch=0.5996 | train_loss_step=-0.0196 | val_rmse_ema=0.9097
# [Epoch 1978]  Val RMSE (20 Heun steps, EMA) = 0.9104
# [progress] epoch 1980/2000 | train_loss=0.5084 | train_loss_epoch=0.5084 | train_loss_step=-0.0854 | val_rmse_ema=0.9104
# [Epoch 1979]  Val RMSE (20 Heun steps, EMA) = 0.9102
# [progress] epoch 1981/2000 | train_loss=0.5587 | train_loss_epoch=0.5587 | train_loss_step=-0.0667 | val_rmse_ema=0.9102
# [Epoch 1980]  Val RMSE (20 Heun steps, EMA) = 0.9103
# [progress] epoch 1982/2000 | train_loss=0.5863 | train_loss_epoch=0.5863 | train_loss_step=-0.0265 | val_rmse_ema=0.9103
# [Epoch 1981]  Val RMSE (20 Heun steps, EMA) = 0.9087
# [progress] epoch 1983/2000 | train_loss=0.5947 | train_loss_epoch=0.5947 | train_loss_step=-0.1000 | val_rmse_ema=0.9087
# [Epoch 1982]  Val RMSE (20 Heun steps, EMA) = 0.9107
# [progress] epoch 1984/2000 | train_loss=0.5677 | train_loss_epoch=0.5677 | train_loss_step=1.4264 | val_rmse_ema=0.9107
# [Epoch 1983]  Val RMSE (20 Heun steps, EMA) = 0.9101
# [progress] epoch 1985/2000 | train_loss=0.5806 | train_loss_epoch=0.5806 | train_loss_step=0.7916 | val_rmse_ema=0.9101
# [Epoch 1984]  Val RMSE (20 Heun steps, EMA) = 0.9113
# [progress] epoch 1986/2000 | train_loss=0.5809 | train_loss_epoch=0.5809 | train_loss_step=-0.0859 | val_rmse_ema=0.9113
# [Epoch 1985]  Val RMSE (20 Heun steps, EMA) = 0.9103
# [progress] epoch 1987/2000 | train_loss=0.5165 | train_loss_epoch=0.5165 | train_loss_step=0.0275 | val_rmse_ema=0.9103
# [Epoch 1986]  Val RMSE (20 Heun steps, EMA) = 0.9109
# [progress] epoch 1988/2000 | train_loss=0.5377 | train_loss_epoch=0.5377 | train_loss_step=-0.0327 | val_rmse_ema=0.9109
# [Epoch 1987]  Val RMSE (20 Heun steps, EMA) = 0.9114
# [progress] epoch 1989/2000 | train_loss=0.5312 | train_loss_epoch=0.5312 | train_loss_step=1.4327 | val_rmse_ema=0.9114
# [Epoch 1988]  Val RMSE (20 Heun steps, EMA) = 0.9092
# [progress] epoch 1990/2000 | train_loss=0.6222 | train_loss_epoch=0.6222 | train_loss_step=1.3339 | val_rmse_ema=0.9092
# [Epoch 1989]  Val RMSE (20 Heun steps, EMA) = 0.9089
# [progress] epoch 1991/2000 | train_loss=0.5428 | train_loss_epoch=0.5428 | train_loss_step=0.7298 | val_rmse_ema=0.9089
# [Epoch 1990]  Val RMSE (20 Heun steps, EMA) = 0.9109
# [progress] epoch 1992/2000 | train_loss=0.5607 | train_loss_epoch=0.5607 | train_loss_step=0.5583 | val_rmse_ema=0.9109
# [Epoch 1991]  Val RMSE (20 Heun steps, EMA) = 0.9101
# [progress] epoch 1993/2000 | train_loss=0.5725 | train_loss_epoch=0.5725 | train_loss_step=0.2345 | val_rmse_ema=0.9101
# [Epoch 1992]  Val RMSE (20 Heun steps, EMA) = 0.9105
# [progress] epoch 1994/2000 | train_loss=0.5328 | train_loss_epoch=0.5328 | train_loss_step=1.4352 | val_rmse_ema=0.9105
# [Epoch 1993]  Val RMSE (20 Heun steps, EMA) = 0.9115
# [progress] epoch 1995/2000 | train_loss=0.5305 | train_loss_epoch=0.5305 | train_loss_step=0.1305 | val_rmse_ema=0.9115
# [Epoch 1994]  Val RMSE (20 Heun steps, EMA) = 0.9105
# [progress] epoch 1996/2000 | train_loss=0.4999 | train_loss_epoch=0.4999 | train_loss_step=1.4172 | val_rmse_ema=0.9105
# [Epoch 1995]  Val RMSE (20 Heun steps, EMA) = 0.9115
# [progress] epoch 1997/2000 | train_loss=0.5242 | train_loss_epoch=0.5242 | train_loss_step=1.2860 | val_rmse_ema=0.9115
# [Epoch 1996]  Val RMSE (20 Heun steps, EMA) = 0.9116
# [progress] epoch 1998/2000 | train_loss=0.5589 | train_loss_epoch=0.5589 | train_loss_step=1.3876 | val_rmse_ema=0.9116
# [Epoch 1997]  Val RMSE (20 Heun steps, EMA) = 0.9108
# [progress] epoch 1999/2000 | train_loss=0.5547 | train_loss_epoch=0.5547 | train_loss_step=-0.1419 | val_rmse_ema=0.9108
# [Epoch 1998]  Val RMSE (20 Heun steps, EMA) = 0.9093
# [progress] epoch 2000/2000 | train_loss=0.5712 | train_loss_epoch=0.5712 | train_loss_step=0.6325 | val_rmse_ema=0.9093
# [Epoch 1999]  Val RMSE (20 Heun steps, EMA) = 0.9119
# `Trainer.fit` stopped: `max_epochs=2000` reached.
# ✅ EMA model saved to: logs_FM_spde/best_model

# %% [markdown]
# ## 🎲 Sampling & Evaluation

# %%
# ── Load EMA model for inference ──────────────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype  = torch.float32

# Must match MODEL_PATH used in the training cell
MODEL_PATH = os.path.join("logs_FM_spde", "best_model")

ema_unet = UNetFM.from_pretrained(MODEL_PATH).eval().to(device=device, dtype=dtype)
print(f"EMA UNetFM loaded from {MODEL_PATH}")
print(f"  Device : {next(ema_unet.parameters()).device}")
print(f"  Params : {sum(p.numel() for p in ema_unet.parameters()):,}")
# Out:
# EMA UNetFM loaded from logs_FM_spde/best_model
#   Device : cuda:0
#   Params : 32,269,829

# %% [markdown]
# ### Test Batch

# %%
# ── Test batch ────────────────────────────────────────────────────────────────
seed_everything(42)
batch = next(iter(datamodule.test_dataloader()))

x_gt  = batch.tgt.to(device=device, dtype=dtype)    # (B, C, H, W) ground truth
y_obs = batch.input.to(device=device, dtype=dtype)  # (B, C, H, W) sparse obs (NaN=missing)

B, C, H, W = x_gt.shape
print(f"Test batch  x_gt:{tuple(x_gt.shape)}  y_obs:{tuple(y_obs.shape)}")

start_t = datamodule.test_ds.indices[0]
x_oi_np = datamodule.oi[start_t : start_t + C].astype(np.float32)  # (C, H, W)
m_norm, s_norm = datamodule.norm_stats()
# Out:
# [rank: 0] Global seed set to 42
# Test batch  x_gt:(1, 5, 128, 128)  y_obs:(1, 5, 128, 128)

# %% [markdown]
# ### Ensemble Generation (N_SAMPLES members)

# %%
# N_SAMPLES set by the parameters cell above
N_STEPS   = 20   # Heun ODE steps

samples = []  # list of (B, C, H, W) tensors

with torch.no_grad():
    for s in range(N_SAMPLES):
        noise = torch.randn_like(x_gt)                         # fresh noise per member
        x_pred, _ = heun_sample(ema_unet, noise, y_obs, n_steps=N_STEPS)
        samples.append(x_pred.cpu())
        if (s + 1) % 10 == 0:
            print(f"  member {s+1}/{N_SAMPLES} done")

samples = torch.stack(samples, dim=0)   # (N_SAMPLES, B, C, H, W)
print(f"Ensemble tensor: {tuple(samples.shape)}")

ens_mean = samples.mean(0)              # (B, C, H, W)
ens_std  = samples.std(0)              # (B, C, H, W)
print(f"Ensemble mean range: [{ens_mean.min():.3f}, {ens_mean.max():.3f}]")
print(f"Ensemble std  range: [{ens_std.min():.3f}, {ens_std.max():.3f}]")

# Squeeze batch dim for downstream metrics (use first batch item)
_b = 0
ens_mean_1 = ens_mean[_b]   # (C, H, W) normalized
ens_std_1  = ens_std[_b]    # (C, H, W) normalized
ensemble_1 = samples[:, _b] # (N, C, H, W) normalized
# Out:
# Ensemble tensor: (1, 1, 5, 128, 128)
# Ensemble mean range: [-5.223, 4.762]
# Ensemble std  range: [nan, nan]
# /tmp/ipykernel_2110587/120397973.py:18: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at /pytorch/aten/src/ATen/native/ReduceOps.cpp:1879.)
#   ens_std  = samples.std(0)              # (B, C, H, W)

# %% [markdown]
# ### Publication Figures — comparison & uncertainty

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
from matplotlib.gridspec import GridSpec

FIG_TAG = 'FM_spde'
FIG_DIR = os.path.join('figures', FIG_TAG)
os.makedirs(FIG_DIR, exist_ok=True)

C = datamodule.window_size

obs_phys  = batch.input[_b].float().cpu().numpy() * s_norm + m_norm   # (C,H,W) NaN ok
gt_phys   = batch.tgt[_b].float().cpu().numpy()   * s_norm + m_norm   # (C,H,W)
oi_phys   = x_oi_np                                                    # (C,H,W) physical
mean_phys = ens_mean_1.float().cpu().numpy() * s_norm + m_norm         # (C,H,W)
std_phys  = ens_std_1.float().cpu().numpy()  * s_norm                  # (C,H,W)
mbr0_phys = ensemble_1[0].float().cpu().numpy() * s_norm + m_norm      # (C,H,W)
mbr1_phys = ensemble_1[1].float().cpu().numpy() * s_norm + m_norm      # (C,H,W)

vmax_f = float(np.nanpercentile(np.abs(gt_phys), 99))
vmin_f = -vmax_f
vmax_s = float(np.nanpercentile(std_phys, 99))

cmap_f = plt.cm.RdBu_r.copy(); cmap_f.set_bad('lightgray')
cmap_s = plt.cm.Reds.copy();   cmap_s.set_bad('lightgray')

def _save_strip(data, filename, vmin, vmax, cmap):
    FW, FH, CB_H = 2.0, 2.0, 0.28
    fig_w = C * FW
    fig_h = FH + CB_H + 0.06
    fig = plt.figure(figsize=(fig_w, fig_h))
    gs = GridSpec(2, C,
                  left=0.01, right=0.99, top=0.99, bottom=0.01,
                  height_ratios=[FH, CB_H], hspace=0.06, wspace=0.03)
    for c in range(C):
        ax = fig.add_subplot(gs[0, c])
        ax.imshow(data[c], origin='lower', cmap=cmap,
                  vmin=vmin, vmax=vmax, interpolation='nearest')
        ax.axis('off')
    ax_cb = fig.add_subplot(gs[1, :])
    sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.Normalize(vmin=vmin, vmax=vmax))
    sm.set_array([])
    cb = fig.colorbar(sm, cax=ax_cb, orientation='horizontal')
    cb.ax.tick_params(labelsize=9)
    fpath = os.path.join(FIG_DIR, f'{filename}.png')
    fig.savefig(fpath, dpi=200, bbox_inches='tight')
    print(f'  Saved: {fpath}')
    plt.show()

figures = [
    (obs_phys,  f'{FIG_TAG}_obs',      vmin_f, vmax_f, cmap_f),
    (gt_phys,   f'{FIG_TAG}_gt',       vmin_f, vmax_f, cmap_f),
    (oi_phys,   f'{FIG_TAG}_oi',       vmin_f, vmax_f, cmap_f),
    (mean_phys, f'{FIG_TAG}_fm_mean',  vmin_f, vmax_f, cmap_f),
    (std_phys,  f'{FIG_TAG}_fm_spread',0.0,    vmax_s, cmap_s),
    (mbr0_phys, f'{FIG_TAG}_member0',  vmin_f, vmax_f, cmap_f),
    (mbr1_phys, f'{FIG_TAG}_member1',  vmin_f, vmax_f, cmap_f),
]

for data, fname, vmin, vmax, cmap in figures:
    _save_strip(data, fname, vmin, vmax, cmap)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 15
#      11 oi_phys   = x_oi_np                                                    # (C,H,W) physical
#      12 mean_phys = ens_mean_1.float().cpu().numpy() * s_norm + m_norm         # (C,H,W)
#      13 std_phys  = ens_std_1.float().cpu().numpy()  * s_norm                  # (C,H,W)
#      14 mbr0_phys = ensemble_1[0].float().cpu().numpy() * s_norm + m_norm      # (C,H,W)
# ---> 15 mbr1_phys = ensemble_1[1].float().cpu().numpy() * s_norm + m_norm      # (C,H,W)
#      16
#      17 vmax_f = float(np.nanpercentile(np.abs(gt_phys), 99))
#      18 vmin_f = -vmax_f
#
# IndexError: index 1 is out of bounds for dimension 0 with size 1

# %% [markdown]
# ### ODE Transport Process — Heun trajectory

# %%
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec

T_CH   = datamodule.window_size // 2   # displayed time channel (t=2)
N_SHOW = 10                             # max frames

N_VIZ_STEPS = 20
torch.manual_seed(42)
noise_traj = torch.randn(1, C, H, W, device=device, dtype=dtype)
y_traj     = y_obs[0:1]

with torch.no_grad():
    _, trajectory = heun_sample(ema_unet, noise_traj, y_traj, n_steps=N_VIZ_STEPS)

# trajectory: list of (1, C, H, W) tensors, length = N_VIZ_STEPS + 1
transport_n = torch.stack(trajectory, dim=0)[:, 0, T_CH, :, :].float().cpu().numpy()
transport_p = transport_n * s_norm + m_norm

nfr = transport_p.shape[0]
stride = max(1, nfr // N_SHOW)
idx_show = list(range(0, nfr, stride))
if (nfr - 1) not in idx_show:
    idx_show.append(nfr - 1)
frames = transport_p[idx_show]
nf = len(frames)

# Layout (all in inches, from bottom to top)
FW, FH   = 2.4, 2.4   # frame width / height
ARR_H    = 0.28        # arrow zone
GAP_1    = 0.14        # gap: arrow -> colorbar
CB_H     = 0.26        # colorbar height
GAP_2    = 0.16        # gap: colorbar -> images

fig_w = nf * FW
fig_h = ARR_H + GAP_1 + CB_H + GAP_2 + FH

# Figure-fraction positions (y = 0 at bottom)
arr_y_f   = (ARR_H / 2) / fig_h
cb_bot_f  = (ARR_H + GAP_1) / fig_h
cb_h_f    = CB_H / fig_h
img_bot_f = (ARR_H + GAP_1 + CB_H + GAP_2) / fig_h

fig = plt.figure(figsize=(fig_w, fig_h))

gs = GridSpec(1, nf, left=0.01, right=0.99,
              top=0.99, bottom=img_bot_f,
              hspace=0, wspace=0.02)

vmax_t = float(np.nanpercentile(np.abs(transport_p), 99))
cmap_t = plt.cm.RdBu_r
for i in range(nf):
    ax = fig.add_subplot(gs[0, i])
    ax.imshow(frames[i], origin='lower', cmap=cmap_t,
              vmin=-vmax_t, vmax=vmax_t, interpolation='nearest')
    ax.axis('off')

# Horizontal colorbar
cb_ax = fig.add_axes([0.15, cb_bot_f, 0.70, cb_h_f])
sm = plt.cm.ScalarMappable(cmap=cmap_t, norm=plt.Normalize(-vmax_t, vmax_t))
sm.set_array([])
cb = fig.colorbar(sm, cax=cb_ax, orientation='horizontal')
cb.set_label('GP field (physical units)', fontsize=24, fontweight='bold')
cb.ax.tick_params(labelsize=20)

# Temporal arrow
fig.add_artist(mpatches.FancyArrowPatch(
    (0.04, 1+arr_y_f), (0.96, 1+arr_y_f),
    transform=fig.transFigure, arrowstyle='-|>',
    color='black', mutation_scale=32, linewidth=1.5,
))
fig.text(0.02, 1+arr_y_f, 'noise', va='bottom', ha='left',  fontsize=24, color='steelblue')
fig.text(0.98, 1+arr_y_f, 'clean', va='bottom', ha='right', fontsize=24, color='tomato')
fig.text(0.50, 1+arr_y_f, 'ODE time (Heun)', va='bottom', ha='center', fontsize=24)

fpath = os.path.join(FIG_DIR, f'{FIG_TAG}_transport.png')
fig.savefig(fpath, dpi=200, bbox_inches='tight')
print(f'  Saved: {fpath}')
plt.show()

# %% [markdown]
# ## 📊 Metrics — Flow Matching vs OI
#
# Evaluation at the **centre of the assimilation window** (`t=T_EVAL`, `C=5`).
#
# | Metric | Description |
# |---|---|
# | **Score ↑** | $1 - \text{RMSE}/\sigma_{\text{GT}}$ |
# | **RMSE ↓** | Root Mean Square Error vs GT |
# | **σ_pred** | Standard deviation of the ensemble mean |
# | **CRPS ↓** | Continuous Ranked Probability Score at **observed** pixels |
# | **λx ↓** | Resolved scale (px): wavelength where spectral score = 0.5 |

# %%
import sys
sys.path.append('../..')   # -> consistency/
from spectral_utils import radial_psd_2d, psd_spectral_score, resolved_scale
import pandas as pd

try:
    from properscoring import crps_ensemble as crps_ens_fn
    HAS_PROPERSCORING = True
except ImportError:
    HAS_PROPERSCORING = False
    print("⚠️  properscoring not installed — CRPS disabled.")

DX_PX  = 1.0                           # 1 pixel = 1 km (assumption)

# ── Full test-set evaluation ─────────────────────────────────────────────
# Loops over EVERY batch of datamodule.test_dataloader() (not just the first
# one used for the illustrative figures above) and EVERY timestep of the
# assimilation window (not just T_EVAL=window_size//2), and compares against
# the matching OI baseline slice for every (sample, timestep) pair. This is
# the expensive part (N_SAMPLES x n_test_batches Heun integrations) --
# N_SAMPLES was reduced from 50 to 20 in methods.yaml specifically to keep a
# full-test-set pass affordable. GP is a synthetic continuous field, so
# unlike SIC there is no MIZ-style domain restriction -- metrics are
# aggregated over the whole spatial domain.
_all_fm = {'score': [], 'rmse': [], 'sigma_gt': [], 'sigma_pred': [], 'crps': [], 'lambda_x': []}
_all_oi = {'score': [], 'rmse': [], 'sigma_gt': [], 'sigma_pred': [], 'lambda_x': []}
_n_pairs = 0
_sample_counter = 0

seed_everything(42)
for _tb in datamodule.test_dataloader():
    _x_gt_b = _tb.tgt.to(device=device, dtype=dtype)      # (B, C, H, W)
    _y_b    = _tb.input.to(device=device, dtype=dtype)     # (B, C, H, W)
    _Bb, _Cb, _Hb, _Wb = _x_gt_b.shape
    _valid_b   = ~torch.isnan(_x_gt_b)
    _obsmask_b = ~torch.isnan(_y_b)

    with torch.no_grad():
        _members = []
        for _ in range(N_SAMPLES):
            _noise = torch.randn_like(_x_gt_b)
            _x_pred, _ = heun_sample(ema_unet, _noise, _y_b, n_steps=N_STEPS)
            _members.append(_x_pred.cpu())
    _ens_b = torch.stack(_members, dim=0)         # (N, B, C, H, W) normalised
    _ens_mean_b = _ens_b.mean(0)                   # (B, C, H, W)

    for _bi in range(_Bb):
        _start_t = datamodule.test_ds.indices[_sample_counter]
        _sample_counter += 1
        _oi_traj = datamodule.oi[_start_t : _start_t + _Cb].astype(np.float32)   # (C, H, W)

        for _t in range(_Cb):
            _valid_t = _valid_b[_bi, _t].cpu().numpy()
            if _valid_t.sum() < 10:
                continue
            _gt_p   = _x_gt_b[_bi, _t].float().cpu().numpy() * s_norm + m_norm
            _mean_p = _ens_mean_b[_bi, _t].float().numpy()    * s_norm + m_norm
            _ens_p  = _ens_b[:, _bi, _t].float().numpy()      * s_norm + m_norm
            _oi_p   = _oi_traj[_t]

            _gt_v, _pred_v = _gt_p[_valid_t], _mean_p[_valid_t]
            _sigma = float(np.std(_gt_v))
            if _sigma <= 0:
                continue
            _rmse  = float(np.sqrt(np.mean((_pred_v - _gt_v) ** 2)))
            _score = 1.0 - _rmse / _sigma
            _sigma_pred = float(np.std(_pred_v))

            _gt_f   = np.nan_to_num(_gt_p,   nan=0.0)
            _pred_f = np.nan_to_num(_mean_p, nan=0.0)
            _wl, _, _, _spec = psd_spectral_score(_pred_f, _gt_f, dx=DX_PX)
            _lam = resolved_scale(_wl, _spec, threshold=0.5)

            _crps_val = np.nan
            if HAS_PROPERSCORING:
                _obs_t  = _obsmask_b[_bi, _t].cpu().numpy()
                _obs_ij = np.argwhere(_valid_t & _obs_t)
                if len(_obs_ij) > 0:
                    _stride = max(1, len(_obs_ij) // 50)   # subsample -- CRPS is O(n) Python loop
                    _crps_val = float(np.mean([
                        crps_ens_fn(float(_gt_p[i, j]), _ens_p[:, i, j])
                        for i, j in _obs_ij[::_stride]
                    ]))

            _all_fm['score'].append(_score)
            _all_fm['rmse'].append(_rmse)
            _all_fm['sigma_gt'].append(_sigma)
            _all_fm['sigma_pred'].append(_sigma_pred)
            _all_fm['crps'].append(_crps_val)
            _all_fm['lambda_x'].append(_lam)

            # OI baseline, same (sample, timestep) pair
            _oi_v = _oi_p[_valid_t]
            _rmse_oi  = float(np.sqrt(np.mean((_oi_v - _gt_v) ** 2)))
            _score_oi = 1.0 - _rmse_oi / _sigma
            _sigma_oi_pred = float(np.std(_oi_v))
            _oi_f = np.nan_to_num(_oi_p, nan=0.0)
            _wl_oi, _, _, _spec_oi = psd_spectral_score(_oi_f, _gt_f, dx=DX_PX)
            _lam_oi = resolved_scale(_wl_oi, _spec_oi, threshold=0.5)
            _all_oi['score'].append(_score_oi)
            _all_oi['rmse'].append(_rmse_oi)
            _all_oi['sigma_gt'].append(_sigma)
            _all_oi['sigma_pred'].append(_sigma_oi_pred)
            _all_oi['lambda_x'].append(_lam_oi)

            _n_pairs += 1

print(f"Evaluated {_n_pairs} (test sample, timestep) pairs across the full test set")

def _agg(vals):
    a = np.asarray(vals, dtype=float)
    a = a[~np.isnan(a)]
    return (float(np.mean(a)), float(np.std(a))) if len(a) else (np.nan, np.nan)

def _row(all_dict, label, has_crps=True):
    score_m, score_s = _agg(all_dict['score'])
    rmse_m, rmse_s   = _agg(all_dict['rmse'])
    sgt_m, sgt_s     = _agg(all_dict['sigma_gt'])
    spr_m, spr_s     = _agg(all_dict['sigma_pred'])
    lam_m, lam_s     = _agg(all_dict['lambda_x'])
    row = {
        'Method'   : label,
        'Score ↑'  : f'{score_m:.3f} ± {score_s:.3f}',
        'RMSE ↓'   : f'{rmse_m:.4f} ± {rmse_s:.4f}',
        'σ_GT'     : f'{sgt_m:.4f} ± {sgt_s:.4f}',
        'σ_pred'   : f'{spr_m:.4f} ± {spr_s:.4f}',
        'λx [px]'  : f'{lam_m:.1f} ± {lam_s:.1f}' if not np.isnan(lam_m) else '?',
    }
    if has_crps:
        crps_m, crps_s = _agg(all_dict['crps'])
        row['CRPS ↓'] = f'{crps_m:.4f} ± {crps_s:.4f}' if not np.isnan(crps_m) else '--'
    return row

row_fm = _row(_all_fm, 'FM (ens. mean, full test set)', has_crps=True)
row_oi = _row(_all_oi, 'OI baseline (full test set)',    has_crps=False)
row_oi['CRPS ↓'] = '--'

df_metrics = pd.DataFrame([row_fm, row_oi]).set_index('Method')
df_metrics = df_metrics[['Score ↑','RMSE ↓','σ_GT','σ_pred','CRPS ↓','λx [px]']]
print(f'\n## Metrics -- full test set (whole domain), n={_n_pairs} (sample,t) pairs\n')
display(df_metrics)

# ── Illustrative PSD plot (single example, T_EVAL=window_size//2 of the first
# test batch, same one used by the figures above) -- qualitative check only,
# NOT the quantitative table (that's df_metrics above, full test set now).
T_EVAL = datamodule.window_size // 2
gt_p_ex   = batch.tgt[_b, T_EVAL].float().cpu().numpy() * s_norm + m_norm
mean_p_ex = ens_mean_1[T_EVAL].float().cpu().numpy()    * s_norm + m_norm
oi_p_ex   = x_oi_np[T_EVAL]

wl_gt,  psd_gt_sig  = radial_psd_2d(gt_p_ex,   dx=DX_PX)
wl_fm2, psd_fm_sig  = radial_psd_2d(mean_p_ex, dx=DX_PX)
wl_oi2, psd_oi_sig  = radial_psd_2d(oi_p_ex,   dx=DX_PX)
wl_fm, _, _, spec_fm = psd_spectral_score(mean_p_ex, gt_p_ex, dx=DX_PX)
wl_oi, _, _, spec_oi = psd_spectral_score(oi_p_ex,   gt_p_ex, dx=DX_PX)
lambda_x_fm = resolved_scale(wl_fm, spec_fm)
lambda_x_oi = resolved_scale(wl_oi, spec_oi)

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

ax = axes[0]
for wl, psd, color, ls, lbl in [
    (wl_gt,  psd_gt_sig,  'black', '-',  'GT'),
    (wl_fm2, psd_fm_sig,  'C0',   '-',  'FM (ens. mean)'),
    (wl_oi2, psd_oi_sig,  'C1',   '--', 'OI baseline'),
]:
    v = np.isfinite(wl) & np.isfinite(psd) & (wl > 0) & (psd > 0)
    ax.loglog(1.0/wl[v], psd[v], color=color, ls=ls, lw=2, label=lbl)
ax.set_xlabel('Spatial frequency  [cycles / pixel]')
ax.set_ylabel('PSD')
ax.set_title(f'Radial PSD (Hann, illustrative t={T_EVAL})')
ax.legend()
ax.grid(True, which='both', alpha=0.3)

ax = axes[1]
lbl_fm = f'FM  (λx = {lambda_x_fm:.1f} px)' if not np.isnan(lambda_x_fm) else 'FM'
lbl_oi = f'OI  (λx = {lambda_x_oi:.1f} px)' if not np.isnan(lambda_x_oi) else 'OI'
for wl, spec, color, ls, lbl in [
    (wl_fm, spec_fm, 'C0', '-',  lbl_fm),
    (wl_oi, spec_oi, 'C1', '--', lbl_oi),
]:
    v = np.isfinite(wl) & np.isfinite(spec)
    ax.plot(wl[v], spec[v], color=color, ls=ls, lw=2, label=lbl)
ax.axhline(0.5, color='gray', lw=1.2, ls='--', label='threshold 0.5')
if not np.isnan(lambda_x_fm):
    ax.axvline(lambda_x_fm, color='C0', lw=1, ls=':')
if not np.isnan(lambda_x_oi):
    ax.axvline(lambda_x_oi, color='C1', lw=1, ls=':')
ax.set_xlabel('Wavelength [px]')
ax.set_ylabel('Spectral score')
ax.set_title('Score PSD  = 1 − PSD(err) / PSD(GT) (illustrative)')
ax.set_ylim(-0.3, 1.05)
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# --- metrics serialization (patch_notebook_params.py) ---
import os
os.makedirs(os.path.dirname(METRICS_CSV) or '.', exist_ok=True)
_df_out = df_metrics.reset_index() if df_metrics.index.name == 'Method' else df_metrics
_df_out.to_csv(METRICS_CSV, index=False)
print(f'Metrics written to {METRICS_CSV}')
